# %% [markdown]
# # Imports

# %%
import pandas as pd
import re
import json
import os
import nltk
from tfidf_ranker import get_most_relevant_sentence_index
import random

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\klouc\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# # Constants

# %%
SUBSTITUTIONS_FILE_PATH = 'data/recipe_substitution_10Sept.xlsx'
RECIPES_FILE_PATH = 'data/recipe_collection/recipe_collection'
KB_PATH = 'data/KB.json'
OUTPUT_CSV_FILE_PATH = 'data/triplets.csv'
 
NEGATIVE_PER_PAIR = 10

# %% [markdown]
# # Load Dataset

# %%
# Load substitution dataset

df = pd.read_excel(SUBSTITUTIONS_FILE_PATH)
print("Number of rows before NaN removal:", df.shape[0])

# Drop rows with missing critical vals
df.dropna(subset=['recipe_id',
                  'ingredient_name',
                  'MasterDB match for subsitutable ingredient',
                  'substitution_text',
                  'DB Food #1'], inplace=True)
print("Number of rows:", df.shape[0])
df
# Out:
# Number of rows before NaN removal: 893
# Number of rows: 892
#      participant_id  recipe_id   ingredient_name  \
# 1      1.256701e+10      400.0     pork sausages
# 2      1.256701e+10       40.0           chicken
# 3      1.256701e+10       38.0       minced beef
# 4      1.256701e+10       39.0   chicken breasts
# 5      1.256701e+10      243.0        beef mince
# ..              ...        ...               ...
# 888    1.271014e+10      551.0  chopped tomatoes
# 889    1.271014e+10      550.0         aubergine
# 890    1.271014e+10      550.0            tomato
# 891    1.271014e+10      550.0       penne pasta
# 892    1.271014e+10      547.0         chickpeas
#
#     MasterDB match for subsitutable ingredient  \
# 1                                      Sausage
# 2                               Chicken:Breast
# 3                                   Beef:Mince
# 4                               Chicken:Breast
# 5                                   Beef:Mince
# ..                                         ...
# 888                              Tomato:Tinned
# 889                                  Aubergine
# 890                               Tomato:Fresh
# 891                                      Pasta
# 892                                   Chickpea
#
#                                     substitution_text           DB Food #1  \
# 1                                      Quorn sausages        Quorn:Sausage
# 2                                        Quorn roast           Quorn:Mince
# 3                                         Quorn mince          Quorn:Mince
# 4                                        Quorn pieces         Quorn:Pieces
# 5                                         Quorn mince          Quorn:Mince
# ..                                                ...                  ...
# 888                                           Passata  Tomato:Passata_SAME
# 889            Leek, mushroom, red cabbage, chickpeas                 Leek
# 890               Tinned chopped tomatoes, red pepper   Tomato:Tinned_SAME
# 891  Spaghetti, macaroni, couscous, rice, other pasta            Spaghetti
# 892       Kidney beans, pinto beans, cannellini beans          Kidney bean
#
#      DB Food #2       DB Food #3  DB Food #4 DB Food #5 Unnamed: 10  \
# 1           NaN              NaN         NaN        NaN         NaN
# 2           NaN              NaN         NaN        NaN         NaN
# 3           NaN              NaN         NaN        NaN         NaN
# 4           NaN              NaN         NaN        NaN         NaN
# 5           NaN              NaN         NaN        NaN         NaN
# ..          ...              ...         ...        ...         ...
# 888         NaN              NaN         NaN        NaN         NaN
# 889    Mushroom          Cabbage    Chickpea        NaN         NaN
# 890      Pepper              NaN         NaN        NaN         NaN
# 891  Pasta_SAME         Couscous  White rice        NaN         NaN
# 892  Pinto bean  Cannellini bean         NaN        NaN         NaN
#
#      Addition #1  Addition #2  Addition #3  Addition #4  Addition #5  \
# 1            NaN          NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN          NaN
# 5            NaN          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 888          NaN          NaN          NaN          NaN          NaN
# 889          NaN          NaN          NaN          NaN          NaN
# 890          NaN          NaN          NaN          NaN          NaN
# 891          NaN          NaN          NaN          NaN          NaN
# 892          NaN          NaN          NaN          NaN          NaN
#
#      Brand needed for substitute model?
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# ..                                  ...
# 888                                 NaN
# 889                                 NaN
# 890                                 NaN
# 891                                 NaN
# 892                                 NaN
#
# [892 rows x 17 columns]

# %% [markdown]
# # Simplifying Dataset (by removing high-level elements for now)

# %%
def term_contains_banned_term(term):
    banned_terms = ['SAME', 'MORE', 'REMOVE', 'REFUSAL', 'COMPLEX']
    for banned_term in banned_terms:
        if(banned_term in term):
            return True
    return False

# remove those which suggest substituions with SAME, MORE, REMOVE, REFUSAL and COMPLEX subtitutions
# if more than on sub suggested, take first one that is not SAME, MORE, REMOVE, REFUSAL and COMPLEX
def simplify_dataset(row):
    # FIELD NAMES:
    # participant_id
    # recipe_id
    # ingredient_name
    # MasterDB match for subsitutable ingredient
    # substitution_text
    # DB Food #1
    # DB Food #2
    # DB Food #3
    # DB Food #4
    # DB Food #5
    # Unnamed: 10
    # Addition #1
    # Addition #2
    # Addition #3
    # Addition #4
    # Addition #5
    # Brand needed for substitute model?

    # We care only about participant_id, recipe_id, ingredient_name, MasterDB match for subsitutable ingredient,
    # and the ingredient we will choose to substitute (it's raw and matched form)
    raw_subs = row['substitution_text'].split(',')
    for idx, sub_suggestion_key in enumerate(['DB Food #1', 'DB Food #2', 'DB Food #3', 'DB Food #4', 'DB Food #5']):
        sub_suggestion = row[sub_suggestion_key]
        if(not (pd.isna(sub_suggestion) or term_contains_banned_term(sub_suggestion))):
            # Here we attempt to extract the raw sub text very crudely (sorry), since the raw sub text (usually)
            # is just a list separted by commas, so we choose the index of the DB food wrt the commas, if that doesn't work,
            # take the first one on the list
            row['chosen_sub_match'] = row[sub_suggestion_key]
            try:
                row['chosen_sub_raw'] = raw_subs[idx]
            except:
                row['chosen_sub_raw'] = raw_subs[0]
            return row

# %%
simple_df = df.apply(lambda row: simplify_dataset(row), axis=1)
simple_df
# Out:
#      participant_id  recipe_id  ingredient_name  \
# 1      1.256701e+10      400.0    pork sausages
# 2      1.256701e+10       40.0          chicken
# 3      1.256701e+10       38.0      minced beef
# 4      1.256701e+10       39.0  chicken breasts
# 5      1.256701e+10      243.0       beef mince
# ..              ...        ...              ...
# 888             NaN        NaN             None
# 889    1.271014e+10      550.0        aubergine
# 890    1.271014e+10      550.0           tomato
# 891    1.271014e+10      550.0      penne pasta
# 892    1.271014e+10      547.0        chickpeas
#
#     MasterDB match for subsitutable ingredient  \
# 1                                      Sausage
# 2                               Chicken:Breast
# 3                                   Beef:Mince
# 4                               Chicken:Breast
# 5                                   Beef:Mince
# ..                                         ...
# 888                                       None
# 889                                  Aubergine
# 890                               Tomato:Fresh
# 891                                      Pasta
# 892                                   Chickpea
#
#                                     substitution_text          DB Food #1  \
# 1                                      Quorn sausages       Quorn:Sausage
# 2                                        Quorn roast          Quorn:Mince
# 3                                         Quorn mince         Quorn:Mince
# 4                                        Quorn pieces        Quorn:Pieces
# 5                                         Quorn mince         Quorn:Mince
# ..                                                ...                 ...
# 888                                              None                None
# 889            Leek, mushroom, red cabbage, chickpeas                Leek
# 890               Tinned chopped tomatoes, red pepper  Tomato:Tinned_SAME
# 891  Spaghetti, macaroni, couscous, rice, other pasta           Spaghetti
# 892       Kidney beans, pinto beans, cannellini beans         Kidney bean
#
#      DB Food #2       DB Food #3  DB Food #4 DB Food #5 Unnamed: 10  \
# 1           NaN              NaN         NaN        NaN         NaN
# 2           NaN              NaN         NaN        NaN         NaN
# 3           NaN              NaN         NaN        NaN         NaN
# 4           NaN              NaN         NaN        NaN         NaN
# 5           NaN              NaN         NaN        NaN         NaN
# ..          ...              ...         ...        ...         ...
# 888        None             None        None       None        None
# 889    Mushroom          Cabbage    Chickpea       None        None
# 890      Pepper              NaN         NaN       None        None
# 891  Pasta_SAME         Couscous  White rice       None        None
# 892  Pinto bean  Cannellini bean         NaN       None        None
#
#      Addition #1  Addition #2  Addition #3  Addition #4  Addition #5  \
# 1            NaN          NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN          NaN
# 5            NaN          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 888          NaN          NaN          NaN          NaN          NaN
# 889          NaN          NaN          NaN          NaN          NaN
# 890          NaN          NaN          NaN          NaN          NaN
# 891          NaN          NaN          NaN          NaN          NaN
# 892          NaN          NaN          NaN          NaN          NaN
#
#      Brand needed for substitute model? chosen_sub_match  chosen_sub_raw
# 1                                   NaN    Quorn:Sausage  Quorn sausages
# 2                                   NaN      Quorn:Mince    Quorn roast
# 3                                   NaN      Quorn:Mince     Quorn mince
# 4                                   NaN     Quorn:Pieces    Quorn pieces
# 5                                   NaN      Quorn:Mince     Quorn mince
# ..                                  ...              ...             ...
# 888                                 NaN             None            None
# 889                                 NaN             Leek            Leek
# 890                                 NaN           Pepper      red pepper
# 891                                 NaN        Spaghetti       Spaghetti
# 892                                 NaN      Kidney bean    Kidney beans
#
# [892 rows x 19 columns]

# %%
simple_df = simple_df.drop(labels=['DB Food #1', 'DB Food #2', 'DB Food #3', 'DB Food #4', 'DB Food #5',
                'Unnamed: 10', 'Addition #1', 'Addition #2', 'Addition #3', 'Addition #4',
                'Addition #5', 'Brand needed for substitute model?'], axis=1)

# %%
simple_df = simple_df.dropna()
simple_df
# Out:
#      participant_id  recipe_id  ingredient_name  \
# 1      1.256701e+10      400.0    pork sausages
# 2      1.256701e+10       40.0          chicken
# 3      1.256701e+10       38.0      minced beef
# 4      1.256701e+10       39.0  chicken breasts
# 5      1.256701e+10      243.0       beef mince
# ..              ...        ...              ...
# 887    1.271014e+10      551.0           paneer
# 889    1.271014e+10      550.0        aubergine
# 890    1.271014e+10      550.0           tomato
# 891    1.271014e+10      550.0      penne pasta
# 892    1.271014e+10      547.0        chickpeas
#
#     MasterDB match for subsitutable ingredient  \
# 1                                      Sausage
# 2                               Chicken:Breast
# 3                                   Beef:Mince
# 4                               Chicken:Breast
# 5                                   Beef:Mince
# ..                                         ...
# 887                                     Paneer
# 889                                  Aubergine
# 890                               Tomato:Fresh
# 891                                      Pasta
# 892                                   Chickpea
#
#                                     substitution_text chosen_sub_match  \
# 1                                      Quorn sausages    Quorn:Sausage
# 2                                        Quorn roast       Quorn:Mince
# 3                                         Quorn mince      Quorn:Mince
# 4                                        Quorn pieces     Quorn:Pieces
# 5                                         Quorn mince      Quorn:Mince
# ..                                                ...              ...
# 887                         Aubergine, tofu, mushroom        Aubergine
# 889            Leek, mushroom, red cabbage, chickpeas             Leek
# 890               Tinned chopped tomatoes, red pepper           Pepper
# 891  Spaghetti, macaroni, couscous, rice, other pasta        Spaghetti
# 892       Kidney beans, pinto beans, cannellini beans      Kidney bean
#
#      chosen_sub_raw
# 1    Quorn sausages
# 2      Quorn roast
# 3       Quorn mince
# 4      Quorn pieces
# 5       Quorn mince
# ..              ...
# 887       Aubergine
# 889            Leek
# 890      red pepper
# 891       Spaghetti
# 892    Kidney beans
#
# [745 rows x 7 columns]

# %% [markdown]
# # Makeshift Knowledge Base

# %%
# Get all formal entries by removing SAME, MORE, REMOVE, REFUSAL and COMPLEX
def clean_ingred(ingred):
    if(pd.isna(ingred)):
        return ''
    
    # Almond_SAME => Almond
    # Almond_MORE => Almond
    # REMOVE, REFUSAL, COMPLEX => ''
    return re.sub(r'_SAME|_MORE|REMOVE|REFUSAL|COMPLEX', '', ingred)

def extract_ingred_set(collection):
    return set([clean_ingred(sub) for sub in collection.tolist() if clean_ingred(sub) != ''])

# %%
ingred_collections = ['MasterDB match for subsitutable ingredient',
                      'DB Food #1',
                      'DB Food #2',
                      'DB Food #3',
                      'DB Food #4',
                      'DB Food #5']

makeshift_kb = set()
for collection_key in ingred_collections:
    makeshift_kb.update(extract_ingred_set(df[collection_key]))
    print('After update, KB has ', len(makeshift_kb), ' elements.')
# Out:
# After update, KB has  133  elements.
# After update, KB has  216  elements.
# After update, KB has  242  elements.
# After update, KB has  252  elements.
# After update, KB has  256  elements.
# After update, KB has  258  elements.

# %% [markdown]
# # Building Triplet Dataset

# %%
simple_df
# Out:
#      participant_id  recipe_id  ingredient_name  \
# 1      1.256701e+10      400.0    pork sausages
# 2      1.256701e+10       40.0          chicken
# 3      1.256701e+10       38.0      minced beef
# 4      1.256701e+10       39.0  chicken breasts
# 5      1.256701e+10      243.0       beef mince
# ..              ...        ...              ...
# 887    1.271014e+10      551.0           paneer
# 889    1.271014e+10      550.0        aubergine
# 890    1.271014e+10      550.0           tomato
# 891    1.271014e+10      550.0      penne pasta
# 892    1.271014e+10      547.0        chickpeas
#
#     MasterDB match for subsitutable ingredient  \
# 1                                      Sausage
# 2                               Chicken:Breast
# 3                                   Beef:Mince
# 4                               Chicken:Breast
# 5                                   Beef:Mince
# ..                                         ...
# 887                                     Paneer
# 889                                  Aubergine
# 890                               Tomato:Fresh
# 891                                      Pasta
# 892                                   Chickpea
#
#                                     substitution_text chosen_sub_match  \
# 1                                      Quorn sausages    Quorn:Sausage
# 2                                        Quorn roast       Quorn:Mince
# 3                                         Quorn mince      Quorn:Mince
# 4                                        Quorn pieces     Quorn:Pieces
# 5                                         Quorn mince      Quorn:Mince
# ..                                                ...              ...
# 887                         Aubergine, tofu, mushroom        Aubergine
# 889            Leek, mushroom, red cabbage, chickpeas             Leek
# 890               Tinned chopped tomatoes, red pepper           Pepper
# 891  Spaghetti, macaroni, couscous, rice, other pasta        Spaghetti
# 892       Kidney beans, pinto beans, cannellini beans      Kidney bean
#
#      chosen_sub_raw
# 1    Quorn sausages
# 2      Quorn roast
# 3       Quorn mince
# 4      Quorn pieces
# 5       Quorn mince
# ..              ...
# 887       Aubergine
# 889            Leek
# 890      red pepper
# 891       Spaghetti
# 892    Kidney beans
#
# [745 rows x 7 columns]

# %%
class Ingredient:
    def __init__(self, rawName=None, matched=None):
        self.rawRecipeText = None
        self.rawName = rawName
        self.matched = matched

    def __repr__(self):
        return f'{self.rawRecipeText}, {self.rawName}, {self.matched}'


class TripletPoint:
    def __init__(self, recipe_id, anchor, pos, neg=None):
        self.recipe_id = recipe_id
        self.anchor = anchor
        self.pos = pos
        self.neg = neg

    def __repr__(self):
        return f'id: {self.recipe_id}\nanchor: ({self.anchor})\npos: ({self.pos})\nneg: ({self.neg})'
    
    def getDeepCopy(self):
        copy = TripletPoint(recipe_id=self.recipe_id,
                            anchor=Ingredient(
                                    rawName=self.anchor.rawName,
                                    matched=self.anchor.matched),
                            pos=Ingredient(
                                    rawName=self.pos.rawName,
                                    matched=self.pos.matched))
        return copy

# %%
tripletPoints = set()

for index, row in simple_df.iterrows():
    dataPoint = TripletPoint(
                             recipe_id=int(row['recipe_id']),
                             anchor=Ingredient(
                                        rawName=row['ingredient_name'],
                                        matched=row['MasterDB match for subsitutable ingredient']),
                             pos=Ingredient(
                                        rawName=row['chosen_sub_raw'],
                                        matched=row['chosen_sub_match']))
    tripletPoints.add(dataPoint)

print('Constructed', len(tripletPoints), 'valid anchor-pos pairs.')
# Out:
# Constructed 745 valid anchor-pos pairs.

# %%
list(tripletPoints)[0]
# Out:
# id: 423
# anchor: (None, mature cheddar, Cheddar)
# pos: (None, Pecorino, Cheese)
# neg: (None)

# %%
recipeJsons = dict()

# Go through recipe direcory
for recipe in os.listdir(RECIPES_FILE_PATH):
    recipeId = recipe.replace('.json', '')

    # If file empty, do not attempt to open
    if(os.stat(RECIPES_FILE_PATH + '/' + recipe).st_size == 0):
        recipeJsons[recipeId] = None
        continue

    with open(RECIPES_FILE_PATH + '/' + recipe, 'r', encoding='utf-8') as file:
        recipeData = json.load(file)
        recipeJsons[recipeId] = recipeData

print('Extracted', len(recipeJsons.items()), 'recipes,',
      len([recipe for recipe in recipeJsons.items() if recipe[1] != None]), 'out of which have content.')
# Out:
# Extracted 583 recipes, 546 out of which have content.

# %%
recipeJsons['132']
# Out:
# {'url': 'https://www.simplyrecipes.com/recipes/lasagna/',
#  'title': 'Lasagna',
#  'total_CO2': 97.40525113491401,
#  'servings': 8,
#  'CO2_per_portion': 12.175656391864251,
#  'E.Mission coefficient': 4.31582763436642,
#  'ingredients': [{'ingredient_number': 1,
#    'original_string': 'A large skillet to brown the beef, bell pepper, and onion',
#    'amount': '1.0',
#    'unit': 'large',
#    'ingredient_name': 'beef',
#    'matched_ingredient': 'Beef',
#    'kg_equivalent': 0.272,
#    'carbon_per_kg': 59.57,
#    'ingredient_carbon': 16.20304},
#   {'ingredient_number': 2,
#    'original_string': '1 28-ounce can good quality tomato sauce',
#    'amount': '29.0',
#    'unit': 'ounce',
#    'ingredient_name': 'tomato sauce',
#    'matched_ingredient': 'Tomato sauce',
#    'kg_equivalent': 0.822136170625,
#    'carbon_per_kg': 1.427,
#    'ingredient_carbon': 1.173188315481875},
#   {'ingredient_number': 3,
#    'original_string': '1 14-ounce can crushed tomatoes',
#    'amount': '15.0',
#    'unit': 'ounce',
#    'ingredient_name': 'crushed tomatoes',
#    'matched_ingredient': 'Tomato',
#    'kg_equivalent': 0.425242846875,
#    'carbon_per_kg': 1.427,
#    'ingredient_carbon': 0.606821542490625},
#   {'ingredient_number': 4,
#    'original_string': 'A large slotted cooking spoon',
#    'amount': '1.0',
#    'unit': 'large',
#    'ingredient_name': 'slotted cooking spoon',
#    'matched_ingredient': 'Groundnut oil',
#    'kg_equivalent': 0.0,
#    'carbon_per_kg': 5.752,
#    'ingredient_carbon': 0.0},
#   {'ingredient_number': 5,
#    'original_string': 'A large wooden cooking spoon',
#    'amount': '1.0',
#    'unit': 'large',
#    'ingredient_name': 'wooden cooking spoon',
#    'matched_ingredient': 'Groundnut oil',
#    'kg_equivalent': 0.0,
#    'carbon_per_kg': 5.752,
#    'ingredient_carbon': 0.0},
#   {'ingredient_number': 6,
#    'original_string': '1/4 cup chopped fresh parsley (preferably flat leaf), packed',
#    'amount': '0.25',
#    'unit': 'cup',
#    'ingredient_name': 'chopped fresh parsley',
#    'matched_ingredient': 'Parsley',
#    'kg_equivalent': 0.059147059125,
#    'carbon_per_kg': 0.437,
#    'ingredient_carbon': 0.025847264837625},
#   {'ingredient_number': 7,
#    'original_string': '2 cloves garlic, minced',
#    'amount': '2.0',
#    'unit': 'cloves',
#    'ingredient_name': 'garlic',
#    'matched_ingredient': 'Garlic',
#    'kg_equivalent': 0.006,
#    'carbon_per_kg': 0.395,
#    'ingredient_carbon': 0.00237},
#   {'ingredient_number': 8,
#    'original_string': 'Pinch of garlic powder and/or garlic salt',
#    'amount': '1.0',
#    'unit': 'pinch',
#    'ingredient_name': 'garlic powder',
#    'matched_ingredient': 'Garlic',
#    'kg_equivalent': 0.005,
#    'carbon_per_kg': 0.395,
#    'ingredient_carbon': 0.001975},
#   {'ingredient_number': 9,
#    'original_string': 'A medium saucepan (3-4 quarts) to simmer the sauce',
#    'amount': '3.5',
#    'unit': 'quarts',
#    'ingredient_name': 'sauce',
#    'matched_ingredient': 'Soy Sauce',
#    'kg_equivalent': 3.312235311,
#    'carbon_per_kg': 0.914,
#    'ingredient_carbon': 3.0273830742539998},
#   {'ingredient_number': 10,
#    'original_string': '1 Tbsp Italian Seasoning',
#    'amount': '1.0',
#    'unit': 'tbsp',
#    'ingredient_name': 'Italian Seasoning',
#    'matched_ingredient': 'Jerk seasoning',
#    'kg_equivalent': 0.0087,
#    'carbon_per_kg': 12.124,
#    'ingredient_carbon': 0.1054788},
#   {'ingredient_number': 11,
#    'original_string': '1/2 lb dry lasagna noodles (requires 9 lasagna noodles - unbroken)',
#    'amount': '0.5',
#    'unit': 'lb',
#    'ingredient_name': 'lasagna noodles',
#    'matched_ingredient': 'Egg noodle',
#    'kg_equivalent': 0.226796185,
#    'carbon_per_kg': 4.507,
#    'ingredient_carbon': 1.022170405795},
#   {'ingredient_number': 12,
#    'original_string': '1 pound lean ground beef (chuck)',
#    'amount': '1.0',
#    'unit': 'pound',
#    'ingredient_name': 'lean ground beef',
#    'matched_ingredient': 'Beef',
#    'kg_equivalent': 0.45359237,
#    'carbon_per_kg': 59.57,
#    'ingredient_carbon': 27.0204974809},
#   {'ingredient_number': 13,
#    'original_string': '1 1/2 lb (24 ounces) Mozzarella cheese, grated or sliced',
#    'amount': '1.5',
#    'unit': 'lb',
#    'ingredient_name': 'Mozzarella cheese',
#    'matched_ingredient': 'Mozzarella',
#    'kg_equivalent': 0.680388555,
#    'carbon_per_kg': 21.24,
#    'ingredient_carbon': 14.451452908199999},
#   {'ingredient_number': 14,
#    'original_string': 'A couple large sheet pans to cool the noodles',
#    'amount': '1.0',
#    'unit': 'large',
#    'ingredient_name': 'noodles',
#    'matched_ingredient': 'Rice noodle',
#    'kg_equivalent': 0.0,
#    'carbon_per_kg': 3.839,
#    'ingredient_carbon': 0.0},
#   {'ingredient_number': 15,
#    'original_string': 'A large colander to drain the noodles',
#    'amount': '1.0',
#    'unit': 'large',
#    'ingredient_name': 'noodles',
#    'matched_ingredient': 'Rice noodle',
#    'kg_equivalent': 0.0,
#    'carbon_per_kg': 3.839,
#    'ingredient_carbon': 0.0},
#   {'ingredient_number': 16,
#    'original_string': 'Olive oil',
#    'amount': '1.0',
#    'ingredient_name': 'Olive oil',
#    'matched_ingredient': 'Olive oil',
#    'kg_equivalent': 0.014,
#    'carbon_per_kg': 5.944,
#    'ingredient_carbon': 0.083216},
#   {'ingredient_number': 17,
#    'original_string': '1/2 onion, diced, about 3/4 cup',
#    'amount': '0.5',
#    'unit': 'cup',
#    'ingredient_name': 'onion',
#    'matched_ingredient': 'Onion',
#    'kg_equivalent': 0.026024706015,
#    'carbon_per_kg': 0.395,
#    'ingredient_carbon': 0.010279758875925001},
#   {'ingredient_number': 18,
#    'original_string': '2 Tbsp chopped fresh oregano or 2 teaspoons dried oregano',
#    'amount': '1.0',
#    'unit': 'Tbsp',
#    'ingredient_name': 'chopped fresh oregano',
#    'matched_ingredient': 'Oregano',
#    'kg_equivalent': 0.0087,
#    'carbon_per_kg': 0.437,
#    'ingredient_carbon': 0.0038018999999999996},
#   {'ingredient_number': 19,
#    'original_string': '2 Tbsp chopped fresh oregano or 2 teaspoons dried oregano',
#    'amount': '1.0',
#    'unit': 'Tbsp',
#    'ingredient_name': 'dried oregano',
#    'matched_ingredient': 'Oregano',
#    'kg_equivalent': 0.0087,
#    'carbon_per_kg': 0.437,
#    'ingredient_carbon': 0.0038018999999999996},
#   {'ingredient_number': 20,
#    'original_string': '1/4 lb (4 ounces) freshly grated Parmesan cheese',
#    'amount': '0.25',
#    'unit': 'lb',
#    'ingredient_name': 'freshly grated Parmesan cheese',
#    'matched_ingredient': 'Parmesan',
#    'kg_equivalent': 0.1133980925,
#    'carbon_per_kg': 21.24,
#    'ingredient_carbon': 2.4085754847},
#   {'ingredient_number': 21,
#    'original_string': 'A large pot (8-12-quarts) for cooking the pasta',
#    'amount': '20.0',
#    'unit': 'quarts',
#    'ingredient_name': 'pasta',
#    'matched_ingredient': 'Pasta',
#    'kg_equivalent': 15.141647136,
#    'carbon_per_kg': 1.441,
#    'ingredient_carbon': 21.819113522976},
#   {'ingredient_number': 22,
#    'original_string': '1 Tbsp red or white wine vinegar',
#    'amount': '0.5',
#    'unit': 'Tbsp',
#    'ingredient_name': 'red',
#    'matched_ingredient': 'Red Windsor',
#    'kg_equivalent': 0.00255,
#    'carbon_per_kg': 21.24,
#    'ingredient_carbon': 0.054162},
#   {'ingredient_number': 23,
#    'original_string': '1 Tbsp red or white wine vinegar',
#    'amount': '0.5',
#    'unit': 'Tbsp',
#    'ingredient_name': 'white wine vinegar',
#    'matched_ingredient': 'Vinegar',
#    'kg_equivalent': 0.0075,
#    'carbon_per_kg': 1.585,
#    'ingredient_carbon': 0.011887499999999999},
#   {'ingredient_number': 24,
#    'original_string': '15 ounces Ricotta cheese',
#    'amount': '15.0',
#    'unit': 'ounces',
#    'ingredient_name': 'Ricotta cheese',
#    'matched_ingredient': 'Ricotta',
#    'kg_equivalent': 0.425242846875,
#    'carbon_per_kg': 21.24,
#    'ingredient_carbon': 9.032158067625},
#   {'ingredient_number': 26,
#    'original_string': "A chef's knife or large paring knife to cut the vegetables",
#    'amount': '1.0',
#    'unit': 'large',
#    'ingredient_name': 'vegetables',
#    'matched_ingredient': 'Vegetable',
#    'kg_equivalent': 0.17,
#    'carbon_per_kg': 0.455,
#    'ingredient_carbon': 0.07735},
#   {'ingredient_number': 27,
#    'original_string': "A chef's knife or large paring knife to cut the vegetables",
#    'amount': '1.0',
#    'unit': 'large',
#    'ingredient_name': 'vegetables',
#    'matched_ingredient': 'Vegetable',
#    'kg_equivalent': 0.17,
#    'carbon_per_kg': 0.455,
#    'ingredient_carbon': 0.07735},
#   {'ingredient_number': 28,
#    'original_string': "13'' x 9'' x 2'' lasagna pan, preferably pyrex or stainless steel (avoid aluminum pans if you can, they can react with the acidity of the sauce)",
#    'amount': '0.0',
#    'unit': "x 9'' x 2''",
#    'ingredient_name': 'acidity',
#    'matched_ingredient': 'Bicarbonate of soda',
#    'kg_equivalent': 0.0,
#    'carbon_per_kg': 12.124,
#    'ingredient_carbon': 0.0},
#   {'ingredient_number': 29,
#    'original_string': '1 Tbsp to 1/4 cup sugar (to taste, optional)',
#    'amount': '1.0',
#    'unit': 'Tbsp to 1',
#    'ingredient_name': 'sugar',
#    'matched_ingredient': 'Sugar',
#    'kg_equivalent': 0.0046,
#    'carbon_per_kg': 1.536,
#    'ingredient_carbon': 0.0070656},
#   {'ingredient_number': 30,
#    'original_string': '3 ounces (half a 6-oz can) tomato paste',
#    'amount': '3.0',
#    'unit': 'ounces',
#    'ingredient_name': 'tomato paste',
#    'matched_ingredient': 'Cherry tomato',
#    'kg_equivalent': 0.085048569375,
#    'carbon_per_kg': 1.427,
#    'ingredient_carbon': 0.12136430849812499},
#   {'ingredient_number': 31,
#    'original_string': '1/2 large bell pepper (green, red, or yellow), stem and core removed, diced, about 3/4 cup',
#    'amount': '0.5',
#    'unit': 'cup',
#    'ingredient_name': 'bell pepper',
#    'matched_ingredient': 'Pepper',
#    'kg_equivalent': 0.0603300003075,
#    'carbon_per_kg': 0.455,
#    'ingredient_carbon': 0.0274501501399125},
#   {'ingredient_number': 32,
#    'original_string': '1/2 large bell pepper (green, red, or yellow), stem and core removed, diced, about 3/4 cup',
#    'amount': '0.5',
#    'unit': 'cup',
#    'ingredient_name': 'bell pepper',
#    'matched_ingredient': 'Pepper',
#    'kg_equivalent': 0.0603300003075,
#    'carbon_per_kg': 0.455,
#    'ingredient_carbon': 0.0274501501399125}],
#  'instructions': [{'number': 1,
#    'instruction': '1 Put a large pot of salted water (1 Tbsp salt for every 2 quarts of water) on the stovetop on high heat. It can take a while for a large pot of water to come to a boil (this will be your pasta water), so prepare the sauce in the next steps while the water is heating.2In a large skillet heat 2 teaspoonsof olive oil on medium high heat.'},
#   {'number': 2,
#    'instruction': 'Add the ground beef and cook it until it is lightly browned on all sides.'},
#   {'number': 3,
#    'instruction': "Remove the beef with a slotted spoon to a bowl.If there is more than a tablespoon of fat left in the pan (there shouldn't be if you are using lean ground beef) remove it from the pan. 3"},
#   {'number': 4,
#    'instruction': 'Add the diced bell pepper and onions to skillet (in the photo we are using yellow bell pepper and red onions). Cook for 4 to 5 minutes, until the onions are translucent and the peppers softened.'},
#   {'number': 5,
#    'instruction': 'Add the minced garlic and cook half a minute more. Return the browned ground beef to the pan. Stir to combine, reduce the heat to low and cook for another 5 minutes. 4'},
#   {'number': 6,
#    'instruction': 'Transfer the beef pepper onion mixture to a medium sized (3 to 4 quart) pot.'},
#   {'number': 7,
#    'instruction': 'Add the crushed tomatoes, tomato sauce, and tomato paste to the pot.'},
#   {'number': 8,
#    'instruction': 'Add the parsley, oregano, and Italian seasonings, adjusting the amounts to taste.'},
#   {'number': 9,
#    'instruction': 'Sprinkle with garlic powder and/or garlic salt, to taste.'},
#   {'number': 10,
#    'instruction': 'Sprinkle with red or white wine vinegar. Stir in sugar, a tablespoon at a time, tasting after each addition, to taste. (The amount of sugar needed will vary, depending on how acidic the tomatoes are that you are using.)'},
#   {'number': 11,
#    'instruction': 'Add salt to taste, and note that you will later be adding Parmesan, which is salty.Bring the sauce to a simmer and lower the heat to low to maintain a low simmer. Cook for 15-45 minutes, stirring often. Scrape the bottom of the pot every so often so nothing sticks to the bottom and scorches.'},
#   {'number': 12,
#    'instruction': 'Remove from heat. 5By now the salted water you started heating in step one should be boiling.'},
#   {'number': 13,
#    'instruction': 'Add the dry lasagna noodles and cook then per package directions (al dente). (Note noodles may be cooked in advance.) Stir often to prevent from sticking. Make sure that water remains at a full rolling boil during the entire cooking to prevent noodles from sticking. When ready, drain in a colander and rinse with cool water, gently separating any noodles that may be sticking together.'},
#   {'number': 14,
#    'instruction': 'Spread a little olive oil on a large rimmed baking sheet, and lay out the cooked noodles on this sheet, turning them over so that they get coated with a little of the olive oil. This will prevent them from sticking together.   6 In a 13x9x2-inch casserole or lasagna dish, ladle acup of sauce and spread it overthe bottom of the dish. Arrangeone layer of lasagna noodles lengthwise (about 3 long noodles, edge may overlap, depending on your pan) over the sauce. Ladle a third of the remaining sauce over the noodles.'},
#   {'number': 15,
#    'instruction': 'Sprinklea layer of a third of the grated mozzarella on top of lasagna sauce.'},
#   {'number': 16,
#    'instruction': 'Add half of the ricotta cheese, by placing cheese dollops every coupleinches.'},
#   {'number': 17,
#    'instruction': 'Sprinkle the grated parmesan cheese evenly over thetop of ricotta cheese. Apply second layer of noodles, top it with half of the remaining sauce.'},
#   {'number': 18,
#    'instruction': 'Add half of the remaining Mozzarella, the remaining ricotta cheese, and another thin sprinkling of Parmesan. Finish with another layer of noodles.'},
#   {'number': 19,
#    'instruction': 'Spread the remaining sauce over the top layer of noodles and sprinkle with the remaining Mozzarella cheese.7 Tent the lasagna pan with aluminum foil (not touching noodles or sauce).'},
#   {'number': 20,
#    'instruction': 'Bake at 375F for 45 minutes. Allow to cool before serving.May be reheated in conventional oven or microwave. Leave aluminum tent on for storage. (Try to keep the aluminum foil from touching the sauce.)'}]}

# %% [markdown]
# # Extract KB items

# %%
with open(KB_PATH, 'r', encoding='utf-8') as file:
    KB = json.load(file)

print(f'Read {len(KB)} items in KB.')
# Out:
# Read 664 items in KB.

# %%
KB
# Out:
# [{'ingredient': 'Apple',
#   'foodon_ids': ['FOODON_00002473'],
#   'alternate_names': ['apple (whole)', 'apple'],
#   'foodon_foodex2_id': 'FOODON_03541473'},
#  {'ingredient': 'Apple juice',
#   'foodon_ids': ['FOODON_00001059'],
#   'alternate_names': ['apple juice'],
#   'foodon_foodex2_id': 'FOODON_03543171'},
#  {'ingredient': 'Apple sauce',
#   'foodon_ids': ['FOODON_03301126'],
#   'alternate_names': ['applesauce'],
#   'foodon_foodex2_id': 'FOODON_03544148'},
#  {'ingredient': 'Cider',
#   'foodon_ids': ['FOODON_00001276'],
#   'alternate_names': ['apple cider (alcoholic)', 'cider'],
#   'foodon_foodex2_id': 'FOODON_03543357'},
#  {'ingredient': 'Pear',
#   'foodon_ids': ['FOODON_03301724'],
#   'alternate_names': ['pear (whole, raw)', 'pear'],
#   'foodon_foodex2_id': 'FOODON_03541477'},
#  {'ingredient': 'Capers',
#   'foodon_ids': ['FOODON_00001681', 'FOODON_00003493'],
#   'alternate_names': ['caper food product',
#    'caper',
#    'capers',
#    'caper (whole)',
#    'Flinders rose',
#    'caper bush'],
#   'foodon_foodex2_id': 'FOODON_03541329'},
#  {'ingredient': 'Laverbread',
#   'foodon_ids': ['NCBITaxon_2786'],
#   'alternate_names': ['Porphyra umbilicalis'],
#   'foodon_foodex2_id': 'FOODON_03540766'},
#  {'ingredient': 'Nori',
#   'foodon_ids': ['FOODON_03315448'],
#   'alternate_names': ['nori'],
#   'foodon_foodex2_id': 'FOODON_03540766'},
#  {'ingredient': 'Salsify',
#   'foodon_ids': ['NCBITaxon_114289'],
#   'alternate_names': ['Scorzonera hispanica ',
#    'black oysterplant',
#    'spanish salsify',
#    "common viper's-grass",
#    'black salsify',
#    'scorzonera hispanica'],
#   'foodon_foodex2_id': 'FOODON_03540406'},
#  {'ingredient': 'Seaweed',
#   'foodon_ids': ['FOODON_03412266'],
#   'alternate_names': ['seaweed', 'macroalgae'],
#   'foodon_foodex2_id': 'FOODON_03540759'},
#  {'ingredient': 'Banana',
#   'foodon_ids': ['FOODON_03316257'],
#   'alternate_names': ['banana (whole)', 'banana'],
#   'foodon_foodex2_id': 'FOODON_03541736'},
#  {'ingredient': 'Matoki',
#   'foodon_ids': ['NCBITaxon_4641'],
#   'alternate_names': ['Musa acuminata',
#    'dwarf banana',
#    'dessert bananas',
#    'sweet banana'],
#   'foodon_foodex2_id': 'FOODON_03541737'},
#  {'ingredient': 'Plantain',
#   'foodon_ids': ['FOODON_03310126'],
#   'alternate_names': ['plantain (whole, raw)', 'plantain'],
#   'foodon_foodex2_id': 'FOODON_03541741'},
#  {'ingredient': 'Ale',
#   'foodon_ids': ['FOODON_03302111'],
#   'alternate_names': ['ale'],
#   'foodon_foodex2_id': 'FOODON_03543338'},
#  {'ingredient': 'Beer',
#   'foodon_ids': ['FOODON_00001260'],
#   'alternate_names': ['beer beverage'],
#   'foodon_foodex2_id': 'FOODON_03543332'},
#  {'ingredient': 'Lager',
#   'foodon_ids': ['FOODON_00001260'],
#   'alternate_names': [],
#   'foodon_foodex2_id': 'FOODON_03543333'},
#  {'ingredient': 'Nutritional yeast',
#   'foodon_ids': ['FOODON_03401307'],
#   'alternate_names': ['yeast supplement'],
#   'foodon_foodex2_id': 'FOODON_03543823'},
#  {'ingredient': 'Stout',
#   'foodon_ids': ['FOODON_03315635'],
#   'alternate_names': ['stout (fish, food product)'],
#   'foodon_foodex2_id': 'FOODON_03543341'},
#  {'ingredient': 'Yeast',
#   'foodon_ids': ['FOODON_03411345'],
#   'alternate_names': ['yeast'],
#   'foodon_foodex2_id': 'FOODON_03544455'},
#  {'ingredient': 'Yeast extract',
#   'foodon_ids': ['FOODON_03315426'],
#   'alternate_names': ['yeast extract'],
#   'foodon_foodex2_id': 'FOODON_03544084'},
#  {'ingredient': 'Barbeque sauce',
#   'foodon_ids': ['FOODON_03302062'],
#   'alternate_names': ['barbeque sauce'],
#   'foodon_foodex2_id': 'FOODON_03544196'},
#  {'ingredient': 'Caster sugar',
#   'foodon_ids': ['FOODON_03316271'],
#   'alternate_names': ['sugar product'],
#   'foodon_foodex2_id': 'FOODON_03542985'},
#  {'ingredient': 'Chutney',
#   'foodon_ids': ['FOODON_03317544'],
#   'alternate_names': ['chutney'],
#   'foodon_foodex2_id': 'FOODON_03544133'},
#  {'ingredient': 'Club soda',
#   'foodon_ids': ['FOODON_03304065'],
#   'alternate_names': ['club soda'],
#   'foodon_foodex2_id': 'FOODON_03543271'},
#  {'ingredient': 'Cola',
#   'foodon_ids': ['FOODON_03302254'],
#   'alternate_names': ['cola carbonated beverage (artificially sweetened)'],
#   'foodon_foodex2_id': 'FOODON_03543317'},
#  {'ingredient': 'Golden syrup',
#   'foodon_ids': ['FOODON_03307582'],
#   'alternate_names': ['treacle'],
#   'foodon_foodex2_id': 'FOODON_03543010'},
#  {'ingredient': 'Granulated sugar',
#   'foodon_ids': ['FOODON_03301073'],
#   'alternate_names': ['sugar (granulated)'],
#   'foodon_foodex2_id': 'FOODON_03542985'},
#  {'ingredient': 'Icing',
#   'foodon_ids': ['FOODON_03301932'],
#   'alternate_names': ['icing (food product)'],
#   'foodon_foodex2_id': 'FOODON_03542993'},
#  {'ingredient': 'Icing sugar',
#   'foodon_ids': ['FOODON_03301932'],
#   'alternate_names': [],
#   'foodon_foodex2_id': 'FOODON_03542993'},
#  {'ingredient': 'Marshmallow',
#   'foodon_ids': ['FOODON_03305639'],
#   'alternate_names': ['marshmallow'],
#   'foodon_foodex2_id': 'FOODON_03543051'},
#  {'ingredient': 'Sugar',
#   'foodon_ids': ['FOODON_03420108'],
#   'alternate_names': ['sugar'],
#   'foodon_foodex2_id': 'FOODON_03542984'},
#  {'ingredient': 'Amla',
#   'foodon_ids': ['NCBITaxon_296036'],
#   'alternate_names': ['Phyllanthus emblica',
#    'emblic',
#    'amla',
#    'Indian gooseberry'],
#   'foodon_foodex2_id': 'FOODON_03541609'},
#  {'ingredient': 'Blackberries',
#   'foodon_ids': ['FOODON_00003487'],
#   'alternate_names': ['blackberry (whole)'],
#   'foodon_foodex2_id': 'FOODON_03541543'},
#  {'ingredient': 'Blackcurrant',
#   'foodon_ids': ['FOODON_03311604'],
#   'alternate_names': ['black currant (whole, raw)',
#    'black currant',
#    'blackcurrant'],
#   'foodon_foodex2_id': 'FOODON_03541608'},
#  {'ingredient': 'Blueberries',
#   'foodon_ids': ['FOODON_00003541'],
#   'alternate_names': ['blueberry (whole)'],
#   'foodon_foodex2_id': 'FOODON_03541564'},
#  {'ingredient': 'Cherry',
#   'foodon_ids': ['FOODON_03301240'],
#   'alternate_names': ['cherry (whole, raw)', 'cherry'],
#   'foodon_foodex2_id': 'FOODON_03541495'},
#  {'ingredient': 'Cranberries',
#   'foodon_ids': ['FOODON_03301723'],
#   'alternate_names': ['cranberry (whole, raw)'],
#   'foodon_foodex2_id': 'FOODON_03541595'},
#  {'ingredient': 'Cranberry sauce',
#   'foodon_ids': ['FOODON_03301244'],
#   'alternate_names': ['cranberry sauce'],
#   'foodon_foodex2_id': 'FOODON_03541874'},
#  {'ingredient': 'Currant',
#   'foodon_ids': ['FOODON_03303397'],
#   'alternate_names': ['currant food product', 'currant'],
#   'foodon_foodex2_id': 'FOODON_03541605'},
#  {'ingredient': 'Damson',
#   'foodon_ids': ['FOODON_03305782'],
#   'alternate_names': ['damson plum jam'],
#   'foodon_foodex2_id': 'FOODON_03541517'},
#  {'ingredient': 'Date',
#   'foodon_ids': ['FOODON_03304506'],
#   'alternate_names': ['date (whole, raw)', 'date'],
#   'foodon_foodex2_id': 'FOODON_03541642'},
#  {'ingredient': 'Elderberries',
#   'foodon_ids': ['FOODON_03311347'],
#   'alternate_names': ['elderberry (whole, raw)'],
#   'foodon_foodex2_id': 'FOODON_03541623'},
#  {'ingredient': 'Gooseberries',
#   'foodon_ids': ['FOODON_00001914'],
#   'alternate_names': ['gooseberry food product', 'gooseberry'],
#   'foodon_foodex2_id': 'FOODON_03541610'},
#  {'ingredient': 'Grape',
#   'foodon_ids': ['FOODON_03301123'],
#   'alternate_names': ['grape (whole, raw)', 'grape'],
#   'foodon_foodex2_id': 'FOODON_03541528'},
#  {'ingredient': 'Grape leaves',
#   'foodon_ids': ['FOODON_03540454'],
#   'alternate_names': ['grape leaves'],
#   'foodon_foodex2_id': 'FOODON_03540454'},
#  {'ingredient': 'Greengage',
#   'foodon_ids': ['FOODON_03306393'],
#   'alternate_names': ['greengage preserves'],
#   'foodon_foodex2_id': 'FOODON_03541518'},
#  {'ingredient': 'Jam',
#   'foodon_ids': ['FOODON_03309973'],
#   'alternate_names': ['jam'],
#   'foodon_foodex2_id': 'FOODON_03541805'},
#  {'ingredient': 'Loganberries',
#   'foodon_ids': ['FOODON_03302049'],
#   'alternate_names': ['loganberry (whole, raw)'],
#   'foodon_foodex2_id': 'FOODON_03541547'},
#  {'ingredient': 'Mixed fruit',
#   'foodon_ids': ['FOODON_03307162'],
#   'alternate_names': ['mixed fruit preserves'],
#   'foodon_foodex2_id': 'FOODON_03541856'},
#  {'ingredient': 'Mulberries',
#   'foodon_ids': ['FOODON_00003135'],
#   'alternate_names': ['mulberry (whole, raw)', 'mulberry'],
#   'foodon_foodex2_id': 'FOODON_03541617'},
#  {'ingredient': 'Physalis',
#   'foodon_ids': ['NCBITaxon_24663'],
#   'alternate_names': ['Physalis'],
#   'foodon_foodex2_id': 'FOODON_03540640'},
#  {'ingredient': 'Pimento',
#   'foodon_ids': ['FOODON_00003484'],
#   'alternate_names': ['pimiento (whole)', 'pimento', 'cherry pepper'],
#   'foodon_foodex2_id': 'FOODON_03540650'},
#  {'ingredient': 'Raisin',
#   'foodon_ids': ['FOODON_03301283'],
#   'alternate_names': ['raisin (whole)', 'raisin'],
#   'foodon_foodex2_id': 'FOODON_03541798'},
#  {'ingredient': 'Raspberries',
#   'foodon_ids': ['FOODON_03307119'],
#   'alternate_names': ['raspberry (whole, raw)', 'raspberry'],
#   'foodon_foodex2_id': 'FOODON_03541554'},
#  {'ingredient': 'Redcurrant jelly',
#   'foodon_ids': ['FOODON_00002192'],
#   'alternate_names': ['red currant preserve or jam'],
#   'foodon_foodex2_id': 'FOODON_03541828'},
#  {'ingredient': 'Redcurrants',
#   'foodon_ids': ['FOODON_00003008'],
#   'alternate_names': ['red currant (whole, raw)', 'redcurrant', 'red currant'],
#   'foodon_foodex2_id': 'FOODON_03541607'},
#  {'ingredient': 'Strawberries',
#   'foodon_ids': ['FOODON_03301722'],
#   'alternate_names': ['strawberry (whole, raw)', 'strawberry'],
#   'foodon_foodex2_id': 'FOODON_03541538'},
#  {'ingredient': 'Sultanas',
#   'foodon_ids': ['FOODON_03305819'],
#   'alternate_names': ['sultana raisin (whole, dried)'],
#   'foodon_foodex2_id': 'FOODON_03541528'},
#  {'ingredient': 'Whitecurrant',
#   'foodon_ids': ['FOODON_03412752'],
#   'alternate_names': ['white currant plant'],
#   'foodon_foodex2_id': 'FOODON_03541606'},
#  {'ingredient': 'Beef',
#   'foodon_ids': ['FOODON_00001041'],
#   'alternate_names': ['beef food product'],
#   'foodon_foodex2_id': 'FOODON_03541916'},
#  {'ingredient': 'Dripping',
#   'foodon_ids': ['FOODON_03315430'],
#   'alternate_names': ['dripping from food', 'Beef Dripping'],
#   'foodon_foodex2_id': 'FOODON_03543122'},
#  {'ingredient': 'Oxtail',
#   'foodon_ids': ['FOODON_00003251'],
#   'alternate_names': ['ox'],
#   'foodon_foodex2_id': 'FOODON_03542079'},
#  {'ingredient': 'Pastrami',
#   'foodon_ids': ['FOODON_00003884'],
#   'alternate_names': ['pastrami'],
#   'foodon_foodex2_id': 'FOODON_03542121'},
#  {'ingredient': 'Suet',
#   'foodon_ids': ['FOODON_03305811'],
#   'alternate_names': ['suet (raw)'],
#   'foodon_foodex2_id': 'FOODON_03541989'},
#  {'ingredient': 'Sweetbread',
#   'foodon_ids': ['FOODON_00003155'],
#   'alternate_names': ['sweatbread food product'],
#   'foodon_foodex2_id': 'FOODON_03542054'},
#  {'ingredient': 'Tongue',
#   'foodon_ids': ['FOODON_03315582'],
#   'alternate_names': ['tongue food product'],
#   'foodon_foodex2_id': 'FOODON_03542075'},
#  {'ingredient': 'Tripe',
#   'foodon_ids': ['FOODON_03420192'],
#   'alternate_names': ['tripe'],
#   'foodon_foodex2_id': 'FOODON_03542077'},
#  {'ingredient': 'Veal',
#   'foodon_ids': ['FOODON_00001678'],
#   'alternate_names': ['calf meat food product', 'veal'],
#   'foodon_foodex2_id': 'FOODON_03541917'},
#  {'ingredient': 'Beef extract',
#   'foodon_ids': ['FOODON_03302088'],
#   'alternate_names': ['beef extract'],
#   'foodon_foodex2_id': 'FOODON_03544199'},
#  {'ingredient': 'Beef stock',
#   'foodon_ids': ['FOODON_03304945'],
#   'alternate_names': ['beef stock base (meatless)'],
#   'foodon_foodex2_id': 'FOODON_03544075'},
#  {'ingredient': 'Beef stock cube',
#   'foodon_ids': ['FOODON_03301432'],
#   'alternate_names': ['beef bouillon cube'],
#   'foodon_foodex2_id': 'FOODON_03544075'},
#  {'ingredient': 'Amaranth',
#   'foodon_ids': ['FOODON_00001167'],
#   'alternate_names': ['amaranthaceous food product'],
#   'foodon_foodex2_id': 'FOODON_03540010'},
#  {'ingredient': 'Arugula',
#   'foodon_ids': ['FOODON_00002426'],
#   'alternate_names': ['arugula greens (raw)',
#    'rocket lettuce',
#    'arugula greens',
#    'arugula',
#    'rucola',
#    'colewort',
#    'rocket',
#    'rocket salad',
#    'rucoli',
#    'roquette',
#    'rugula'],
#   'foodon_foodex2_id': 'FOODON_03540382'},
#  {'ingredient': 'Asparagus',
#   'foodon_ids': ['FOODON_03311349'],
#   'alternate_names': ['asparagus spear (whole, raw)', 'asparagus'],
#   'foodon_foodex2_id': 'FOODON_03540539'},
#  {'ingredient': 'Basil',
#   'foodon_ids': ['FOODON_00003044'],
#   'alternate_names': ['basil food product', 'basil'],
#   'foodon_foodex2_id': 'FOODON_03540878'},
#  {'ingredient': 'Bay leaf',
#   'foodon_ids': ['FOODON_03301173'],
#   'alternate_names': ['bay leaf (whole, dried)'],
#   'foodon_foodex2_id': 'FOODON_03541264'},
#  {'ingredient': 'Beetroot',
#   'foodon_ids': ['FOODON_03317254'],
#   'alternate_names': ['beetroot (whole)', 'beet', 'beetroot'],
#   'foodon_foodex2_id': 'FOODON_03540710'},
#  {'ingredient': 'Bele',
#   'foodon_ids': ['NCBITaxon_183220'],
#   'alternate_names': ['Abelmoschus manihot',
#    'mbele',
#    'aibika',
#    'sunset hibiscus'],
#   'foodon_foodex2_id': 'FOODON_03540480'},
#  {'ingredient': 'Broccoli',
#   'foodon_ids': ['FOODON_03301713'],
#   'alternate_names': ['broccoli floret (whole, raw)', 'broccoli'],
#   'foodon_foodex2_id': 'FOODON_03540525'},
#  {'ingredient': 'Brussels Sprouts',
#   'foodon_ids': ['FOODON_03311885'],
#   'alternate_names': ['brussels sprout (whole)', 'brussels sprouts'],
#   'foodon_foodex2_id': 'FOODON_03540472'},
#  {'ingredient': 'Cabbage',
#   'foodon_ids': ['FOODON_03301326'],
#   'alternate_names': ['cabbage head (raw)', 'cabbage'],
#   'foodon_foodex2_id': 'FOODON_03540474'},
#  {'ingredient': 'Cauliflower',
#   'foodon_ids': ['FOODON_03302732'],
#   'alternate_names': ['cauliflower (whole, raw)', 'cauliflower'],
#   'foodon_foodex2_id': 'FOODON_03540531'},
#  {'ingredient': 'Cauliflower rice',
#   'foodon_ids': ['FOODON_00001703'],
#   'alternate_names': ['cauliflower food product'],
#   'foodon_foodex2_id': 'FOODON_03540531'},
#  {'ingredient': 'Chard',
#   'foodon_ids': ['FOODON_03306698'],
#   'alternate_names': ['swiss chard leaf (whole, raw)', 'swiss chard', 'chard'],
#   'foodon_foodex2_id': 'FOODON_03540446'},
#  {'ingredient': 'Chervil',
#   'foodon_ids': ['FOODON_03411444'],
#   'alternate_names': ['chervil plant'],
#   'foodon_foodex2_id': 'FOODON_03540827'},
#  {'ingredient': 'Chicory',
#   'foodon_ids': ['FOODON_00001730'],
#   'alternate_names': ['chicory food product'],
#   'foodon_foodex2_id': 'FOODON_03543421'},
#  {'ingredient': 'Coriander',
#   'foodon_ids': ['FOODON_03310370'],
#   'alternate_names': ['coriander (whole)'],
#   'foodon_foodex2_id': 'FOODON_03540837'},
#  {'ingredient': 'Dill',
#   'foodon_ids': ['FOODON_00001811'],
#   'alternate_names': ['dill food product', 'dill'],
#   'foodon_foodex2_id': 'FOODON_03540839'},
#  {'ingredient': 'Dried basil',
#   'foodon_ids': ['FOODON_00003044'],
#   'alternate_names': [],
#   'foodon_foodex2_id': 'FOODON_03541263'},
#  {'ingredient': 'Dried coriander',
#   'foodon_ids': ['FOODON_03310370'],
#   'alternate_names': [],
#   'foodon_foodex2_id': 'FOODON_03540837'},
#  {'ingredient': 'Endive',
#   'foodon_ids': ['FOODON_00002439'],
#   'alternate_names': ['endive'],
#   'foodon_foodex2_id': 'FOODON_03540373'},
#  {'ingredient': 'Globe artichoke',
#   'foodon_ids': ['FOODON_03301369'],
#   'alternate_names': ['globe artichoke (raw)'],
#   'foodon_foodex2_id': 'FOODON_03540549'},
#  {'ingredient': 'Kale',
#   'foodon_ids': ['FOODON_03304859'],
#   'alternate_names': ['kale leaf (whole, raw)', 'kale'],
#   'foodon_foodex2_id': 'FOODON_03540489'},
#  {'ingredient': 'Kimchi',
#   'foodon_ids': ['FOODON_00002946'],
#   'alternate_names': ['kimchi', 'kimchee'],
#   'foodon_foodex2_id': 'FOODON_03540482'},
#  {'ingredient': 'Lettuce',
#   'foodon_ids': ['FOODON_00001998'],
#   'alternate_names': ['lettuce head food product', 'lettuce'],
#   'foodon_foodex2_id': 'FOODON_03540365'},
#  {'ingredient': 'Mache',
#   'foodon_ids': ['NCBITaxon_59166'],
#   'alternate_names': ['Valerianella locusta',
#    'European cornsalad',
#    "lamb's lettuce"],
#   'foodon_foodex2_id': 'FOODON_03540362'},
#  {'ingredient': 'Marjoram',
#   'foodon_ids': ['FOODON_00002023'],
#   'alternate_names': ['marjoram food product', 'marjoram'],
#   'foodon_foodex2_id': 'FOODON_03540871'},
#  {'ingredient': 'Mint',
#   'foodon_ids': ['FOODON_00002432'],
#   'alternate_names': ['mint food product', 'mint'],
#   'foodon_foodex2_id': 'FOODON_03540879'},
#  {'ingredient': 'Mustard',
#   'foodon_ids': ['FOODON_00002052'],
#   'alternate_names': ['mustard condiment food product'],
#   'foodon_foodex2_id': 'FOODON_03541197'},
#  {'ingredient': 'Oregano',
#   'foodon_ids': ['FOODON_03301482'],
#   'alternate_names': ['oregano (ground)', 'oregano'],
#   'foodon_foodex2_id': 'FOODON_03540873'},
#  {'ingredient': 'Pak choi',
#   'foodon_ids': ['FOODON_03412077'],
#   'alternate_names': ['bok choy plant',
#    'brassica chinensis',
#    'brassica rapa var. chinensis',
#    'pok choi',
#    'pak choi'],
#   'foodon_foodex2_id': 'FOODON_03540487'},
#  {'ingredient': 'Parsley',
#   'foodon_ids': ['FOODON_00002942'],
#   'alternate_names': ['parsley leaf (whole)', 'parsley'],
#   'foodon_foodex2_id': 'FOODON_03540853'},
#  {'ingredient': 'Peppermint',
#   'foodon_ids': ['FOODON_03303920'],
#   'alternate_names': ['peppermint'],
#   'foodon_foodex2_id': 'FOODON_03540885'},
#  {'ingredient': 'Pesto',
#   'foodon_ids': ['FOODON_03310218'],
#   'alternate_names': ['pesto sauce'],
#   'foodon_foodex2_id': 'FOODON_03544123'},
#  {'ingredient': 'Raddiccio',
#   'foodon_ids': ['NCBITaxon_13427'],
#   'alternate_names': ['Cichorium intybus',
#    'chicory',
#    'succory',
#    'radicchio',
#    'witloof'],
#   'foodon_foodex2_id': 'FOODON_03540376'},
#  {'ingredient': 'Rape leaves',
#   'foodon_ids': ['FOODON_03411248'],
#   'alternate_names': ['rapeseed plant', 'brassica napus', 'rape plant'],
#   'foodon_foodex2_id': 'FOODON_03540394'},
#  {'ingredient': 'Rocket',
#   'foodon_ids': ['FOODON_00002426'],
#   'alternate_names': [],
#   'foodon_foodex2_id': 'FOODON_03540383'},
#  {'ingredient': 'Rosemary',
#   'foodon_ids': ['FOODON_00002212'],
#   'alternate_names': ['rosemary food product', 'rosemary'],
#   'foodon_foodex2_id': 'FOODON_03540863'},
#  {'ingredient': 'Sage',
#   'foodon_ids': ['FOODON_00002217'],
#   'alternate_names': ['sage food product', 'sage'],
#   'foodon_foodex2_id': 'FOODON_03540856'},
#  {'ingredient': 'Salad',
#   'foodon_ids': ['FOODON_03316042'],
#   'alternate_names': ['salad'],
#   'foodon_foodex2_id': 'FOODON_03544020'},
#  {'ingredient': 'Sauerkraut',
#   'foodon_ids': ['FOODON_03301397'],
#   'alternate_names': ['sauerkraut'],
#   'foodon_foodex2_id': 'FOODON_03540942'},
#  {'ingredient': 'Spinach',
#   'foodon_ids': ['FOODON_03301716'],
#   'alternate_names': ['spinach leaf (whole, raw)', 'spinach'],
#   'foodon_foodex2_id': 'FOODON_03540421'},
#  {'ingredient': 'Spring green',
#   'foodon_ids': ['FOODON_03411566'],
#   'alternate_names': ['leafy vegetable plant', 'leafy green'],
#   'foodon_foodex2_id': 'FOODON_03540359'},
#  {'ingredient': 'Tarragon',
#   'foodon_ids': ['FOODON_00003036'],
#   'alternate_names': ['tarragon leaf (whole, fresh)', 'tarragon'],
#   'foodon_foodex2_id': 'FOODON_03540907'},
#  {'ingredient': 'Thyme',
#   'foodon_ids': ['FOODON_00002312'],
#   'alternate_names': ['thyme food product', 'thyme'],
#   'foodon_foodex2_id': 'FOODON_03540866'},
#  {'ingredient': 'Turnip',
#   'foodon_ids': ['FOODON_03307633'],
#   'alternate_names': ['turnip (whole, raw)', 'turnip'],
#   'foodon_foodex2_id': 'FOODON_03540752'},
#  {'ingredient': 'Watercress',
#   'foodon_ids': ['FOODON_00003064'],
#   'alternate_names': ['watercress'],
#   'foodon_foodex2_id': 'FOODON_03540458'},
#  {'ingredient': 'Buffalo',
#   'foodon_ids': ['FOODON_03411476'],
#   'alternate_names': ['buffalo'],
#   'foodon_foodex2_id': 'FOODON_03541918'},
#  {'ingredient': 'Butter',
#   'foodon_ids': ['FOODON_03310351'],
#   'alternate_names': ['butter'],
#   'foodon_foodex2_id': 'FOODON_03543148'},
#  {'ingredient': 'Cream',
#   'foodon_ids': ['FOODON_03305284'],
#   'alternate_names': ['cream (sterilized)'],
#   'foodon_foodex2_id': 'FOODON_03542681'},
#  {'ingredient': 'Crème fraiche',
#   'foodon_ids': ['FOODON_03317381'],
#   'alternate_names': ['cream (pasteurized, fresh)'],
#   'foodon_foodex2_id': 'FOODON_03542717'},
#  {'ingredient': 'Double cream',
#   'foodon_ids': ['FOODON_03310795'],
#   'alternate_names': ['heavy cream'],
#   'foodon_foodex2_id': 'FOODON_03542680'},
#  {'ingredient': 'Ghee',
#   'foodon_ids': ['FOODON_03310185'],
#   'alternate_names': ['ghee'],
#   'foodon_foodex2_id': 'FOODON_03543141'},
#  {'ingredient': 'Greek Yogurt',
#   'foodon_ids': ['FOODON_00003258'],
#   'alternate_names': ['sack yoghurt', 'Greek yogurt', 'yogurt cheese'],
#   'foodon_foodex2_id': 'FOODON_03542703'},
#  {'ingredient': 'Mushroom sauce',
#   'foodon_ids': ['FOODON_03302590'],
#   'alternate_names': ['mushroom sauce'],
#   'foodon_foodex2_id': 'FOODON_03544131'},
#  {'ingredient': 'Natural Yogurt',
#   'foodon_ids': ['FOODON_03301502'],
#   'alternate_names': ['yogurt (plain)'],
#   'foodon_foodex2_id': 'FOODON_03542701'},
#  {'ingredient': 'Single cream',
#   'foodon_ids': ['FOODON_03305284'],
#   'alternate_names': [],
#   'foodon_foodex2_id': 'FOODON_03542680'},
#  {'ingredient': 'Soured cream',
#   'foodon_ids': ['FOODON_03302515'],
#   'alternate_names': ['sour cream'],
#   'foodon_foodex2_id': 'FOODON_03542716'},
#  {'ingredient': 'Yogurt',
#   'foodon_ids': ['FOODON_00001014'],
#   'alternate_names': ['yogurt food product'],
#   'foodon_foodex2_id': 'FOODON_03542693'},
#  {'ingredient': 'Brown sugar',
#   'foodon_ids': ['FOODON_03420156'],
#   'alternate_names': ['brown sugar'],
#   'foodon_foodex2_id': 'FOODON_03542988'},
#  {'ingredient': 'Demerara sugar',
#   'foodon_ids': ['FOODON_00002847'],
#   'alternate_names': ['demerara sugar'],
#   'foodon_foodex2_id': 'FOODON_03542990'},
#  {'ingredient': 'Jaggery',
#   'foodon_ids': ['FOODON_00002291'],
#   'alternate_names': ['sugar cane food product'],
#   'foodon_foodex2_id': 'FOODON_03543004'},
#  {'ingredient': 'Molasses',
#   'foodon_ids': ['CHEBI_83163'],
#   'alternate_names': ['molasses'],
#   'foodon_foodex2_id': 'FOODON_03543001'},
#  {'ingredient': 'Palm sugar',
#   'foodon_ids': ['FOODON_03304565'],
#   'alternate_names': ['palm sugar'],
#   'foodon_foodex2_id': 'FOODON_03542991'},
#  {'ingredient': 'Syrup',
#   'foodon_ids': ['FOODON_03303225'],
#   'alternate_names': ['syrup'],
#   'foodon_foodex2_id': 'FOODON_03543006'},
#  {'ingredient': 'Treacle',
#   'foodon_ids': ['FOODON_03307582'],
#   'alternate_names': [],
#   'foodon_foodex2_id': 'FOODON_03543010'},
#  {'ingredient': 'Cassava',
#   'foodon_ids': ['FOODON_03302304'],
#   'alternate_names': ['cassava (whole, raw)', 'cassava'],
#   'foodon_foodex2_id': 'FOODON_03540966'},
#  {'ingredient': 'Cassava flour',
#   'foodon_ids': ['FOODON_03310125'],
#   'alternate_names': ['cassava flour'],
#   'foodon_foodex2_id': 'FOODON_03540966'},
#  {'ingredient': 'Gari flour',
#   'foodon_ids': ['FOODON_03310125'],
#   'alternate_names': [],
#   'foodon_foodex2_id': 'FOODON_03540966'},
#  {'ingredient': 'Sago',
#   'foodon_ids': ['FOODON_03310136'],
#   'alternate_names': ['sago'],
#   'foodon_foodex2_id': 'FOODON_03544162'},
#  {'ingredient': 'Blue Cheese',
#   'foodon_ids': ['FOODON_03316725'],
#   'alternate_names': ['blue-veined cheese'],
#   'foodon_foodex2_id': 'FOODON_03542908'},
#  {'ingredient': 'Brie',
#   'foodon_ids': ['FOODON_03303508'],
#   'alternate_names': ['brie cheese'],
#   'foodon_foodex2_id': 'FOODON_03542770'},
#  {'ingredient': 'Caerphilly',
#   'foodon_ids': ['FOODON_03302979'],
#   'alternate_names': ['caerphilly cheese'],
#   'foodon_foodex2_id': 'FOODON_03542803'},
#  {'ingredient': 'Camembert',
#   'foodon_ids': ['FOODON_03302995'],
#   'alternate_names': ['camembert cheese'],
#   'foodon_foodex2_id': 'FOODON_03542771'},
#  {'ingredient': 'Cheddar',
#   'foodon_ids': ['FOODON_03302458'],
#   'alternate_names': ['cheddar cheese'],
#   'foodon_foodex2_id': 'FOODON_03542872'},
#  {'ingredient': 'Cheese',
#   'foodon_ids': ['FOODON_00001013'],
#   'alternate_names': ['cheese food product'],
#   'foodon_foodex2_id': 'FOODON_03542731'},
#  {'ingredient': 'Cottage cheese',
#   'foodon_ids': ['FOODON_03301605'],
#   'alternate_names': ['cottage cheese'],
#   'foodon_foodex2_id': 'FOODON_03542733'},
#  {'ingredient': 'Cream cheese',
#   'foodon_ids': ['FOODON_03301889'],
#   'alternate_names': ['cream cheese'],
#   'foodon_foodex2_id': 'FOODON_03542750'},
#  {'ingredient': 'Danish blue',
#   'foodon_ids': ['FOODON_03316728'],
#   'alternate_names': ['cheese danablu'],
#   'foodon_foodex2_id': 'FOODON_03542782'},
#  {'ingredient': 'Derby cheese',
#   'foodon_ids': ['FOODON_03303666'],
#   'alternate_names': ['derby cheese'],
#   'foodon_foodex2_id': 'FOODON_03542811'},
#  {'ingredient': 'Dolcelatte',
#   'foodon_ids': ['FOODON_03316725'],
#   'alternate_names': [],
#   'foodon_foodex2_id': 'FOODON_03542780'},
#  {'ingredient': 'Double Gloucester',
#   'foodon_ids': ['FOODON_03303665'],
#   'alternate_names': ['gloucester cheese'],
#   'foodon_foodex2_id': 'FOODON_03542812'},
#  {'ingredient': 'Edam',
#   'foodon_ids': ['FOODON_03302971'],
#   'alternate_names': ['edam cheese'],
#   'foodon_foodex2_id': 'FOODON_03542814'},
#  {'ingredient': 'Emmental',
#   'foodon_ids': ['FOODON_03316148'],
#   'alternate_names': ['semihard cheese'],
#   'foodon_foodex2_id': 'FOODON_03542874'},
#  {'ingredient': 'Feta',
#   'foodon_ids': ['FOODON_03307280'],
#   'alternate_names': ['feta cheese'],
#   'foodon_foodex2_id': 'FOODON_03542753'},
#  {'ingredient': 'Fromage frais',
#   'foodon_ids': ['FOODON_00002252'],
#   'alternate_names': ['soft cheese food product'],
#   'foodon_foodex2_id': 'FOODON_03542736'},
#  {'ingredient': 'Goats cheese',
#   'foodon_ids': ['FOODON_03303655'],
#   'alternate_names': ['goat milk cheese'],
#   'foodon_foodex2_id': 'FOODON_03542744'},
#  {'ingredient': 'Gouda',
#   'foodon_ids': ['FOODON_03303514'],
#   'alternate_names': ['gouda cheese'],
#   'foodon_foodex2_id': 'FOODON_03542818'},
#  {'ingredient': 'Grana Padano',
#   'foodon_ids': ['FOODON_00002920'],
#   'alternate_names': ['grana padano'],
#   'foodon_foodex2_id': 'FOODON_03542899'},
#  {'ingredient': 'Gruyere',
#   'foodon_ids': ['FOODON_03303686'],
#   'alternate_names': ['gruyere cheese'],
#   'foodon_foodex2_id': 'FOODON_03542876'},
#  {'ingredient': 'Halloumi',
#   'foodon_ids': ['FOODON_00001030'],
#   'alternate_names': ['halloumi cheese food product'],
#   'foodon_foodex2_id': 'FOODON_03542754'},
#  {'ingredient': 'Lancashire',
#   'foodon_ids': ['FOODON_03303668'],
#   'alternate_names': ['lancashire cheese'],
#   'foodon_foodex2_id': 'FOODON_03542826'},
#  {'ingredient': 'Mascarpone',
#   'foodon_ids': ['FOODON_00003255'],
#   'alternate_names': ['mascarpone'],
#   'foodon_foodex2_id': 'FOODON_03542734'},
#  {'ingredient': 'Monterey Jack',
#   'foodon_ids': ['FOODON_03311068'],
#   'alternate_names': ['monterey jack cheese made from raw milk'],
#   'foodon_foodex2_id': 'FOODON_03542792'},
#  {'ingredient': 'Mozzarella',
#   'foodon_ids': ['FOODON_03303578'],
#   'alternate_names': ['mozzarella cheese'],
#   'foodon_foodex2_id': 'FOODON_03542735'},
#  {'ingredient': 'Paneer',
#   'foodon_ids': ['FOODON_03315601'],
#   'alternate_names': ['cream cheese (acid coagulated)'],
#   'foodon_foodex2_id': 'FOODON_03542737'},
#  {'ingredient': 'Parmesan',
#   'foodon_ids': ['FOODON_00003247'],
#   'alternate_names': ['parmesan cheese', 'parmesan'],
#   'foodon_foodex2_id': 'FOODON_03542892'},
#  {'ingredient': 'Pecorino',
#   'foodon_ids': ['FOODON_00001295'],
#   'alternate_names': ['pecorino cheese'],
#   'foodon_foodex2_id': 'FOODON_03542902'},
#  {'ingredient': 'Port Salut',
#   'foodon_ids': ['FOODON_03303537'],
#   'alternate_names': ['port salut cheese'],
#   'foodon_foodex2_id': 'FOODON_03542858'},
#  {'ingredient': 'Quark',
#   'foodon_ids': ['FOODON_03310352'],
#   'alternate_names': ['cheese curd'],
#   'foodon_foodex2_id': 'FOODON_03542736'},
#  {'ingredient': 'Red Leicester',
#   'foodon_ids': ['FOODON_03303667'],
#   'alternate_names': ['leicester cheese'],
#   'foodon_foodex2_id': 'FOODON_03542828'},
#  {'ingredient': 'Red Windsor',
#   'foodon_ids': ['FOODON_03302458'],
#   'alternate_names': [],
#   'foodon_foodex2_id': 'FOODON_03542872'},
#  {'ingredient': 'Ricotta',
#   'foodon_ids': ['FOODON_03302908'],
#   'alternate_names': ['ricotta cheese'],
#   'foodon_foodex2_id': 'FOODON_03542738'},
#  {'ingredient': 'Roquefort',
#   'foodon_ids': ['FOODON_00002424'],
#   'alternate_names': ['roquefort cheese', 'roquefort'],
#   'foodon_foodex2_id': 'FOODON_03542916'},
#  {'ingredient': 'Sage Derby',
#   'foodon_ids': ['FOODON_03317582'],
#   'alternate_names': ['sage derby cheese'],
#   'foodon_foodex2_id': 'FOODON_03542811'},
#  {'ingredient': 'Stilton',
#   'foodon_ids': ['FOODON_03303870'],
#   'alternate_names': ['stilton cheese'],
#   'foodon_foodex2_id': 'FOODON_03542918'},
#  {'ingredient': 'Wensleydale',
#   'foodon_ids': ['FOODON_03303669'],
#   'alternate_names': ['wensleydale cheese'],
#   'foodon_foodex2_id': 'FOODON_03542864'},
#  {'ingredient': 'Grapefruit',
#   'foodon_ids': ['FOODON_03301702'],
#   'alternate_names': ['grapefruit (whole, raw)', 'grapefruit'],
#   'foodon_foodex2_id': 'FOODON_03541425'},
#  {'ingredient': 'Lemon',
#   'foodon_ids': ['FOODON_03301441'],
#   'alternate_names': ['lemon (whole, raw)', 'lemon'],
#   'foodon_foodex2_id': 'FOODON_03541446'},
#  {'ingredient': 'Lime',
#   'foodon_ids': ['FOODON_03305086'],
#   'alternate_names': ['lime (whole, raw)', 'lime'],
#   'foodon_foodex2_id': 'FOODON_03541450'},
#  {'ingredient': 'Lime leaves',
#   'foodon_ids': ['FOODON_03411067'],
#   'alternate_names': ['lime (citrus) plant'],
#   'foodon_foodex2_id': 'FOODON_03540903'},
#  {'ingredient': 'Mandarin',
#   'foodon_ids': ['FOODON_00003555'],
#   'alternate_names': ['mandarine (whole)'],
#   'foodon_foodex2_id': 'FOODON_03541456'},
#  {'ingredient': 'Mixed peel',
#   'foodon_ids': ['FOODON_03302021'],
#   'alternate_names': ['candied citrus peel'],
#   'foodon_foodex2_id': 'FOODON_03541845'},
#  {'ingredient': 'Nardicots',
#   'foodon_ids': ['FOODON_03303079'],
#   'alternate_names': ['clementine (whole, raw)', 'clementine'],
#   'foodon_foodex2_id': 'FOODON_03541459'},
#  {'ingredient': 'Orange',
#   'foodon_ids': ['FOODON_03315106'],
#   'alternate_names': ['orange (whole)', 'orange'],
#   'foodon_foodex2_id': 'FOODON_03541435'},
#  {'ingredient': 'Ortaniques',
#   'foodon_ids': ['FOODON_03412468'],
#   'alternate_names': ['king orange plant', 'king mandarin orange', 'tangor'],
#   'foodon_foodex2_id': 'FOODON_03541464'},
#  {'ingredient': 'Coffee',
#   'foodon_ids': ['FOODON_03301036'],
#   'alternate_names': ['coffee (liquid drink)', 'coffee'],
#   'foodon_foodex2_id': 'FOODON_03543404'},
#  {'ingredient': 'Tea',
#   'foodon_ids': ['FOODON_03315081'],
#   'alternate_names': ['tea food product', 'tea'],
#   'foodon_foodex2_id': 'FOODON_03543440'},
#  {'ingredient': 'Cockles',
#   'foodon_ids': ['FOODON_03412113'],
#   'alternate_names': ['bivalve'],
#   'foodon_foodex2_id': 'FOODON_03542552'},
#  {'ingredient': 'Crab',
#   'foodon_ids': ['FOODON_03411335'],
#   'alternate_names': ['crab'],
#   'foodon_foodex2_id': 'FOODON_03542500'},
#  {'ingredient': 'Crayfish',
#   'foodon_ids': ['FOODON_00001789'],
#   'alternate_names': ['crayfish food product'],
#   'foodon_foodex2_id': 'FOODON_03542487'},
#  {'ingredient': 'Langoustine',
#   'foodon_ids': ['FOODON_00002059'],
#   'alternate_names': ['norway lobster food product',
#    'dublin bay prawn',
#    'scampi'],
#   'foodon_foodex2_id': 'FOODON_03542505'},
#  {'ingredient': 'Lobster',
#   'foodon_ids': ['FOODON_03411505'],
#   'alternate_names': ['lobster'],
#   'foodon_foodex2_id': 'FOODON_03542502'},
#  {'ingredient': 'Mussel',
#   'foodon_ids': ['FOODON_03411223'],
#   'alternate_names': ['mussel', 'mytilidae'],
#   'foodon_foodex2_id': 'FOODON_03542534'},
#  {'ingredient': 'Oyster',
#   'foodon_ids': ['FOODON_03411224'],
#   'alternate_names': ['oyster', 'ostreidae'],
#   'foodon_foodex2_id': 'FOODON_03542529'},
#  {'ingredient': 'Prawn',
#   'foodon_ids': ['FOODON_00002239'],
#   'alternate_names': ['shrimp food product'],
#   'foodon_foodex2_id': 'FOODON_03542511'},
#  {'ingredient': 'Shrimp',
#   'foodon_ids': ['FOODON_03411237'],
#   'alternate_names': ['shrimp'],
#   'foodon_foodex2_id': 'FOODON_03542515'},
#  {'ingredient': 'Whelk',
#   'foodon_ids': ['FOODON_03411633'],
#   'alternate_names': ['whelk'],
#   'foodon_foodex2_id': 'FOODON_03542528'},
#  {'ingredient': 'Winkle',
#   'foodon_ids': ['FOODON_03412925'],
#   'alternate_names': ['periwinkle family'],
#   'foodon_foodex2_id': 'FOODON_03542525'},
#  {'ingredient': 'Chocolate Spread',
#   'foodon_ids': ['FOODON_00003187'],
#   'alternate_names': ['chocolate spread'],
#   'foodon_foodex2_id': 'FOODON_03543044'},
#  {'ingredient': 'Cocoa',
#   'foodon_ids': ['FOODON_03301072'],
#   'alternate_names': ['cocoa', 'cocoa powder'],
#   'foodon_foodex2_id': 'FOODON_03543428'},
#  {'ingredient': 'Dark chocolate',
#   'foodon_ids': ['FOODON_03303588'],
#   'alternate_names': ['dark chocolate'],
#   'foodon_foodex2_id': 'FOODON_03543035'},
#  {'ingredient': 'Drinking chocolate',
#   'foodon_ids': ['FOODON_00001246'],
#   'alternate_names': ['hot chocolate food product'],
#   'foodon_foodex2_id': 'FOODON_03543723'},
#  {'ingredient': 'Milk chocolate',
#   'foodon_ids': ['FOODON_03302806'],
#   'alternate_names': ['milk chocolate'],
#   'foodon_foodex2_id': 'FOODON_03543037'},
#  {'ingredient': 'White chocolate',
#   'foodon_ids': ['FOODON_03301329'],
#   'alternate_names': ['white chocolate'],
#   'foodon_foodex2_id': 'FOODON_03543041'},
#  {'ingredient': 'Egg',
#   'foodon_ids': ['FOODON_03316061'],
#   'alternate_names': ['hen egg (whole)', 'chicken egg', 'hen egg'],
#   'foodon_foodex2_id': 'FOODON_03542950'},
#  {'ingredient': 'Egg noodle',
#   'foodon_ids': ['FOODON_03301006'],
#   'alternate_names': ['noodle (egg)', 'egg noodle'],
#   'foodon_foodex2_id': 'FOODON_03540179'},
#  {'ingredient': 'Egg pasta',
#   'foodon_ids': ['FOODON_03306347'],
#   'alternate_names': ['pasta'],
#   'foodon_foodex2_id': 'FOODON_03540179'},
#  {'ingredient': 'Mayonnaise',
#   'foodon_ids': ['FOODON_03301440'],
#   'alternate_names': ['mayonnaise'],
#   'foodon_foodex2_id': 'FOODON_03544093'},
#  {'ingredient': 'Anchovy',
#   'foodon_ids': ['FOODON_03411854'],
#   'alternate_names': ['anchovy'],
#   'foodon_foodex2_id': 'FOODON_03542405'},
#  {'ingredient': 'Boal',
#   'foodon_ids': ['NCBITaxon_36718'],
#   'alternate_names': ['Wallago attu'],
#   'foodon_foodex2_id': 'FOODON_03542243'},
#  {'ingredient': 'Bream',
#   'foodon_ids': ['FOODON_03412388', 'NCBITaxon_38527'],
#   'alternate_names': ['sea bream', 'Abramis brama', 'common bream', 'bream'],
#   'foodon_foodex2_id': 'FOODON_03542368'},
#  {'ingredient': 'Calamari',
#   'foodon_ids': ['FOODON_00002897'],
#   'alternate_names': ['calamari'],
#   'foodon_foodex2_id': 'FOODON_03542561'},
#  {'ingredient': 'Chital',
#   'foodon_ids': ['FOODON_03411583'],
#   'alternate_names': ['deer'],
#   'foodon_foodex2_id': 'FOODON_03541946'},
#  {'ingredient': 'Cod',
#   'foodon_ids': ['FOODON_03411423'],
#   'alternate_names': ['cod'],
#   'foodon_foodex2_id': 'FOODON_03542346'},
#  {'ingredient': 'Cod roe',
#   'foodon_ids': ['FOODON_03302873'],
#   'alternate_names': ['cod roe'],
#   'foodon_foodex2_id': 'FOODON_03542471'},
#  {'ingredient': 'Coley',
#   'foodon_ids': ['FOODON_03413876'],
#   'alternate_names': ['pollock', 'pollacchius spp'],
#   'foodon_foodex2_id': 'FOODON_03542355'},
#  {'ingredient': 'Dab',
#   'foodon_ids': ['FOODON_03309265'],
#   'alternate_names': ['dab (raw)'],
#   'foodon_foodex2_id': 'FOODON_03542329'},
#  {'ingredient': 'Dogfish',
#   'foodon_ids': ['FOODON_03411912'],
#   'alternate_names': ['dogfish shark family'],
#   'foodon_foodex2_id': 'FOODON_03542462'},
#  {'ingredient': 'Dover sole',
#   'foodon_ids': ['FOODON_03308230'],
#   'alternate_names': ['dover sole (raw)'],
#   'foodon_foodex2_id': 'FOODON_03542340'},
#  {'ingredient': 'Fish',
#   'foodon_ids': ['FOODON_03411222'],
#   'alternate_names': ['fish'],
#   'foodon_foodex2_id': 'FOODON_03542212'},
#  {'ingredient': 'Fish sauce',
#   'foodon_ids': ['FOODON_03317197'],
#   'alternate_names': ['fish sauce'],
#   'foodon_foodex2_id': 'FOODON_03544114'},
#  {'ingredient': 'Fish stock',
#   'foodon_ids': ['FOODON_03311638'],
#   'alternate_names': ['fish broth'],
#   'foodon_foodex2_id': 'FOODON_03544072'},
#  {'ingredient': 'Flounder',
#   'foodon_ids': ['FOODON_00002442'],
#   'alternate_names': ['flounder food product'],
#   'foodon_foodex2_id': 'FOODON_03542330'},
#  {'ingredient': 'Haddock',
#   'foodon_ids': ['FOODON_00001941'],
#   'alternate_names': ['haddock food product'],
#   'foodon_foodex2_id': 'FOODON_03542350'},
#  {'ingredient': 'Hake',
#   'foodon_ids': ['FOODON_03413878'],
#   'alternate_names': ['hake'],
#   'foodon_foodex2_id': 'FOODON_03542351'},
#  {'ingredient': 'Halibut',
#   'foodon_ids': ['FOODON_03411532'],
#   'alternate_names': ['halibut', 'reinhardtius spp.', 'hippoglossus spp.'],
#   'foodon_foodex2_id': 'FOODON_03542328'},
#  {'ingredient': 'Hering roe',
#   'foodon_ids': ['FOODON_03308006'],
#   'alternate_names': ['herring roe (raw)'],
#   'foodon_foodex2_id': 'FOODON_03542474'},
#  {'ingredient': 'Herring',
#   'foodon_ids': ['FOODON_03411414'],
#   'alternate_names': ['herring'],
#   'foodon_foodex2_id': 'FOODON_03542406'},
#  {'ingredient': 'Hilsa',
#   'foodon_ids': ['NCBITaxon_373995'],
#   'alternate_names': ['Tenualosa ilisha',
#    'palla fish',
#    'modar',
#    'sboor',
#    'ilish',
#    'terubok',
#    'terubok umno',
#    'pulasa',
#    'ellis',
#    'jatka',
#    'ilih',
#    'hilsa',
#    'hilsha',
#    'ilisha',
#    'pallo machhi',
#    'ulla mean',
#    'Hilsa shad',
#    'ilihi',
#    'palva',
#    'ilishi hilsa',
#    'herring\r'],
#   'foodon_foodex2_id': 'FOODON_03542321'},
#  {'ingredient': 'Hoki',
#   'foodon_ids': ['FOODON_03309206'],
#   'alternate_names': ['hoki (raw)'],
#   'foodon_foodex2_id': 'FOODON_03542316'},
#  {'ingredient': 'John Dory',
#   'foodon_ids': ['NCBITaxon_64108'],
#   'alternate_names': ['Zeus faber',
#    "doorkeeper's fish",
#    'Atlantic John dory',
#    'John dory'],
#   'foodon_foodex2_id': 'FOODON_03542362'},
#  {'ingredient': 'Kalabasu',
#   'foodon_ids': ['NCBITaxon_177615'],
#   'alternate_names': ['calbasu', 'orange-fin labeo'],
#   'foodon_foodex2_id': 'FOODON_03542228'},
#  {'ingredient': 'Katla',
#   'foodon_ids': ['NCBITaxon_72446'],
#   'alternate_names': ['major Indian carp',
#    'Gibelion catla',
#    'catla',
#    'major carp'],
#   'foodon_foodex2_id': 'FOODON_03542230'},
#  {'ingredient': 'Kippers',
#   'foodon_ids': ['FOODON_03308382'],
#   'alternate_names': ['kipper'],
#   'foodon_foodex2_id': 'FOODON_03542407'},
#  {'ingredient': 'Lemon sole',
#   'foodon_ids': ['NCBITaxon_106175'],
#   'alternate_names': ['Microstomus kitt', 'lemon sole'],
#   'foodon_foodex2_id': 'FOODON_03542340'},
#  {'ingredient': 'Ling',
#   'foodon_ids': ['FOODON_03308649'],
#   'alternate_names': ['ling (raw)'],
#   'foodon_foodex2_id': 'FOODON_03542352'},
#  {'ingredient': 'Mackerel',
#   'foodon_ids': ['FOODON_03411043'],
#   'alternate_names': ['mackerel'],
#   'foodon_foodex2_id': 'FOODON_03542449'},
#  {'ingredient': 'Monkfish',
#   'foodon_ids': ['NCBITaxon_472767'],
#   'alternate_names': ['Lophius gastrophysus'],
#   'foodon_foodex2_id': 'FOODON_03542396'},
#  {'ingredient': 'Mullet',
#   'foodon_ids': ['FOODON_03413916'],
#   'alternate_names': ['mullet'],
#   'foodon_foodex2_id': 'FOODON_03542363'},
#  {'ingredient': 'Octopus',
#   'foodon_ids': ['FOODON_03316989'],
#   'alternate_names': ['octopus food product'],
#   'foodon_foodex2_id': 'FOODON_03542558'},
#  {'ingredient': 'Oyster sauce',
#   'foodon_ids': ['FOODON_03317654'],
#   'alternate_names': ['oyster sauce'],
#   'foodon_foodex2_id': 'FOODON_03544112'},
#  {'ingredient': 'Pangasius',
#   'foodon_ids': ['NCBITaxon_8000'],
#   'alternate_names': ['Pangasius'],
#   'foodon_foodex2_id': 'FOODON_03542245'},
#  {'ingredient': 'Parrot fish',
#   'foodon_ids': ['NCBITaxon_8247'],
#   'alternate_names': ['Labridae', 'parrotfishes', 'wrasses'],
#   'foodon_foodex2_id': 'FOODON_03542433'},
#  {'ingredient': 'Pilchard',
#   'foodon_ids': ['FOODON_03413853'],
#   'alternate_names': ['pilchard'],
#   'foodon_foodex2_id': 'FOODON_03542402'},
#  {'ingredient': 'Plaice',
#   'foodon_ids': ['FOODON_03412570'],
#   'alternate_names': ['plaice'],
#   'foodon_foodex2_id': 'FOODON_03542337'},
#  {'ingredient': 'Pollock',
#   'foodon_ids': ['FOODON_03413876'],
#   'alternate_names': [],
#   'foodon_foodex2_id': 'FOODON_03542354'},
#  {'ingredient': 'Pomfret',
#   'foodon_ids': ['FOODON_03412571'],
#   'alternate_names': ['pomfret'],
#   'foodon_foodex2_id': 'FOODON_03542435'},
#  {'ingredient': 'Red snapper',
#   'foodon_ids': ['FOODON_00002194'],
#   'alternate_names': ['red snapper food product'],
#   'foodon_foodex2_id': 'FOODON_03542371'},
#  {'ingredient': 'Redfish',
#   'foodon_ids': ['FOODON_03411153'],
#   'alternate_names': ['redfish or ocean perch'],
#   'foodon_foodex2_id': 'FOODON_03542371'},
#  {'ingredient': 'Rohu',
#   'foodon_ids': ['NCBITaxon_84645'],
#   'alternate_names': ['Labeo rohita', 'Jayanti rohu', 'rohu'],
#   'foodon_foodex2_id': 'FOODON_03542229'},
#  {'ingredient': 'Sardine',
#   'foodon_ids': ['FOODON_03411558'],
#   'alternate_names': ['sardine'],
#   'foodon_foodex2_id': 'FOODON_03542402'},
#  {'ingredient': 'Scallops',
#   'foodon_ids': ['FOODON_03411489'],
#   'alternate_names': ['scallop', 'pectinidae'],
#   'foodon_foodex2_id': 'FOODON_03542538'},
#  {'ingredient': 'Seafood',
#   'foodon_ids': ['FOODON_03310116'],
#   'alternate_names': ['seafood (raw)'],
#   'foodon_foodex2_id': 'FOODON_03542641'},
#  {'ingredient': 'Shark',
#   'foodon_ids': ['FOODON_03411342'],
#   'alternate_names': ['shark'],
#   'foodon_foodex2_id': 'FOODON_03542455'},
#  {'ingredient': 'Skate',
#   'foodon_ids': ['FOODON_03411340'],
#   'alternate_names': ['skate'],
#   'foodon_foodex2_id': 'FOODON_03542463'},
#  {'ingredient': 'Sole',
#   'foodon_ids': ['FOODON_03411025'],
#   'alternate_names': ['sole family', 'soleidae', 'true sole'],
#   'foodon_foodex2_id': 'FOODON_03542340'},
#  {'ingredient': 'Sprat',
#   'foodon_ids': ['FOODON_03411235'],
#   'alternate_names': ['sprat'],
#   'foodon_foodex2_id': 'FOODON_03542410'},
#  {'ingredient': 'Squid',
#   'foodon_ids': ['FOODON_03411205'],
#   'alternate_names': ['squid'],
#   'foodon_foodex2_id': 'FOODON_03542562'},
#  {'ingredient': 'Swordfish',
#   'foodon_ids': ['FOODON_00002307'],
#   'alternate_names': ['swordfish food product'],
#   'foodon_foodex2_id': 'FOODON_03542428'},
#  {'ingredient': 'Tuna',
#   'foodon_ids': ['FOODON_03411269'],
#   'alternate_names': ['tuna', 'true tuna', 'thunnini'],
#   'foodon_foodex2_id': 'FOODON_03542417'},
#  {'ingredient': 'Turbot',
#   'foodon_ids': ['FOODON_00002321'],
#   'alternate_names': ['turbot food product'],
#   'foodon_foodex2_id': 'FOODON_03542342'},
#  {'ingredient': 'White fish',
#   'foodon_ids': ['FOODON_00003281'],
#   'alternate_names': ['whitefish (fisheries term)', 'white fish'],
#   'foodon_foodex2_id': 'FOODON_03542316'},
#  {'ingredient': 'Whitebait',
#   'foodon_ids': ['FOODON_03308295'],
#   'alternate_names': ['whitebait fish (raw)'],
#   'foodon_foodex2_id': 'FOODON_03542410'},
#  {'ingredient': 'Whiting',
#   'foodon_ids': ['FOODON_03411640'],
#   'alternate_names': ['whiting'],
#   'foodon_foodex2_id': 'FOODON_03542357'},
#  {'ingredient': 'Bass',
#   'foodon_ids': ['FOODON_03412180'],
#   'alternate_names': ['sea bass', 'centropristis spp.'],
#   'foodon_foodex2_id': 'FOODON_03542366'},
#  {'ingredient': 'Carp',
#   'foodon_ids': ['FOODON_03412617'],
#   'alternate_names': ['carp'],
#   'foodon_foodex2_id': 'FOODON_03542220'},
#  {'ingredient': 'Catfish',
#   'foodon_ids': ['FOODON_03412620'],
#   'alternate_names': ['catfish'],
#   'foodon_foodex2_id': 'FOODON_03542243'},
#  {'ingredient': 'Caviar',
#   'foodon_ids': ['FOODON_03301080'],
#   'alternate_names': ['caviar'],
#   'foodon_foodex2_id': 'FOODON_03542469'},
#  {'ingredient': 'Cuttlefish',
#   'foodon_ids': ['FOODON_03411644'],
#   'alternate_names': ['cuttlefish'],
#   'foodon_foodex2_id': 'FOODON_03542554'},
#  {'ingredient': 'Eel',
#   'foodon_ids': ['FOODON_03411278'],
#   'alternate_names': ['eel'],
#   'foodon_foodex2_id': 'FOODON_03542293'},
#  {'ingredient': 'Salmon',
#   'foodon_ids': ['FOODON_00003473'],
#   'alternate_names': ['salmon'],
#   'foodon_foodex2_id': 'FOODON_03542296'},
#  {'ingredient': 'Tilapia',
#   'foodon_ids': ['FOODON_03412434'],
#   'alternate_names': ['tilapia'],
#   'foodon_foodex2_id': 'FOODON_03542238'},
#  {'ingredient': 'Trout',
#   'foodon_ids': ['FOODON_03411258'],
#   'alternate_names': ['trout'],
#   'foodon_foodex2_id': 'FOODON_03542305'},
#  {'ingredient': 'Apricot',
#   'foodon_ids': ['FOODON_03301701'],
#   'alternate_names': ['apricot (whole, raw)'],
#   'foodon_foodex2_id': 'FOODON_03541492'},
#  {'ingredient': 'Arrowhead',
#   'foodon_ids': ['FOODON_03411716'],
#   'alternate_names': ['arrowhead plant',
#    'sagittaria latifolia',
#    'broadleaf arrowhead',
#    'wapato',
#    'Indian potato',
#    'duck potato'],
#   'foodon_foodex2_id': 'FOODON_03540756'},
#  {'ingredient': 'Avocado',
#   'foodon_ids': ['FOODON_03305236'],
#   'alternate_names': ['avocado (whole, raw)', 'avocado'],
#   'foodon_foodex2_id': 'FOODON_03541733'},
#  {'ingredient': 'Babaco',
#   'foodon_ids': ['FOODON_03412797'],
#   'alternate_names': ['babaco plant'],
#   'foodon_foodex2_id': 'FOODON_03541664'},
#  {'ingredient': 'Breadfruit',
#   'foodon_ids': ['FOODON_03305285'],
#   'alternate_names': ['breadfruit (whole, raw)', 'breadfruit'],
#   'foodon_foodex2_id': 'FOODON_03541779'},
#  {'ingredient': 'Breadnut',
#   'foodon_ids': ['FOODON_03305165'],
#   'alternate_names': ['breadnut tree seed'],
#   'foodon_foodex2_id': 'FOODON_03541646'},
#  {'ingredient': 'Coconut',
#   'foodon_ids': ['FOODON_03303085'],
#   'alternate_names': ['coconut (whole, raw)', 'coconut'],
#   'foodon_foodex2_id': 'FOODON_03541139'},
#  {'ingredient': 'Coconut cream',
#   'foodon_ids': ['FOODON_03303088'],
#   'alternate_names': ['coconut cream'],
#   'foodon_foodex2_id': 'FOODON_03543839'},
#  {'ingredient': 'Dried apricot',
#   'foodon_ids': ['FOODON_03301756'],
#   'alternate_names': ['apricot (dried)'],
#   'foodon_foodex2_id': 'FOODON_03541797'},
#  {'ingredient': 'Durian',
#   'foodon_ids': ['FOODON_00003121'],
#   'alternate_names': ['durian (whole, raw)', 'durian'],
#   'foodon_foodex2_id': 'FOODON_03541783'},
#  {'ingredient': 'Feijoa',
#   'foodon_ids': ['FOODON_03412767'],
#   'alternate_names': ['pineapple guava plant',
#    'feijoa sellowiana',
#    'acca sellowiana',
#    'orthostemon sellowiana',
#    'feijoa',
#    'brazilian guava'],
#   'foodon_foodex2_id': 'FOODON_03541750'},
#  {'ingredient': 'Fig',
#   'foodon_ids': ['FOODON_00003266'],
#   'alternate_names': ['fig (whole)'],
#   'foodon_foodex2_id': 'FOODON_03541647'},
#  {'ingredient': 'Grenadillas',
#   'foodon_ids': ['NCBITaxon_237863'],
#   'alternate_names': ['Passiflora ligularis', 'sweet granadilla'],
#   'foodon_foodex2_id': 'FOODON_03541714'},
#  {'ingredient': 'Guacamole',
#   'foodon_ids': ['FOODON_03310550'],
#   'alternate_names': ['guacamole'],
#   'foodon_foodex2_id': 'FOODON_03541732'},
#  {'ingredient': 'Guava',
#   'foodon_ids': ['FOODON_03305317'],
#   'alternate_names': ['guava (whole, raw)', 'guava'],
#   'foodon_foodex2_id': 'FOODON_03541770'},
#  {'ingredient': 'Jackfruit',
#   'foodon_ids': ['FOODON_00003087'],
#   'alternate_names': ['jackfruit (whole, raw)',
#    'langka',
#    'jakfruit',
#    'jack fruit',
#    'jack',
#    'jackfruit'],
#   'foodon_foodex2_id': 'FOODON_03541780'},
#  {'ingredient': 'Jambu',
#   'foodon_ids': ['FOODON_00003626'],
#   'alternate_names': ['java apple (whole)',
#    'Java apple',
#    'wax apple',
#    'Semarang rose-apple',
#    'wax jambu'],
#   'foodon_foodex2_id': 'FOODON_03541690'},
#  {'ingredient': 'Jujube',
#   'foodon_ids': ['FOODON_00002487'],
#   'alternate_names': ['jujube fruit (whole, raw)', 'Jujube', 'jujube fruit'],
#   'foodon_foodex2_id': 'FOODON_03541516'},
#  {'ingredient': 'Kiwi',
#   'foodon_ids': ['FOODON_03414363'],
#   'alternate_names': ['kiwi'],
#   'foodon_foodex2_id': 'FOODON_03541701'},
#  {'ingredient': 'Kumquats',
#   'foodon_ids': ['FOODON_03306597'],
#   'alternate_names': ['kumquat (whole, raw)', 'kumquat'],
#   'foodon_foodex2_id': 'FOODON_03541655'},
#  {'ingredient': 'Longan',
#   'foodon_ids': ['FOODON_00003168'],
#   'alternate_names': ['longan (whole, raw)',
#    'lungan',
#    'longan',
#    'dragon eyes'],
#   'foodon_foodex2_id': 'FOODON_03541706'},
#  {'ingredient': 'Loquat',
#   'foodon_ids': ['FOODON_00003181'],
#   'alternate_names': ['loquat (whole, raw)'],
#   'foodon_foodex2_id': 'FOODON_03541488'},
#  {'ingredient': 'Mango',
#   'foodon_ids': ['FOODON_03301813'],
#   'alternate_names': ['mango (whole, raw)'],
#   'foodon_foodex2_id': 'FOODON_03541746'},
#  {'ingredient': 'Mangosteen',
#   'foodon_ids': ['FOODON_00003110'],
#   'alternate_names': ['mangosteen food product',
#    'mangosteen',
#    'purple mangosteen'],
#   'foodon_foodex2_id': 'FOODON_03541752'},
#  {'ingredient': 'Medlar',
#   'foodon_ids': ['FOODON_00003133'],
#   'alternate_names': ['medlar (whole, raw)', 'Medlar'],
#   'foodon_foodex2_id': 'FOODON_03541486'},
#  {'ingredient': 'Melon',
#   'foodon_ids': ['FOODON_03301593'],
#   'alternate_names': ['melon (whole, raw)', 'melon'],
#   'foodon_foodex2_id': 'FOODON_03540694'},
#  {'ingredient': 'Nectarine',
#   'foodon_ids': ['FOODON_03301107'],
#   'alternate_names': ['nectarine (whole, raw)', 'nectarine'],
#   'foodon_foodex2_id': 'FOODON_03541508'},
#  {'ingredient': 'Papaya',
#   'foodon_ids': ['FOODON_03301830'],
# ...
#   'foodon_ids': ['FOODON_03309664'],
#   'alternate_names': ['tofu food product'],
#   'foodon_foodex2_id': 'FOODON_03543841'},
#  {'ingredient': 'Cherry tomato',
#   'foodon_ids': ['FOODON_03311800'],
#   'alternate_names': ['miniature tomato (whole, raw)', 'cherry tomato'],
#   'foodon_foodex2_id': 'FOODON_03540639'},
#  {'ingredient': 'Passata',
#   'foodon_ids': ['FOODON_03317029'],
#   'alternate_names': ['tomato puree (for further processing)'],
#   'foodon_foodex2_id': 'FOODON_03540933'},
#  {'ingredient': 'Salsa',
#   'foodon_ids': ['FOODON_03310086'],
#   'alternate_names': ['salsa'],
#   'foodon_foodex2_id': 'FOODON_03544127'},
#  {'ingredient': 'Tomato',
#   'foodon_ids': ['FOODON_03301453'],
#   'alternate_names': ['tomato (whole)', 'tomato'],
#   'foodon_foodex2_id': 'FOODON_03540633'},
#  {'ingredient': 'Tomato ketchup',
#   'foodon_ids': ['FOODON_03301460'],
#   'alternate_names': ['tomato catsup', 'Ketchup'],
#   'foodon_foodex2_id': 'FOODON_03544118'},
#  {'ingredient': 'Tomato puree',
#   'foodon_ids': ['FOODON_03301457'],
#   'alternate_names': ['tomato puree'],
#   'foodon_foodex2_id': 'FOODON_03540936'},
#  {'ingredient': 'Tomato sauce',
#   'foodon_ids': ['FOODON_03301217'],
#   'alternate_names': ['tomato sauce'],
#   'foodon_foodex2_id': 'FOODON_03544098'},
#  {'ingredient': 'Ackee',
#   'foodon_ids': ['NCBITaxon_259381'],
#   'alternate_names': ['Blighia sapida', 'akee', 'ackee', 'aki'],
#   'foodon_foodex2_id': 'FOODON_03541749'},
#  {'ingredient': 'Acorn squash',
#   'foodon_ids': ['FOODON_03315223'],
#   'alternate_names': ['acorn squash (whole, raw)', 'acorn squash'],
#   'foodon_foodex2_id': 'FOODON_03540700'},
#  {'ingredient': 'Allspice',
#   'foodon_ids': ['FOODON_03301554'],
#   'alternate_names': ['allspice (ground)', 'allspice'],
#   'foodon_foodex2_id': 'FOODON_03541370'},
#  {'ingredient': 'Asafoetida',
#   'foodon_ids': ['FOODON_00002936'],
#   'alternate_names': ['asafoetida',
#    'jowani badian',
#    'inguva',
#    'hengu',
#    'ting',
#    'hing',
#    'kayam'],
#   'foodon_foodex2_id': 'FOODON_03540832'},
#  {'ingredient': 'Aubergine',
#   'foodon_ids': ['FOODON_03411458'],
#   'alternate_names': ['eggplant plant', 'solanum melongena', 'aubergine'],
#   'foodon_foodex2_id': 'FOODON_03540658'},
#  {'ingredient': 'Bamboo shoots',
#   'foodon_ids': ['FOODON_03307912'],
#   'alternate_names': ['bamboo shoot (raw)', 'bamboo shoot'],
#   'foodon_foodex2_id': 'FOODON_03540560'},
#  {'ingredient': 'Beansprouts',
#   'foodon_ids': ['FOODON_00002576'],
#   'alternate_names': ['bean sprout'],
#   'foodon_foodex2_id': 'FOODON_03540515'},
#  {'ingredient': 'Betel leaves',
#   'foodon_ids': ['FOODON_03302218'],
#   'alternate_names': ['betel leaf (whole)', 'betel leaf'],
#   'foodon_foodex2_id': 'FOODON_03540905'},
#  {'ingredient': 'Brown sauce',
#   'foodon_ids': ['FOODON_03305335'],
#   'alternate_names': ['brown sauce mix'],
#   'foodon_foodex2_id': 'FOODON_03544115'},
#  {'ingredient': 'Butternut squash',
#   'foodon_ids': ['FOODON_00002981'],
#   'alternate_names': ['butternut squash (whole, raw)', 'butternut squash'],
#   'foodon_foodex2_id': 'FOODON_03540698'},
#  {'ingredient': 'Cayenne',
#   'foodon_ids': ['FOODON_00003798'],
#   'alternate_names': ['cayenne pepper (whole)', 'cayenne pepper pod'],
#   'foodon_foodex2_id': 'FOODON_03541405'},
#  {'ingredient': 'Celery',
#   'foodon_ids': ['FOODON_03301727'],
#   'alternate_names': ['celery stalk (whole, raw)', 'celery', 'celery stalk'],
#   'foodon_foodex2_id': 'FOODON_03540833'},
#  {'ingredient': 'Celery salt',
#   'foodon_ids': ['FOODON_03304738'],
#   'alternate_names': ['celery salt'],
#   'foodon_foodex2_id': 'FOODON_03541297'},
#  {'ingredient': 'Chia seed',
#   'foodon_ids': ['FOODON_00002961'],
#   'alternate_names': ['chia seed (whole)', 'chia seed'],
#   'foodon_foodex2_id': 'FOODON_03541235'},
#  {'ingredient': 'Chili garlic sauce',
#   'foodon_ids': ['FOODON_03311687'],
#   'alternate_names': ['chili-garlic in oil'],
#   'foodon_foodex2_id': 'FOODON_03544121'},
#  {'ingredient': 'Chilli',
#   'foodon_ids': ['FOODON_03301511'],
#   'alternate_names': ['chili con carne (dish)',
#    'Chilli garlic sauce',
#    'chilli'],
#   'foodon_foodex2_id': 'FOODON_03540651'},
#  {'ingredient': 'Chilli paste',
#   'foodon_ids': ['FOODON_03315435'],
#   'alternate_names': ['chili paste'],
#   'foodon_foodex2_id': 'FOODON_03544234'},
#  {'ingredient': 'Chilli powder',
#   'foodon_ids': ['FOODON_03302030'],
#   'alternate_names': ['chili powder'],
#   'foodon_foodex2_id': 'FOODON_03541406'},
#  {'ingredient': 'Chilli sauce',
#   'foodon_ids': ['FOODON_03304583'],
#   'alternate_names': ['chili sauce'],
#   'foodon_foodex2_id': 'FOODON_03544234'},
#  {'ingredient': 'Cho Cho',
#   'foodon_ids': ['FOODON_00003653'],
#   'alternate_names': ['chayote (whole)'],
#   'foodon_foodex2_id': 'FOODON_03540680'},
#  {'ingredient': 'Cinnamon',
#   'foodon_ids': ['FOODON_03301175'],
#   'alternate_names': ['cinnamon'],
#   'foodon_foodex2_id': 'FOODON_03541342'},
#  {'ingredient': 'Cloves',
#   'foodon_ids': ['FOODON_00001745'],
#   'alternate_names': ['clove food product', 'cloves'],
#   'foodon_foodex2_id': 'FOODON_03541323'},
#  {'ingredient': 'Courgette',
#   'foodon_ids': ['FOODON_03411462'],
#   'alternate_names': ['zucchini plant',
#    'courgette',
#    'cucurbita pepo var. melopepo cv. zucchini'],
#   'foodon_foodex2_id': 'FOODON_03540677'},
#  {'ingredient': 'Cucumber',
#   'foodon_ids': ['FOODON_03301545'],
#   'alternate_names': ['cucumber (whole, raw)', 'cucumber'],
#   'foodon_foodex2_id': 'FOODON_03540670'},
#  {'ingredient': 'Curry leaves',
#   'foodon_ids': ['FOODON_03413424'],
#   'alternate_names': ['curryleaf plant'],
#   'foodon_foodex2_id': 'FOODON_03540902'},
#  {'ingredient': 'Curry paste',
#   'foodon_ids': ['FOODON_03302920'],
#   'alternate_names': ['curry paste'],
#   'foodon_foodex2_id': 'FOODON_03544122'},
#  {'ingredient': 'Curry powder',
#   'foodon_ids': ['FOODON_03301842'],
#   'alternate_names': ['curry powder'],
#   'foodon_foodex2_id': 'FOODON_03544062'},
#  {'ingredient': 'Curry sauce',
#   'foodon_ids': ['FOODON_03304046'],
#   'alternate_names': ['curry sauce'],
#   'foodon_foodex2_id': 'FOODON_03544122'},
#  {'ingredient': 'Fenugreek leaves',
#   'foodon_ids': ['FOODON_00003620'],
#   'alternate_names': ['fenugreek leaf (whole)',
#    'methi leaf',
#    'fenugreek leaf'],
#   'foodon_foodex2_id': 'FOODON_03540841'},
#  {'ingredient': 'Fenugreek seeds',
#   'foodon_ids': ['FOODON_03307812'],
#   'alternate_names': ['fenugreek seed (whole)', 'fenugreek seed'],
#   'foodon_foodex2_id': 'FOODON_03541312'},
#  {'ingredient': 'Garlic ginger paste',
#   'foodon_ids': ['FOODON_03305217'],
#   'alternate_names': ['garlic paste'],
#   'foodon_foodex2_id': 'FOODON_03544152'},
#  {'ingredient': 'Garlic salt',
#   'foodon_ids': ['FOODON_03307739'],
#   'alternate_names': ['garlic salt'],
#   'foodon_foodex2_id': 'FOODON_03544270'},
#  {'ingredient': 'Gherkin',
#   'foodon_ids': ['FOODON_00003005'],
#   'alternate_names': ['pickled cucumber', 'gherkin', 'pickle'],
#   'foodon_foodex2_id': 'FOODON_03540674'},
#  {'ingredient': 'Gochujang',
#   'foodon_ids': ['FOODON_03315435'],
#   'alternate_names': [],
#   'foodon_foodex2_id': 'FOODON_03544152'},
#  {'ingredient': 'Gourd',
#   'foodon_ids': ['FOODON_00001915'],
#   'alternate_names': ['gourd food product'],
#   'foodon_foodex2_id': 'FOODON_03540676'},
#  {'ingredient': 'Harissa',
#   'foodon_ids': ['FOODON_00002484'],
#   'alternate_names': ['harissa chili paste'],
#   'foodon_foodex2_id': 'FOODON_03544152'},
#  {'ingredient': 'Kabsa',
#   'foodon_ids': ['FOODON_03304292'],
#   'alternate_names': [],
#   'foodon_foodex2_id': 'FOODON_03544060'},
#  {'ingredient': 'Lemongrass',
#   'foodon_ids': ['FOODON_03412273'],
#   'alternate_names': ['lemon grass plant', 'lemongrass', 'lemon grass'],
#   'foodon_foodex2_id': 'FOODON_03540911'},
#  {'ingredient': 'Marrow',
#   'foodon_ids': ['FOODON_00002785'],
#   'alternate_names': ['marrow bean (whole)', 'marrow bean'],
#   'foodon_foodex2_id': 'FOODON_03540700'},
#  {'ingredient': 'Mixed herbs',
#   'foodon_ids': ['FOODON_03315168'],
#   'alternate_names': ['herbs and seasonings'],
#   'foodon_foodex2_id': 'FOODON_03544061'},
#  {'ingredient': 'Molokhia',
#   'foodon_ids': ['NCBITaxon_93759'],
#   'alternate_names': ['Corchorus olitorius', 'jute', 'Nalta jute'],
#   'foodon_foodex2_id': 'FOODON_03540412'},
#  {'ingredient': 'Mushroom',
#   'foodon_ids': ['FOODON_03301303'],
#   'alternate_names': ['mushroom (whole, raw)', 'mushroom'],
#   'foodon_foodex2_id': 'FOODON_03540784'},
#  {'ingredient': 'Nut roast',
#   'foodon_ids': ['FOODON_00001172'],
#   'alternate_names': [],
#   'foodon_foodex2_id': 'FOODON_03541118'},
#  {'ingredient': 'Okra',
#   'foodon_ids': ['FOODON_03301828'],
#   'alternate_names': ['okra (whole, raw)', 'okra'],
#   'foodon_foodex2_id': 'FOODON_03540665'},
#  {'ingredient': 'Olive',
#   'foodon_ids': ['FOODON_03315145'],
#   'alternate_names': ['olive (whole, ripe)', 'olive'],
#   'foodon_foodex2_id': 'FOODON_03541649'},
#  {'ingredient': 'Paprika',
#   'foodon_ids': ['FOODON_03301105'],
#   'alternate_names': ['paprika'],
#   'foodon_foodex2_id': 'FOODON_03544338'},
#  {'ingredient': 'Pepper',
#   'foodon_ids': ['FOODON_03309928'],
#   'alternate_names': ['pepper (whole, raw)', 'pepper'],
#   'foodon_foodex2_id': 'FOODON_03540649'},
#  {'ingredient': 'Rhubarb',
#   'foodon_ids': ['FOODON_00002202'],
#   'alternate_names': ['rhubarb food product'],
#   'foodon_foodex2_id': 'FOODON_03540558'},
#  {'ingredient': 'Spaghetti squash',
#   'foodon_ids': ['FOODON_03412508'],
#   'alternate_names': ['spaghetti squash plant'],
#   'foodon_foodex2_id': 'FOODON_03540697'},
#  {'ingredient': 'Squash',
#   'foodon_ids': ['FOODON_03301577'],
#   'alternate_names': ['squash (whole, raw)', 'squash'],
#   'foodon_foodex2_id': 'FOODON_03540698'},
#  {'ingredient': 'Summer squash',
#   'foodon_ids': ['FOODON_00003708'],
#   'alternate_names': ['summer squash (whole)', 'summer squash'],
#   'foodon_foodex2_id': 'FOODON_03540685'},
#  {'ingredient': 'Vegetable',
#   'foodon_ids': ['FOODON_00003816'],
#   'alternate_names': ['vegetable (whole)', 'vegetable'],
#   'foodon_foodex2_id': 'FOODON_03540358'},
#  {'ingredient': 'Vine leaves',
#   'foodon_ids': ['FOODON_03411329'],
#   'alternate_names': ['grape plant', 'vitis spp.'],
#   'foodon_foodex2_id': 'FOODON_03540454'},
#  {'ingredient': 'Wasabi',
#   'foodon_ids': ['FOODON_03305495'],
#   'alternate_names': ['wasabi (food product)'],
#   'foodon_foodex2_id': 'FOODON_03541358'},
#  {'ingredient': 'Bran',
#   'foodon_ids': ['FOODON_03301118'],
#   'alternate_names': ['bran food product'],
#   'foodon_foodex2_id': 'FOODON_03540108'},
#  {'ingredient': 'Sourdough',
#   'foodon_ids': ['FOODON_03302481'],
#   'alternate_names': ['sourdough bread', 'sourdough'],
#   'foodon_foodex2_id': 'FOODON_03544457'},
#  {'ingredient': 'Bread',
#   'foodon_ids': ['FOODON_00001183'],
#   'alternate_names': ['bread food product'],
#   'foodon_foodex2_id': 'FOODON_03540116'},
#  {'ingredient': 'Buckwheat',
#   'foodon_ids': ['FOODON_03305367'],
#   'alternate_names': ['buckwheat food product'],
#   'foodon_foodex2_id': 'FOODON_03540009'},
#  {'ingredient': 'Buckwheat flour',
#   'foodon_ids': ['FOODON_03309980'],
#   'alternate_names': ['buckwheat flour'],
#   'foodon_foodex2_id': 'FOODON_03540071'},
#  {'ingredient': 'Buckwheat noodle',
#   'foodon_ids': ['FOODON_03309979'],
#   'alternate_names': ['buckwheat noodle'],
#   'foodon_foodex2_id': 'FOODON_03540197'},
#  {'ingredient': 'Bulgur wheat',
#   'foodon_ids': ['FOODON_00003143'],
#   'alternate_names': ['bulgur', 'bulgur wheat'],
#   'foodon_foodex2_id': 'FOODON_03540103'},
#  {'ingredient': 'Chapati flour',
#   'foodon_ids': ['FOODON_03302340'],
#   'alternate_names': ['whole wheat flour'],
#   'foodon_foodex2_id': 'FOODON_03540094'},
#  {'ingredient': 'Couscous',
#   'foodon_ids': ['FOODON_03303207'],
#   'alternate_names': ['couscous'],
#   'foodon_foodex2_id': 'FOODON_03540196'},
#  {'ingredient': 'Dough',
#   'foodon_ids': ['FOODON_03311552'],
#   'alternate_names': ['dough'],
#   'foodon_foodex2_id': 'FOODON_03540198'},
#  {'ingredient': 'Flour',
#   'foodon_ids': ['FOODON_00001056'],
#   'alternate_names': ['flour food product'],
#   'foodon_foodex2_id': 'FOODON_03540067'},
#  {'ingredient': 'Flour tortilla',
#   'foodon_ids': ['FOODON_03307944'],
#   'alternate_names': ['tortilla flour'],
#   'foodon_foodex2_id': 'FOODON_03540143'},
#  {'ingredient': 'Gravy granules',
#   'foodon_ids': ['FOODON_03315265'],
#   'alternate_names': ['gravy mix (prepared)'],
#   'foodon_foodex2_id': 'FOODON_03544071'},
#  {'ingredient': 'Millet flour',
#   'foodon_ids': ['FOODON_03310137'],
#   'alternate_names': ['millet flour'],
#   'foodon_foodex2_id': 'FOODON_03540075'},
#  {'ingredient': 'Naan bread',
#   'foodon_ids': ['FOODON_00002532'],
#   'alternate_names': ['naan'],
#   'foodon_foodex2_id': 'FOODON_03540138'},
#  {'ingredient': 'Pasta',
#   'foodon_ids': ['FOODON_03306347'],
#   'alternate_names': [],
#   'foodon_foodex2_id': 'FOODON_03540175'},
#  {'ingredient': 'Pearl barley',
#   'foodon_ids': ['FOODON_03306062'],
#   'alternate_names': ['barley (pearled)'],
#   'foodon_foodex2_id': 'FOODON_03540007'},
#  {'ingredient': 'Quinoa',
#   'foodon_ids': ['FOODON_00001192'],
#   'alternate_names': ['quinoa food product'],
#   'foodon_foodex2_id': 'FOODON_03540015'},
#  {'ingredient': 'Rusk',
#   'foodon_ids': ['FOODON_03316236'],
#   'alternate_names': ['rusks containing fat'],
#   'foodon_foodex2_id': 'FOODON_03540162'},
#  {'ingredient': 'Rye flour',
#   'foodon_ids': ['FOODON_03302492'],
#   'alternate_names': ['rye flour'],
#   'foodon_foodex2_id': 'FOODON_03540078'},
#  {'ingredient': 'Seitan',
#   'foodon_ids': ['FOODON_03310809'],
#   'alternate_names': ['wheat gluten'],
#   'foodon_foodex2_id': 'FOODON_03544161'},
#  {'ingredient': 'Shredded Wheat',
#   'foodon_ids': ['FOODON_03303943'],
#   'alternate_names': ['shredded wheat breakfast cereal'],
#   'foodon_foodex2_id': 'FOODON_03540308'},
#  {'ingredient': 'Spaghetti',
#   'foodon_ids': ['FOODON_03316839'],
#   'alternate_names': ['spaghetti (egg, wheat, and soy)'],
#   'foodon_foodex2_id': 'FOODON_03540194'},
#  {'ingredient': 'Wheat flour',
#   'foodon_ids': ['FOODON_03301116'],
#   'alternate_names': ['wheat flour'],
#   'foodon_foodex2_id': 'FOODON_03540088'},
#  {'ingredient': 'Wheat noodle',
#   'foodon_ids': ['FOODON_03316962'],
#   'alternate_names': ['noodle (egg, wheat, and soy)'],
#   'foodon_foodex2_id': 'FOODON_03540197'},
#  {'ingredient': 'Wheatgerm',
#   'foodon_ids': ['FOODON_03301595'],
#   'alternate_names': ['wheat germ'],
#   'foodon_foodex2_id': 'FOODON_03540115'},
#  {'ingredient': 'Brandy',
#   'foodon_ids': ['FOODON_03301632'],
#   'alternate_names': ['brandy'],
#   'foodon_foodex2_id': 'FOODON_03543387'},
#  {'ingredient': 'Curacao',
#   'foodon_ids': ['FOODON_03316303'],
#   'alternate_names': ['liqueur (flavored with fruit aromas)'],
#   'foodon_foodex2_id': 'FOODON_03543392'},
#  {'ingredient': 'Gin',
#   'foodon_ids': ['FOODON_03309491'],
#   'alternate_names': ['gin'],
#   'foodon_foodex2_id': 'FOODON_03543390'},
#  {'ingredient': 'Mirin',
#   'foodon_ids': ['FOODON_03310729'],
#   'alternate_names': ['mirin japanese'],
#   'foodon_foodex2_id': 'FOODON_03543349'},
#  {'ingredient': 'Port',
#   'foodon_ids': ['FOODON_03311271'],
#   'alternate_names': ['port wine'],
#   'foodon_foodex2_id': 'FOODON_03543369'},
#  {'ingredient': 'Sake',
#   'foodon_ids': ['FOODON_03301670'],
#   'alternate_names': ['sake'],
#   'foodon_foodex2_id': 'FOODON_03543349'},
#  {'ingredient': 'Sherry',
#   'foodon_ids': ['FOODON_03310760'],
#   'alternate_names': ['sherry'],
#   'foodon_foodex2_id': 'FOODON_03543367'},
#  {'ingredient': 'Vermouth',
#   'foodon_ids': ['FOODON_03307808'],
#   'alternate_names': ['vermouth'],
#   'foodon_foodex2_id': 'FOODON_03543366'},
#  {'ingredient': 'Vinegar',
#   'foodon_ids': ['FOODON_03301705'],
#   'alternate_names': ['vinegar'],
#   'foodon_foodex2_id': 'FOODON_03544087'},
#  {'ingredient': 'Whiskey',
#   'foodon_ids': ['FOODON_03302775'],
#   'alternate_names': ['whiskey'],
#   'foodon_foodex2_id': 'FOODON_03543384'},
#  {'ingredient': 'Wine',
#   'foodon_ids': ['FOODON_00002364'],
#   'alternate_names': ['wine or wine-like food product'],
#   'foodon_foodex2_id': 'FOODON_03543348'},
#  {'ingredient': 'Worcestershire sauce',
#   'foodon_ids': ['FOODON_03305003'],
#   'alternate_names': ['worcestershire sauce'],
#   'foodon_foodex2_id': 'FOODON_03544110'},
#  {'ingredient': 'Water',
#   'foodon_ids': ['CHEBI_15377'],
#   'alternate_names': ['water', 'oxidane'],
#   'foodon_foodex2_id': 'FOODON_03543262'}]

# %%
KB_ingreds = [entry['ingredient'].lower() for entry in KB]
KB_ingreds
# Out:
# ['apple',
#  'apple juice',
#  'apple sauce',
#  'cider',
#  'pear',
#  'capers',
#  'laverbread',
#  'nori',
#  'salsify',
#  'seaweed',
#  'banana',
#  'matoki',
#  'plantain',
#  'ale',
#  'beer',
#  'lager',
#  'nutritional yeast',
#  'stout',
#  'yeast',
#  'yeast extract',
#  'barbeque sauce',
#  'caster sugar',
#  'chutney',
#  'club soda',
#  'cola',
#  'golden syrup',
#  'granulated sugar',
#  'icing',
#  'icing sugar',
#  'marshmallow',
#  'sugar',
#  'amla',
#  'blackberries',
#  'blackcurrant',
#  'blueberries',
#  'cherry',
#  'cranberries',
#  'cranberry sauce',
#  'currant',
#  'damson',
#  'date',
#  'elderberries',
#  'gooseberries',
#  'grape',
#  'grape leaves',
#  'greengage',
#  'jam',
#  'loganberries',
#  'mixed fruit',
#  'mulberries',
#  'physalis',
#  'pimento',
#  'raisin',
#  'raspberries',
#  'redcurrant jelly',
#  'redcurrants',
#  'strawberries',
#  'sultanas',
#  'whitecurrant',
#  'beef',
#  'dripping',
#  'oxtail',
#  'pastrami',
#  'suet',
#  'sweetbread',
#  'tongue',
#  'tripe',
#  'veal',
#  'beef extract',
#  'beef stock',
#  'beef stock cube',
#  'amaranth',
#  'arugula',
#  'asparagus',
#  'basil',
#  'bay leaf',
#  'beetroot',
#  'bele',
#  'broccoli',
#  'brussels sprouts',
#  'cabbage',
#  'cauliflower',
#  'cauliflower rice',
#  'chard',
#  'chervil',
#  'chicory',
#  'coriander',
#  'dill',
#  'dried basil',
#  'dried coriander',
#  'endive',
#  'globe artichoke',
#  'kale',
#  'kimchi',
#  'lettuce',
#  'mache',
#  'marjoram',
#  'mint',
#  'mustard',
#  'oregano',
#  'pak choi',
#  'parsley',
#  'peppermint',
#  'pesto',
#  'raddiccio',
#  'rape leaves',
#  'rocket',
#  'rosemary',
#  'sage',
#  'salad',
#  'sauerkraut',
#  'spinach',
#  'spring green',
#  'tarragon',
#  'thyme',
#  'turnip',
#  'watercress',
#  'buffalo',
#  'butter',
#  'cream',
#  'crème fraiche',
#  'double cream',
#  'ghee',
#  'greek yogurt',
#  'mushroom sauce',
#  'natural yogurt',
#  'single cream',
#  'soured cream',
#  'yogurt',
#  'brown sugar',
#  'demerara sugar',
#  'jaggery',
#  'molasses',
#  'palm sugar',
#  'syrup',
#  'treacle',
#  'cassava',
#  'cassava flour',
#  'gari flour',
#  'sago',
#  'blue cheese',
#  'brie',
#  'caerphilly',
#  'camembert',
#  'cheddar',
#  'cheese',
#  'cottage cheese',
#  'cream cheese',
#  'danish blue',
#  'derby cheese',
#  'dolcelatte',
#  'double gloucester',
#  'edam',
#  'emmental',
#  'feta',
#  'fromage frais',
#  'goats cheese',
#  'gouda',
#  'grana padano',
#  'gruyere',
#  'halloumi',
#  'lancashire',
#  'mascarpone',
#  'monterey jack',
#  'mozzarella',
#  'paneer',
#  'parmesan',
#  'pecorino',
#  'port salut',
#  'quark',
#  'red leicester',
#  'red windsor',
#  'ricotta',
#  'roquefort',
#  'sage derby',
#  'stilton',
#  'wensleydale',
#  'grapefruit',
#  'lemon',
#  'lime',
#  'lime leaves',
#  'mandarin',
#  'mixed peel',
#  'nardicots',
#  'orange',
#  'ortaniques',
#  'coffee',
#  'tea',
#  'cockles',
#  'crab',
#  'crayfish',
#  'langoustine',
#  'lobster',
#  'mussel',
#  'oyster',
#  'prawn',
#  'shrimp',
#  'whelk',
#  'winkle',
#  'chocolate spread',
#  'cocoa',
#  'dark chocolate',
#  'drinking chocolate',
#  'milk chocolate',
#  'white chocolate',
#  'egg',
#  'egg noodle',
#  'egg pasta',
#  'mayonnaise',
#  'anchovy',
#  'boal',
#  'bream',
#  'calamari',
#  'chital',
#  'cod',
#  'cod roe',
#  'coley',
#  'dab',
#  'dogfish',
#  'dover sole',
#  'fish',
#  'fish sauce',
#  'fish stock',
#  'flounder',
#  'haddock',
#  'hake',
#  'halibut',
#  'hering roe',
#  'herring',
#  'hilsa',
#  'hoki',
#  'john dory',
#  'kalabasu',
#  'katla',
#  'kippers',
#  'lemon sole',
#  'ling',
#  'mackerel',
#  'monkfish',
#  'mullet',
#  'octopus',
#  'oyster sauce',
#  'pangasius',
#  'parrot fish',
#  'pilchard',
#  'plaice',
#  'pollock',
#  'pomfret',
#  'red snapper',
#  'redfish',
#  'rohu',
#  'sardine',
#  'scallops',
#  'seafood',
#  'shark',
#  'skate',
#  'sole',
#  'sprat',
#  'squid',
#  'swordfish',
#  'tuna',
#  'turbot',
#  'white fish',
#  'whitebait',
#  'whiting',
#  'bass',
#  'carp',
#  'catfish',
#  'caviar',
#  'cuttlefish',
#  'eel',
#  'salmon',
#  'tilapia',
#  'trout',
#  'apricot',
#  'arrowhead',
#  'avocado',
#  'babaco',
#  'breadfruit',
#  'breadnut',
#  'coconut',
#  'coconut cream',
#  'dried apricot',
#  'durian',
#  'feijoa',
#  'fig',
#  'grenadillas',
#  'guacamole',
#  'guava',
#  'jackfruit',
#  'jambu',
#  'jujube',
#  'kiwi',
#  'kumquats',
#  'longan',
#  'loquat',
#  'mango',
#  'mangosteen',
#  'medlar',
#  'melon',
#  'nectarine',
#  'papaya',
#  'passion fruit',
#  'peach',
#  'pineapple',
#  'plum',
#  'pomegranate',
#  'pomelo',
#  'prickly pear',
#  'prune',
#  'pumpkin',
#  'pumpkin seed',
#  'rambutan',
#  'sapodilla',
#  'sharon fruit',
#  'star fruit',
#  'tamarillo',
#  'tamarind',
#  'peanut',
#  'peanut butter',
#  'tigernut',
#  'goat',
#  'kidney',
#  'lamb',
#  'lamb stock',
#  'mutton',
#  'venison',
#  'corn flour',
#  'corn tortilla',
#  'cornflakes',
#  'cornmeal',
#  'polenta',
#  'semolina',
#  'sweetcorn',
#  'advocaat',
#  'buttermilk',
#  'condensed milk',
#  'custard',
#  'evaporated milk',
#  'milk',
#  'whey',
#  'almond',
#  'almond butter',
#  'almond milk',
#  'betel nut',
#  'brazil nut',
#  'cashew cream',
#  'cashew milk',
#  'cashew nut',
#  'chestnut',
#  'hazelnut',
#  'macadamia nut',
#  'marzipan',
#  'nougat',
#  'nut',
#  'nut loaf',
#  'pecan nut',
#  'pine nut',
#  'pistachio',
#  'poppy seed',
#  'seed',
#  'sesame seed',
#  'sunflower seed',
#  'tahini',
#  'walnut',
#  'water chestnut',
#  'oat',
#  'oat milk',
#  'porridge oat',
#  'coconut oil',
#  'grapeseed oil',
#  'groundnut oil',
#  'hazelnut oil',
#  'peanut oil',
#  'walnut oil',
#  'dressing',
#  'olive oil',
#  'truffle oil',
#  'allium',
#  'chives',
#  'fennel',
#  'garlic',
#  'leek',
#  'onion',
#  'shallot',
#  'spring onion',
#  'vegetable stock',
#  'vegetable stock cube',
#  'palm oil',
#  'pastry',
#  'shortening',
#  'mange-tout',
#  'pea',
#  'sugar snap peas',
#  'bacon',
#  'black pudding',
#  'brawn',
#  'chorizo',
#  'frankfurter',
#  'gelatine',
#  'ham',
#  'haslet',
#  'kabana',
#  'lard',
#  'liver',
#  'luncheon meat',
#  'meatball',
#  'pancetta',
#  'pepperoni',
#  'polony',
#  'pork',
#  'salami',
#  'sausage',
#  'saveloy',
#  'gnocchi',
#  'potato',
#  'sweet potato',
#  'chicken',
#  'chicken stock',
#  'chicken stock cube',
#  'duck',
#  'giblet',
#  'goose',
#  'grouse',
#  'hare',
#  'partridge',
#  'pheasant',
#  'pigeon',
#  'poussin',
#  'rabbit',
#  'turkey',
#  'aduki bean',
#  'alfalfa sprout',
#  'baked bean',
#  'balor bean',
#  'bean',
#  'black bean',
#  'black gram',
#  'blackeye bean',
#  'borlotti bean',
#  'broad bean',
#  'butter bean',
#  'cannellini bean',
#  'chickpea',
#  'chilki urad dahl',
#  'cluster bean',
#  'duhli urad dahl',
#  'edamame bean',
#  'gram flour',
#  'green bean',
#  'haricot bean',
#  'hummus',
#  'kidney bean',
#  'lentil',
#  'mung bean',
#  'papri bean',
#  'pigeon pea',
#  'pinto bean',
#  'runner bean',
#  'soya bean',
#  'soya flour',
#  'sword bean',
#  'urad gram',
#  'chili oil',
#  'corn oil',
#  'cottonseed oil',
#  'evening primrose oil',
#  'margarine',
#  'oil',
#  'rapeseed oil',
#  'safflower oil',
#  'vegetable oil',
#  'vegetable suet',
#  'wheatgerm oil',
#  'arborio rice',
#  'basmati rice',
#  'brown rice',
#  'brown rice syrup',
#  'carnaroli rice',
#  'crisp rice',
#  'jasmine rice',
#  'long-grain rice',
#  'paella rice',
#  'pilau rice',
#  'rice',
#  'rice flour',
#  'rice milk',
#  'rice noodle',
#  'risotto rice',
#  'sushi rice',
#  'white rice',
#  'wild rice',
#  'carrot',
#  'celeriac',
#  'ginger',
#  'ground ginger',
#  'horseradish',
#  'jerusalem artichoke',
#  'kohl rabi',
#  'liquorice',
#  'lotus',
#  'mooli',
#  'parsnip',
#  'radish',
#  'swede',
#  'tannia',
#  'tapioca',
#  'taro',
#  'yam',
#  'coconut milk',
#  'hoisin',
#  'liquid aminos',
#  'plant milk',
#  'soy sauce',
#  'soya milk',
#  'plant-based cream',
#  'plant-based egg',
#  'all purpose seasoning',
#  'anise seed',
#  "za'atar",
#  'baking powder',
#  'bicarbonate of soda',
#  'black pepper',
#  'cajun seasoning',
#  'caraway seeds',
#  'cardamon',
#  'coriander seed',
#  'cream of tartar',
#  'cumin',
#  'five-spice',
#  'garam masala',
#  'jerk seasoning',
#  'mace',
#  'nutmeg',
#  'saffron',
#  'salt',
#  'spice',
#  'star anise',
#  'truffles',
#  'turmeric',
#  'vanilla',
#  'sesame oil',
#  'sunflower oil',
#  'agar',
#  'agave',
#  'glucose',
#  'honey',
#  'maple syrup',
#  'miso',
#  'plant-based bacon',
#  'plant-based burger',
#  'plant-based cheese',
#  'plant-based chicken',
#  'plant-based ham',
#  'plant-based mayonnaise',
#  'plant-based meatball',
#  'plant-based mince',
#  'plant-based sausage',
#  'plant-based yogurt',
#  'quorn',
#  'quorn sausage',
#  'soya mince',
#  'tempeh',
#  'tofu',
#  'cherry tomato',
#  'passata',
#  'salsa',
#  'tomato',
#  'tomato ketchup',
#  'tomato puree',
#  'tomato sauce',
#  'ackee',
#  'acorn squash',
#  'allspice',
#  'asafoetida',
#  'aubergine',
#  'bamboo shoots',
#  'beansprouts',
#  'betel leaves',
#  'brown sauce',
#  'butternut squash',
#  'cayenne',
#  'celery',
#  'celery salt',
#  'chia seed',
#  'chili garlic sauce',
#  'chilli',
#  'chilli paste',
#  'chilli powder',
#  'chilli sauce',
#  'cho cho',
#  'cinnamon',
#  'cloves',
#  'courgette',
#  'cucumber',
#  'curry leaves',
#  'curry paste',
#  'curry powder',
#  'curry sauce',
#  'fenugreek leaves',
#  'fenugreek seeds',
#  'garlic ginger paste',
#  'garlic salt',
#  'gherkin',
#  'gochujang',
#  'gourd',
#  'harissa',
#  'kabsa',
#  'lemongrass',
#  'marrow',
#  'mixed herbs',
#  'molokhia',
#  'mushroom',
#  'nut roast',
#  'okra',
#  'olive',
#  'paprika',
#  'pepper',
#  'rhubarb',
#  'spaghetti squash',
#  'squash',
#  'summer squash',
#  'vegetable',
#  'vine leaves',
#  'wasabi',
#  'bran',
#  'sourdough',
#  'bread',
#  'buckwheat',
#  'buckwheat flour',
#  'buckwheat noodle',
#  'bulgur wheat',
#  'chapati flour',
#  'couscous',
#  'dough',
#  'flour',
#  'flour tortilla',
#  'gravy granules',
#  'millet flour',
#  'naan bread',
#  'pasta',
#  'pearl barley',
#  'quinoa',
#  'rusk',
#  'rye flour',
#  'seitan',
#  'shredded wheat',
#  'spaghetti',
#  'wheat flour',
#  'wheat noodle',
#  'wheatgerm',
#  'brandy',
#  'curacao',
#  'gin',
#  'mirin',
#  'port',
#  'sake',
#  'sherry',
#  'vermouth',
#  'vinegar',
#  'whiskey',
#  'wine',
#  'worcestershire sauce',
#  'water']

# %% [markdown]
# # Construct triplets

# %%
def get_negative_examples(triplet):
    anchor = triplet.anchor.matched
    pos = triplet.pos.matched
    orig = [anchor, pos]
    used_negs = []

    while True:
        neg = random.choice(KB_ingreds)
        if(neg not in orig and neg not in used_negs):
            used_negs.append(neg)
        if(len(used_negs) == NEGATIVE_PER_PAIR):
            break
    
    newTriplets = []
    for neg in used_negs:
        newTriplet = triplet.getDeepCopy()
        newTriplet.neg = Ingredient(
            matched=neg
        )
        newTriplets.append(newTriplet)
    return newTriplets

# %%
def replace_source_ingrd_with_target(text, source, target):

    # Separate recipe name
    name_index = text.find(':')
    recipe_name = text[0:name_index + 1]
    text_instruction_only = text[name_index + 1:]

    # Apply temp string
    for source_word in source.split(' '):
        text_instruction_only = text_instruction_only.replace(source_word, "TEMP_STRING")
    
    text = recipe_name + text_instruction_only
    
    # Remove white spaces between temp string
    text = re.sub(re.compile(r'TEMP_STRING+(?:\sTEMP_STRING+)*'), target, text)
    return text

# # Example usage
# text = "This is ground beef with a bit of lean beef"
# source = "lean ground beef"
# target = "raw chicken"

# new_text = replace_source_ingrd_with_target(text, source, target)
# print(new_text)

# %%
validTripletPoints = list()

for tripletPoint in list(tripletPoints):
    currRecipeId = tripletPoint.recipe_id
    currRecipe = recipeJsons[f'{currRecipeId}']
    rawAnchor = tripletPoint.anchor.rawName
    
    instructions = []
    try:
        instructions = currRecipe['instructions']
    except:
        print(f'Recipe with id {currRecipeId} has no instructions! Skipping...')
        continue
    
    if(len(instructions) == 0):
        print(f'Recipe with id {currRecipeId} has no instructions! Skipping...')
        continue

    currRecipeName = currRecipe['title']

    sentenceCandidates = []
    for instruction in currRecipe['instructions']:
        instruction = instruction['instruction']
        # An instruction may contain multiple 
        sentenceCandidates.extend(nltk.sent_tokenize(instruction))

    best_sent_index = get_most_relevant_sentence_index(rawAnchor, sentenceCandidates)

    # If can't choose best sentence, skip
    if(best_sent_index == -1):
        print(f'Can\'t choose best sentence in recipe with id {currRecipeId}! Skipping...')
        continue

    # Add recipe name
    sentenceCandidates = [f'{currRecipeName}: {sent}' for sent in sentenceCandidates]
    
    # Save anchor sentence
    anchorSent = sentenceCandidates[best_sent_index]
    tripletPoint.anchor.rawRecipeText = anchorSent

    # Construct pos sentence and save
    posSent = replace_source_ingrd_with_target(anchorSent, rawAnchor, tripletPoint.pos.rawName.lower())
    tripletPoint.pos.rawRecipeText = posSent
    
    # Add neg examples
    newTriplets = get_negative_examples(tripletPoint)
    for newTriplet in newTriplets:
        # Construct neg sentence and save
        negSent = replace_source_ingrd_with_target(anchorSent, rawAnchor, newTriplet.neg.matched.lower())
        
        newTriplet.anchor.rawRecipeText = anchorSent
        newTriplet.pos.rawRecipeText = posSent
        newTriplet.neg.rawRecipeText = negSent
        validTripletPoints.append(newTriplet)
    
    print(anchorSent, rawAnchor)
print(f'Constructed {len(validTripletPoints)} valid triplets.')
# Out:
# Can't choose best sentence in recipe with id 423! Skipping...
# Can't choose best sentence in recipe with id 424! Skipping...
# Can't choose best sentence in recipe with id 137! Skipping...
# Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside coconut rice. fat coconut milk
# Classic jacket potatoes: Cut a cross on top of each potato, squeeze the sides, add the soured cream and your favourite toppings. soured cream
# Chinese Vegetable Stir-Fry: Add the broccoli and cook for 2-3 minutes, or until tender-crisp. broccoli
# Homemade Vegetarian Chili: Add the diced tomatoes and their juices, the drained black beans and pinto beans, vegetable broth and bay leaf. black beans
# Crispy Sesame Chicken with a Sticky Asian Sauce: Add the chicken back in and toss in the sauce to coat. chicken breast fillets
# Kale, tofu, mushroom and quinoa protein bowl: Rinse the cooked kale with ice-cold water and drain well, set aside. cooked tri-colour quinoa
# Creamy Garlic Herb Mushroom Spaghetti: Add the milk slowly, whisking to incorporate. milk
# Green beans & mushrooms with tangy soy dressing: Pour over the beans and toss gently. French green beans
# Dumpling Wrapper Bun with juicy filling: Prepare the zucchini and filling zucchini
# Simple veggie & tofu stir-fry: Cut the tofu into cubes, then place in a bowl and dust with the cornflour and a pinch of sea salt and black pepper. firm tofu
# Chilli con carne recipe: Add the onion and cook, stirring fairly frequently, for about 5 minutes, or until the onion is soft, squidgy and slightly translucent.STEP 5Tip in the garlic, red pepper, 1 heaped tsp hot chilli powder or 1 level tbsp mild chilli powder, 1 tsp paprika and 1 tsp ground cumin.STEP 6Give it a good stir, then leave it to cook for another 5 minutes, stirring occasionally.STEP 7Brown 500g lean minced beef. lean minced beef
# Lasagne: Tip in the beef and pork mince, the milk and chopped tomatoes. beef mince
# Tortilla de Patatas: Add olive oil to a large skillet over medium heat. extra virgin olive oil
# Can't choose best sentence in recipe with id 424! Skipping...
# Shockingly Easy No-Knead Focaccia: Add 5 cups (625 g) all-purpose flour and 5 tsp. all-purpose flour
# Can't choose best sentence in recipe with id 503! Skipping...
# Recipe with id 561 has no instructions! Skipping...
# Can't choose best sentence in recipe with id 470! Skipping...
# Mexican Chicken Tinga: When the chicken is cooked, set aside. chicken breast
# Scottish Oat Cakes: Add the butter and rub together until everything is mixed and has the consistency of large bread crumbs. butter
# Can't choose best sentence in recipe with id 99! Skipping...
# Jerk Cod with Avocado and Corn Salsa: Gently break the cod into chunks and serve with the salsa and lime wedges. skinless cod fillet
# Easy sausage casserole: Add 6 chorizo sausages and 6 pork sausages and fry for 5 minutes. pork sausages
# Mushroom Leek Stroganoff: Cook the pasta according to the package instructions. pasta
# Home-style chicken curry: Cook for 5 mins to coat the chicken in the masala and seal in the juices, and then pour over 250ml hot chicken stock. chicken thighs
# Creamy Garlic Herb Mushroom Spaghetti: Melt 2 tablespoons of butter over medium high heat. butter
# Ultimate spaghetti carbonara: Keep the heat under the pancetta on low. pancetta
# Wild Mushroom Risotto: Gently stir in heavy cream and parmesan cheese and cook for an additional 5 min on low heat grated parmesan cheese
: 579
#  anchor: (Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside coconut rice., fat coconut milk, Coconut milk)
#  pos: (Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside  oat yoghurt rice.,  oat yoghurt, Plant-based yogurt)
#  neg: (Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside agave rice., None, agave),
#  id: 579
#  anchor: (Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside coconut rice., fat coconut milk, Coconut milk)
#  pos: (Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside  oat yoghurt rice.,  oat yoghurt, Plant-based yogurt)
#  neg: (Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside lemon sole rice., None, lemon sole),
#  id: 579
#  anchor: (Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside coconut rice., fat coconut milk, Coconut milk)
#  pos: (Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside  oat yoghurt rice.,  oat yoghurt, Plant-based yogurt)
#  neg: (Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside betel leaves rice., None, betel leaves),
#  id: 579
#  anchor: (Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside coconut rice., fat coconut milk, Coconut milk)
#  pos: (Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside  oat yoghurt rice.,  oat yoghurt, Plant-based yogurt)
#  neg: (Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside tofu rice., None, tofu),
#  id: 579
#  anchor: (Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside coconut rice., fat coconut milk, Coconut milk)
#  pos: (Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside  oat yoghurt rice.,  oat yoghurt, Plant-based yogurt)
#  neg: (Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside halloumi rice., None, halloumi),
#  id: 579
#  anchor: (Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside coconut rice., fat coconut milk, Coconut milk)
#  pos: (Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside  oat yoghurt rice.,  oat yoghurt, Plant-based yogurt)
#  neg: (Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside breadnut rice., None, breadnut),
#  id: 579
#  anchor: (Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside coconut rice., fat coconut milk, Coconut milk)
#  pos: (Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside  oat yoghurt rice.,  oat yoghurt, Plant-based yogurt)
#  neg: (Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside feta rice., None, feta),
#  id: 579
#  anchor: (Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside coconut rice., fat coconut milk, Coconut milk)
#  pos: (Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside  oat yoghurt rice.,  oat yoghurt, Plant-based yogurt)
#  neg: (Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside alfalfa sprout rice., None, alfalfa sprout),
#  id: 579
#  anchor: (Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside coconut rice., fat coconut milk, Coconut milk)
#  pos: (Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside  oat yoghurt rice.,  oat yoghurt, Plant-based yogurt)
#  neg: (Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside squid rice., None, squid),
#  id: 579
#  anchor: (Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside coconut rice., fat coconut milk, Coconut milk)
#  pos: (Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside  oat yoghurt rice.,  oat yoghurt, Plant-based yogurt)
#  neg: (Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside whitebait rice., None, whitebait),
#  id: 424
#  anchor: (Classic jacket potatoes: Cut a cross on top of each potato, squeeze the sides, add the soured cream and your favourite toppings., soured cream, Soured cream)
#  pos: (Classic jacket potatoes: Cut a cross on top of each potato, squeeze the sides, add the cream and your favourite toppings., Cream, Cream)
#  neg: (Classic jacket potatoes: Cut a cross on top of each potato, squeeze the sides, add the ground ginger and your favourite toppings., None, ground ginger),
#  id: 424
#  anchor: (Classic jacket potatoes: Cut a cross on top of each potato, squeeze the sides, add the soured cream and your favourite toppings., soured cream, Soured cream)
#  pos: (Classic jacket potatoes: Cut a cross on top of each potato, squeeze the sides, add the cream and your favourite toppings., Cream, Cream)
#  neg: (Classic jacket potatoes: Cut a cross on top of each potato, squeeze the sides, add the jam and your favourite toppings., None, jam),
#  id: 424
#  anchor: (Classic jacket potatoes: Cut a cross on top of each potato, squeeze the sides, add the soured cream and your favourite toppings., soured cream, Soured cream)
#  pos: (Classic jacket potatoes: Cut a cross on top of each potato, squeeze the sides, add the cream and your favourite toppings., Cream, Cream)
#  neg: (Classic jacket potatoes: Cut a cross on top of each potato, squeeze the sides, add the yogurt and your favourite toppings., None, yogurt),
#  id: 424
#  anchor: (Classic jacket potatoes: Cut a cross on top of each potato, squeeze the sides, add the soured cream and your favourite toppings., soured cream, Soured cream)
#  pos: (Classic jacket potatoes: Cut a cross on top of each potato, squeeze the sides, add the cream and your favourite toppings., Cream, Cream)
#  neg: (Classic jacket potatoes: Cut a cross on top of each potato, squeeze the sides, add the cornmeal and your favourite toppings., None, cornmeal),
#  id: 424
#  anchor: (Classic jacket potatoes: Cut a cross on top of each potato, squeeze the sides, add the soured cream and your favourite toppings., soured cream, Soured cream)
#  pos: (Classic jacket potatoes: Cut a cross on top of each potato, squeeze the sides, add the cream and your favourite toppings., Cream, Cream)
#  neg: (Classic jacket potatoes: Cut a cross on top of each potato, squeeze the sides, add the coconut cream and your favourite toppings., None, coconut cream),
#  id: 424
#  anchor: (Classic jacket potatoes: Cut a cross on top of each potato, squeeze the sides, add the soured cream and your favourite toppings., soured cream, Soured cream)
#  pos: (Classic jacket potatoes: Cut a cross on top of each potato, squeeze the sides, add the cream and your favourite toppings., Cream, Cream)
#  neg: (Classic jacket potatoes: Cut a cross on top of each potato, squeeze the sides, add the tomato puree and your favourite toppings., None, tomato puree),
#  id: 424
#  anchor: (Classic jacket potatoes: Cut a cross on top of each potato, squeeze the sides, add the soured cream and your favourite toppings., soured cream, Soured cream)
#  pos: (Classic jacket potatoes: Cut a cross on top of each potato, squeeze the sides, add the cream and your favourite toppings., Cream, Cream)
#  neg: (Classic jacket potatoes: Cut a cross on top of each potato, squeeze the sides, add the plantain and your favourite toppings., None, plantain),
#  id: 424
#  anchor: (Classic jacket potatoes: Cut a cross on top of each potato, squeeze the sides, add the soured cream and your favourite toppings., soured cream, Soured cream)
#  pos: (Classic jacket potatoes: Cut a cross on top of each potato, squeeze the sides, add the cream and your favourite toppings., Cream, Cream)
#  neg: (Classic jacket potatoes: Cut a cross on top of each potato, squeeze the sides, add the leek and your favourite toppings., None, leek),
#  id: 424
#  anchor: (Classic jacket potatoes: Cut a cross on top of each potato, squeeze the sides, add the soured cream and your favourite toppings., soured cream, Soured cream)
#  pos: (Classic jacket potatoes: Cut a cross on top of each potato, squeeze the sides, add the cream and your favourite toppings., Cream, Cream)
#  neg: (Classic jacket potatoes: Cut a cross on top of each potato, squeeze the sides, add the kabsa and your favourite toppings., None, kabsa),
#  id: 424
#  anchor: (Classic jacket potatoes: Cut a cross on top of each potato, squeeze the sides, add the soured cream and your favourite toppings., soured cream, Soured cream)
#  pos: (Classic jacket potatoes: Cut a cross on top of each potato, squeeze the sides, add the cream and your favourite toppings., Cream, Cream)
#  neg: (Classic jacket potatoes: Cut a cross on top of each potato, squeeze the sides, add the agave and your favourite toppings., None, agave),
#  id: 97
#  anchor: (Chinese Vegetable Stir-Fry: Add the broccoli and cook for 2-3 minutes, or until tender-crisp., broccoli, Broccoli)
#  pos: (Chinese Vegetable Stir-Fry: Add the  seasonal green beans and cook for 2-3 minutes, or until tender-crisp.,  seasonal green beans, Green bean)
#  neg: (Chinese Vegetable Stir-Fry: Add the pecan nut and cook for 2-3 minutes, or until tender-crisp., None, pecan nut),
#  id: 97
#  anchor: (Chinese Vegetable Stir-Fry: Add the broccoli and cook for 2-3 minutes, or until tender-crisp., broccoli, Broccoli)
#  pos: (Chinese Vegetable Stir-Fry: Add the  seasonal green beans and cook for 2-3 minutes, or until tender-crisp.,  seasonal green beans, Green bean)
#  neg: (Chinese Vegetable Stir-Fry: Add the cho cho and cook for 2-3 minutes, or until tender-crisp., None, cho cho),
#  id: 97
#  anchor: (Chinese Vegetable Stir-Fry: Add the broccoli and cook for 2-3 minutes, or until tender-crisp., broccoli, Broccoli)
#  pos: (Chinese Vegetable Stir-Fry: Add the  seasonal green beans and cook for 2-3 minutes, or until tender-crisp.,  seasonal green beans, Green bean)
#  neg: (Chinese Vegetable Stir-Fry: Add the curry sauce and cook for 2-3 minutes, or until tender-crisp., None, curry sauce),
#  id: 97
#  anchor: (Chinese Vegetable Stir-Fry: Add the broccoli and cook for 2-3 minutes, or until tender-crisp., broccoli, Broccoli)
#  pos: (Chinese Vegetable Stir-Fry: Add the  seasonal green beans and cook for 2-3 minutes, or until tender-crisp.,  seasonal green beans, Green bean)
#  neg: (Chinese Vegetable Stir-Fry: Add the polenta and cook for 2-3 minutes, or until tender-crisp., None, polenta),
#  id: 97
#  anchor: (Chinese Vegetable Stir-Fry: Add the broccoli and cook for 2-3 minutes, or until tender-crisp., broccoli, Broccoli)
#  pos: (Chinese Vegetable Stir-Fry: Add the  seasonal green beans and cook for 2-3 minutes, or until tender-crisp.,  seasonal green beans, Green bean)
#  neg: (Chinese Vegetable Stir-Fry: Add the sesame oil and cook for 2-3 minutes, or until tender-crisp., None, sesame oil),
#  id: 97
#  anchor: (Chinese Vegetable Stir-Fry: Add the broccoli and cook for 2-3 minutes, or until tender-crisp., broccoli, Broccoli)
#  pos: (Chinese Vegetable Stir-Fry: Add the  seasonal green beans and cook for 2-3 minutes, or until tender-crisp.,  seasonal green beans, Green bean)
#  neg: (Chinese Vegetable Stir-Fry: Add the tarragon and cook for 2-3 minutes, or until tender-crisp., None, tarragon),
#  id: 97
#  anchor: (Chinese Vegetable Stir-Fry: Add the broccoli and cook for 2-3 minutes, or until tender-crisp., broccoli, Broccoli)
#  pos: (Chinese Vegetable Stir-Fry: Add the  seasonal green beans and cook for 2-3 minutes, or until tender-crisp.,  seasonal green beans, Green bean)
#  neg: (Chinese Vegetable Stir-Fry: Add the lime and cook for 2-3 minutes, or until tender-crisp., None, lime),
#  id: 97
#  anchor: (Chinese Vegetable Stir-Fry: Add the broccoli and cook for 2-3 minutes, or until tender-crisp., broccoli, Broccoli)
#  pos: (Chinese Vegetable Stir-Fry: Add the  seasonal green beans and cook for 2-3 minutes, or until tender-crisp.,  seasonal green beans, Green bean)
#  neg: (Chinese Vegetable Stir-Fry: Add the margarine and cook for 2-3 minutes, or until tender-crisp., None, margarine),
#  id: 97
#  anchor: (Chinese Vegetable Stir-Fry: Add the broccoli and cook for 2-3 minutes, or until tender-crisp., broccoli, Broccoli)
#  pos: (Chinese Vegetable Stir-Fry: Add the  seasonal green beans and cook for 2-3 minutes, or until tender-crisp.,  seasonal green beans, Green bean)
#  neg: (Chinese Vegetable Stir-Fry: Add the plant-based cream and cook for 2-3 minutes, or until tender-crisp., None, plant-based cream),
#  id: 97
#  anchor: (Chinese Vegetable Stir-Fry: Add the broccoli and cook for 2-3 minutes, or until tender-crisp., broccoli, Broccoli)
#  pos: (Chinese Vegetable Stir-Fry: Add the  seasonal green beans and cook for 2-3 minutes, or until tender-crisp.,  seasonal green beans, Green bean)
#  neg: (Chinese Vegetable Stir-Fry: Add the summer squash and cook for 2-3 minutes, or until tender-crisp., None, summer squash),
#  id: 425
#  anchor: (Homemade Vegetarian Chili: Add the diced tomatoes and their juices, the drained black beans and pinto beans, vegetable broth and bay leaf., black beans, Black bean)
#  pos: (Homemade Vegetarian Chili: Add the diced tomatoes and their juices, the drained chick peas and pinto chick peas, vegetable broth and bay leaf., Chick peas, Chickpea)
#  neg: (Homemade Vegetarian Chili: Add the diced tomatoes and their juices, the drained lime leaves and pinto lime leaves, vegetable broth and bay leaf., None, lime leaves),
#  id: 425
#  anchor: (Homemade Vegetarian Chili: Add the diced tomatoes and their juices, the drained black beans and pinto beans, vegetable broth and bay leaf., black beans, Black bean)
#  pos: (Homemade Vegetarian Chili: Add the diced tomatoes and their juices, the drained chick peas and pinto chick peas, vegetable broth and bay leaf., Chick peas, Chickpea)
#  neg: (Homemade Vegetarian Chili: Add the diced tomatoes and their juices, the drained eel and pinto eel, vegetable broth and bay leaf., None, eel),
#  id: 425
#  anchor: (Homemade Vegetarian Chili: Add the diced tomatoes and their juices, the drained black beans and pinto beans, vegetable broth and bay leaf., black beans, Black bean)
#  pos: (Homemade Vegetarian Chili: Add the diced tomatoes and their juices, the drained chick peas and pinto chick peas, vegetable broth and bay leaf., Chick peas, Chickpea)
#  neg: (Homemade Vegetarian Chili: Add the diced tomatoes and their juices, the drained jambu and pinto jambu, vegetable broth and bay leaf., None, jambu),
#  id: 425
#  anchor: (Homemade Vegetarian Chili: Add the diced tomatoes and their juices, the drained black beans and pinto beans, vegetable broth and bay leaf., black beans, Black bean)
#  pos: (Homemade Vegetarian Chili: Add the diced tomatoes and their juices, the drained chick peas and pinto chick peas, vegetable broth and bay leaf., Chick peas, Chickpea)
#  neg: (Homemade Vegetarian Chili: Add the diced tomatoes and their juices, the drained catfish and pinto catfish, vegetable broth and bay leaf., None, catfish),
#  id: 425
#  anchor: (Homemade Vegetarian Chili: Add the diced tomatoes and their juices, the drained black beans and pinto beans, vegetable broth and bay leaf., black beans, Black bean)
#  pos: (Homemade Vegetarian Chili: Add the diced tomatoes and their juices, the drained chick peas and pinto chick peas, vegetable broth and bay leaf., Chick peas, Chickpea)
#  neg: (Homemade Vegetarian Chili: Add the diced tomatoes and their juices, the drained corn tortilla and pinto corn tortilla, vegetable broth and bay leaf., None, corn tortilla),
#  id: 425
#  anchor: (Homemade Vegetarian Chili: Add the diced tomatoes and their juices, the drained black beans and pinto beans, vegetable broth and bay leaf., black beans, Black bean)
#  pos: (Homemade Vegetarian Chili: Add the diced tomatoes and their juices, the drained chick peas and pinto chick peas, vegetable broth and bay leaf., Chick peas, Chickpea)
#  neg: (Homemade Vegetarian Chili: Add the diced tomatoes and their juices, the drained octopus and pinto octopus, vegetable broth and bay leaf., None, octopus),
#  id: 425
#  anchor: (Homemade Vegetarian Chili: Add the diced tomatoes and their juices, the drained black beans and pinto beans, vegetable broth and bay leaf., black beans, Black bean)
#  pos: (Homemade Vegetarian Chili: Add the diced tomatoes and their juices, the drained chick peas and pinto chick peas, vegetable broth and bay leaf., Chick peas, Chickpea)
#  neg: (Homemade Vegetarian Chili: Add the diced tomatoes and their juices, the drained harissa and pinto harissa, vegetable broth and bay leaf., None, harissa),
#  id: 425
#  anchor: (Homemade Vegetarian Chili: Add the diced tomatoes and their juices, the drained black beans and pinto beans, vegetable broth and bay leaf., black beans, Black bean)
#  pos: (Homemade Vegetarian Chili: Add the diced tomatoes and their juices, the drained chick peas and pinto chick peas, vegetable broth and bay leaf., Chick peas, Chickpea)
#  neg: (Homemade Vegetarian Chili: Add the diced tomatoes and their juices, the drained raddiccio and pinto raddiccio, vegetable broth and bay leaf., None, raddiccio),
#  id: 425
#  anchor: (Homemade Vegetarian Chili: Add the diced tomatoes and their juices, the drained black beans and pinto beans, vegetable broth and bay leaf., black beans, Black bean)
#  pos: (Homemade Vegetarian Chili: Add the diced tomatoes and their juices, the drained chick peas and pinto chick peas, vegetable broth and bay leaf., Chick peas, Chickpea)
#  neg: (Homemade Vegetarian Chili: Add the diced tomatoes and their juices, the drained caviar and pinto caviar, vegetable broth and bay leaf., None, caviar),
#  id: 425
#  anchor: (Homemade Vegetarian Chili: Add the diced tomatoes and their juices, the drained black beans and pinto beans, vegetable broth and bay leaf., black beans, Black bean)
#  pos: (Homemade Vegetarian Chili: Add the diced tomatoes and their juices, the drained chick peas and pinto chick peas, vegetable broth and bay leaf., Chick peas, Chickpea)
#  neg: (Homemade Vegetarian Chili: Add the diced tomatoes and their juices, the drained fennel and pinto fennel, vegetable broth and bay leaf., None, fennel),
#  id: 350
#  anchor: (Crispy Sesame Chicken with a Sticky Asian Sauce: Add the chicken back in and toss in the sauce to coat., chicken breast fillets, Chicken:Fillet)
#  pos: (Crispy Sesame Chicken with a Sticky Asian Sauce: Add the quorn cocktail sausages back in and toss in the sauce to coat., Quorn cocktail sausages, Quorn sausage)
#  neg: (Crispy Sesame Chicken with a Sticky Asian Sauce: Add the mascarpone back in and toss in the sauce to coat., None, mascarpone),
#  id: 350
#  anchor: (Crispy Sesame Chicken with a Sticky Asian Sauce: Add the chicken back in and toss in the sauce to coat., chicken breast fillets, Chicken:Fillet)
#  pos: (Crispy Sesame Chicken with a Sticky Asian Sauce: Add the quorn cocktail sausages back in and toss in the sauce to coat., Quorn cocktail sausages, Quorn sausage)
#  neg: (Crispy Sesame Chicken with a Sticky Asian Sauce: Add the haricot bean back in and toss in the sauce to coat., None, haricot bean),
#  id: 350
#  anchor: (Crispy Sesame Chicken with a Sticky Asian Sauce: Add the chicken back in and toss in the sauce to coat., chicken breast fillets, Chicken:Fillet)
#  pos: (Crispy Sesame Chicken with a Sticky Asian Sauce: Add the quorn cocktail sausages back in and toss in the sauce to coat., Quorn cocktail sausages, Quorn sausage)
#  neg: (Crispy Sesame Chicken with a Sticky Asian Sauce: Add the cauliflower back in and toss in the sauce to coat., None, cauliflower),
#  id: 350
#  anchor: (Crispy Sesame Chicken with a Sticky Asian Sauce: Add the chicken back in and toss in the sauce to coat., chicken breast fillets, Chicken:Fillet)
#  pos: (Crispy Sesame Chicken with a Sticky Asian Sauce: Add the quorn cocktail sausages back in and toss in the sauce to coat., Quorn cocktail sausages, Quorn sausage)
#  neg: (Crispy Sesame Chicken with a Sticky Asian Sauce: Add the vegetable stock back in and toss in the sauce to coat., None, vegetable stock),
#  id: 350
#  anchor: (Crispy Sesame Chicken with a Sticky Asian Sauce: Add the chicken back in and toss in the sauce to coat., chicken breast fillets, Chicken:Fillet)
#  pos: (Crispy Sesame Chicken with a Sticky Asian Sauce: Add the quorn cocktail sausages back in and toss in the sauce to coat., Quorn cocktail sausages, Quorn sausage)
#  neg: (Crispy Sesame Chicken with a Sticky Asian Sauce: Add the bream back in and toss in the sauce to coat., None, bream),
#  id: 350
#  anchor: (Crispy Sesame Chicken with a Sticky Asian Sauce: Add the chicken back in and toss in the sauce to coat., chicken breast fillets, Chicken:Fillet)
#  pos: (Crispy Sesame Chicken with a Sticky Asian Sauce: Add the quorn cocktail sausages back in and toss in the sauce to coat., Quorn cocktail sausages, Quorn sausage)
#  neg: (Crispy Sesame Chicken with a Sticky Asian Sauce: Add the sourdough back in and toss in the sauce to coat., None, sourdough),
#  id: 350
#  anchor: (Crispy Sesame Chicken with a Sticky Asian Sauce: Add the chicken back in and toss in the sauce to coat., chicken breast fillets, Chicken:Fillet)
#  pos: (Crispy Sesame Chicken with a Sticky Asian Sauce: Add the quorn cocktail sausages back in and toss in the sauce to coat., Quorn cocktail sausages, Quorn sausage)
#  neg: (Crispy Sesame Chicken with a Sticky Asian Sauce: Add the brazil nut back in and toss in the sauce to coat., None, brazil nut),
#  id: 350
#  anchor: (Crispy Sesame Chicken with a Sticky Asian Sauce: Add the chicken back in and toss in the sauce to coat., chicken breast fillets, Chicken:Fillet)
#  pos: (Crispy Sesame Chicken with a Sticky Asian Sauce: Add the quorn cocktail sausages back in and toss in the sauce to coat., Quorn cocktail sausages, Quorn sausage)
#  neg: (Crispy Sesame Chicken with a Sticky Asian Sauce: Add the nutritional yeast back in and toss in the sauce to coat., None, nutritional yeast),
#  id: 350
#  anchor: (Crispy Sesame Chicken with a Sticky Asian Sauce: Add the chicken back in and toss in the sauce to coat., chicken breast fillets, Chicken:Fillet)
#  pos: (Crispy Sesame Chicken with a Sticky Asian Sauce: Add the quorn cocktail sausages back in and toss in the sauce to coat., Quorn cocktail sausages, Quorn sausage)
#  neg: (Crispy Sesame Chicken with a Sticky Asian Sauce: Add the basmati rice back in and toss in the sauce to coat., None, basmati rice),
#  id: 350
#  anchor: (Crispy Sesame Chicken with a Sticky Asian Sauce: Add the chicken back in and toss in the sauce to coat., chicken breast fillets, Chicken:Fillet)
#  pos: (Crispy Sesame Chicken with a Sticky Asian Sauce: Add the quorn cocktail sausages back in and toss in the sauce to coat., Quorn cocktail sausages, Quorn sausage)
#  neg: (Crispy Sesame Chicken with a Sticky Asian Sauce: Add the acorn squash back in and toss in the sauce to coat., None, acorn squash),
#  id: 259
#  anchor: (Kale, tofu, mushroom and quinoa protein bowl: Rinse the cooked kale with ice-cold water and drain well, set aside., cooked tri-colour quinoa, Quinoa)
#  pos: (Kale, tofu, mushroom and quinoa protein bowl: Rinse the barley kale with ice-cold water and drain well, set aside., Barley, Pearl barley)
#  neg: (Kale, tofu, mushroom and quinoa protein bowl: Rinse the seafood kale with ice-cold water and drain well, set aside., None, seafood),
#  id: 259
#  anchor: (Kale, tofu, mushroom and quinoa protein bowl: Rinse the cooked kale with ice-cold water and drain well, set aside., cooked tri-colour quinoa, Quinoa)
#  pos: (Kale, tofu, mushroom and quinoa protein bowl: Rinse the barley kale with ice-cold water and drain well, set aside., Barley, Pearl barley)
#  neg: (Kale, tofu, mushroom and quinoa protein bowl: Rinse the cinnamon kale with ice-cold water and drain well, set aside., None, cinnamon),
#  id: 259
#  anchor: (Kale, tofu, mushroom and quinoa protein bowl: Rinse the cooked kale with ice-cold water and drain well, set aside., cooked tri-colour quinoa, Quinoa)
#  pos: (Kale, tofu, mushroom and quinoa protein bowl: Rinse the barley kale with ice-cold water and drain well, set aside., Barley, Pearl barley)
#  neg: (Kale, tofu, mushroom and quinoa protein bowl: Rinse the custard kale with ice-cold water and drain well, set aside., None, custard),
#  id: 259
#  anchor: (Kale, tofu, mushroom and quinoa protein bowl: Rinse the cooked kale with ice-cold water and drain well, set aside., cooked tri-colour quinoa, Quinoa)
#  pos: (Kale, tofu, mushroom and quinoa protein bowl: Rinse the barley kale with ice-cold water and drain well, set aside., Barley, Pearl barley)
#  neg: (Kale, tofu, mushroom and quinoa protein bowl: Rinse the sharon fruit kale with ice-cold water and drain well, set aside., None, sharon fruit),
#  id: 259
#  anchor: (Kale, tofu, mushroom and quinoa protein bowl: Rinse the cooked kale with ice-cold water and drain well, set aside., cooked tri-colour quinoa, Quinoa)
#  pos: (Kale, tofu, mushroom and quinoa protein bowl: Rinse the barley kale with ice-cold water and drain well, set aside., Barley, Pearl barley)
#  neg: (Kale, tofu, mushroom and quinoa protein bowl: Rinse the walnut oil kale with ice-cold water and drain well, set aside., None, walnut oil),
#  id: 259
#  anchor: (Kale, tofu, mushroom and quinoa protein bowl: Rinse the cooked kale with ice-cold water and drain well, set aside., cooked tri-colour quinoa, Quinoa)
#  pos: (Kale, tofu, mushroom and quinoa protein bowl: Rinse the barley kale with ice-cold water and drain well, set aside., Barley, Pearl barley)
#  neg: (Kale, tofu, mushroom and quinoa protein bowl: Rinse the vine leaves kale with ice-cold water and drain well, set aside., None, vine leaves),
#  id: 259
#  anchor: (Kale, tofu, mushroom and quinoa protein bowl: Rinse the cooked kale with ice-cold water and drain well, set aside., cooked tri-colour quinoa, Quinoa)
#  pos: (Kale, tofu, mushroom and quinoa protein bowl: Rinse the barley kale with ice-cold water and drain well, set aside., Barley, Pearl barley)
#  neg: (Kale, tofu, mushroom and quinoa protein bowl: Rinse the tahini kale with ice-cold water and drain well, set aside., None, tahini),
#  id: 259
#  anchor: (Kale, tofu, mushroom and quinoa protein bowl: Rinse the cooked kale with ice-cold water and drain well, set aside., cooked tri-colour quinoa, Quinoa)
#  pos: (Kale, tofu, mushroom and quinoa protein bowl: Rinse the barley kale with ice-cold water and drain well, set aside., Barley, Pearl barley)
#  neg: (Kale, tofu, mushroom and quinoa protein bowl: Rinse the dill kale with ice-cold water and drain well, set aside., None, dill),
#  id: 259
#  anchor: (Kale, tofu, mushroom and quinoa protein bowl: Rinse the cooked kale with ice-cold water and drain well, set aside., cooked tri-colour quinoa, Quinoa)
#  pos: (Kale, tofu, mushroom and quinoa protein bowl: Rinse the barley kale with ice-cold water and drain well, set aside., Barley, Pearl barley)
#  neg: (Kale, tofu, mushroom and quinoa protein bowl: Rinse the turnip kale with ice-cold water and drain well, set aside., None, turnip),
#  id: 259
#  anchor: (Kale, tofu, mushroom and quinoa protein bowl: Rinse the cooked kale with ice-cold water and drain well, set aside., cooked tri-colour quinoa, Quinoa)
#  pos: (Kale, tofu, mushroom and quinoa protein bowl: Rinse the barley kale with ice-cold water and drain well, set aside., Barley, Pearl barley)
#  neg: (Kale, tofu, mushroom and quinoa protein bowl: Rinse the prune kale with ice-cold water and drain well, set aside., None, prune),
#  id: 565
#  anchor: (Creamy Garlic Herb Mushroom Spaghetti: Add the milk slowly, whisking to incorporate., milk, Milk)
#  pos: (Creamy Garlic Herb Mushroom Spaghetti: Add the oat milk slowly, whisking to incorporate., oat milk, Oat milk)
#  neg: (Creamy Garlic Herb Mushroom Spaghetti: Add the cheddar slowly, whisking to incorporate., None, cheddar),
#  id: 565
#  anchor: (Creamy Garlic Herb Mushroom Spaghetti: Add the milk slowly, whisking to incorporate., milk, Milk)
#  pos: (Creamy Garlic Herb Mushroom Spaghetti: Add the oat milk slowly, whisking to incorporate., oat milk, Oat milk)
#  neg: (Creamy Garlic Herb Mushroom Spaghetti: Add the curacao slowly, whisking to incorporate., None, curacao),
#  id: 565
#  anchor: (Creamy Garlic Herb Mushroom Spaghetti: Add the milk slowly, whisking to incorporate., milk, Milk)
#  pos: (Creamy Garlic Herb Mushroom Spaghetti: Add the oat milk slowly, whisking to incorporate., oat milk, Oat milk)
#  neg: (Creamy Garlic Herb Mushroom Spaghetti: Add the ground ginger slowly, whisking to incorporate., None, ground ginger),
#  id: 565
#  anchor: (Creamy Garlic Herb Mushroom Spaghetti: Add the milk slowly, whisking to incorporate., milk, Milk)
#  pos: (Creamy Garlic Herb Mushroom Spaghetti: Add the oat milk slowly, whisking to incorporate., oat milk, Oat milk)
#  neg: (Creamy Garlic Herb Mushroom Spaghetti: Add the cherry slowly, whisking to incorporate., None, cherry),
#  id: 565
#  anchor: (Creamy Garlic Herb Mushroom Spaghetti: Add the milk slowly, whisking to incorporate., milk, Milk)
#  pos: (Creamy Garlic Herb Mushroom Spaghetti: Add the oat milk slowly, whisking to incorporate., oat milk, Oat milk)
#  neg: (Creamy Garlic Herb Mushroom Spaghetti: Add the partridge slowly, whisking to incorporate., None, partridge),
#  id: 565
#  anchor: (Creamy Garlic Herb Mushroom Spaghetti: Add the milk slowly, whisking to incorporate., milk, Milk)
#  pos: (Creamy Garlic Herb Mushroom Spaghetti: Add the oat milk slowly, whisking to incorporate., oat milk, Oat milk)
#  neg: (Creamy Garlic Herb Mushroom Spaghetti: Add the porridge oat slowly, whisking to incorporate., None, porridge oat),
#  id: 565
#  anchor: (Creamy Garlic Herb Mushroom Spaghetti: Add the milk slowly, whisking to incorporate., milk, Milk)
#  pos: (Creamy Garlic Herb Mushroom Spaghetti: Add the oat milk slowly, whisking to incorporate., oat milk, Oat milk)
#  neg: (Creamy Garlic Herb Mushroom Spaghetti: Add the sardine slowly, whisking to incorporate., None, sardine),
#  id: 565
#  anchor: (Creamy Garlic Herb Mushroom Spaghetti: Add the milk slowly, whisking to incorporate., milk, Milk)
#  pos: (Creamy Garlic Herb Mushroom Spaghetti: Add the oat milk slowly, whisking to incorporate., oat milk, Oat milk)
#  neg: (Creamy Garlic Herb Mushroom Spaghetti: Add the date slowly, whisking to incorporate., None, date),
#  id: 565
#  anchor: (Creamy Garlic Herb Mushroom Spaghetti: Add the milk slowly, whisking to incorporate., milk, Milk)
#  pos: (Creamy Garlic Herb Mushroom Spaghetti: Add the oat milk slowly, whisking to incorporate., oat milk, Oat milk)
#  neg: (Creamy Garlic Herb Mushroom Spaghetti: Add the aduki bean slowly, whisking to incorporate., None, aduki bean),
#  id: 565
#  anchor: (Creamy Garlic Herb Mushroom Spaghetti: Add the milk slowly, whisking to incorporate., milk, Milk)
#  pos: (Creamy Garlic Herb Mushroom Spaghetti: Add the oat milk slowly, whisking to incorporate., oat milk, Oat milk)
#  neg: (Creamy Garlic Herb Mushroom Spaghetti: Add the truffle oil slowly, whisking to incorporate., None, truffle oil),
#  id: 470
#  anchor: (Green beans & mushrooms with tangy soy dressing: Pour over the beans and toss gently., French green beans, Green bean)
#  pos: (Green beans & mushrooms with tangy soy dressing: Pour over the other green beans or green vegetable and toss gently., Other green beans or green vegetable, Broccoli)
#  neg: (Green beans & mushrooms with tangy soy dressing: Pour over the bicarbonate of soda and toss gently., None, bicarbonate of soda),
#  id: 470
#  anchor: (Green beans & mushrooms with tangy soy dressing: Pour over the beans and toss gently., French green beans, Green bean)
#  pos: (Green beans & mushrooms with tangy soy dressing: Pour over the other green beans or green vegetable and toss gently., Other green beans or green vegetable, Broccoli)
#  neg: (Green beans & mushrooms with tangy soy dressing: Pour over the marjoram and toss gently., None, marjoram),
#  id: 470
#  anchor: (Green beans & mushrooms with tangy soy dressing: Pour over the beans and toss gently., French green beans, Green bean)
#  pos: (Green beans & mushrooms with tangy soy dressing: Pour over the other green beans or green vegetable and toss gently., Other green beans or green vegetable, Broccoli)
#  neg: (Green beans & mushrooms with tangy soy dressing: Pour over the yeast extract and toss gently., None, yeast extract),
#  id: 470
#  anchor: (Green beans & mushrooms with tangy soy dressing: Pour over the beans and toss gently., French green beans, Green bean)
#  pos: (Green beans & mushrooms with tangy soy dressing: Pour over the other green beans or green vegetable and toss gently., Other green beans or green vegetable, Broccoli)
#  neg: (Green beans & mushrooms with tangy soy dressing: Pour over the shortening and toss gently., None, shortening),
#  id: 470
#  anchor: (Green beans & mushrooms with tangy soy dressing: Pour over the beans and toss gently., French green beans, Green bean)
#  pos: (Green beans & mushrooms with tangy soy dressing: Pour over the other green beans or green vegetable and toss gently., Other green beans or green vegetable, Broccoli)
#  neg: (Green beans & mushrooms with tangy soy dressing: Pour over the mackerel and toss gently., None, mackerel),
#  id: 470
#  anchor: (Green beans & mushrooms with tangy soy dressing: Pour over the beans and toss gently., French green beans, Green bean)
#  pos: (Green beans & mushrooms with tangy soy dressing: Pour over the other green beans or green vegetable and toss gently., Other green beans or green vegetable, Broccoli)
#  neg: (Green beans & mushrooms with tangy soy dressing: Pour over the rabbit and toss gently., None, rabbit),
#  id: 470
#  anchor: (Green beans & mushrooms with tangy soy dressing: Pour over the beans and toss gently., French green beans, Green bean)
#  pos: (Green beans & mushrooms with tangy soy dressing: Pour over the other green beans or green vegetable and toss gently., Other green beans or green vegetable, Broccoli)
#  neg: (Green beans & mushrooms with tangy soy dressing: Pour over the radish and toss gently., None, radish),
#  id: 470
#  anchor: (Green beans & mushrooms with tangy soy dressing: Pour over the beans and toss gently., French green beans, Green bean)
#  pos: (Green beans & mushrooms with tangy soy dressing: Pour over the other green beans or green vegetable and toss gently., Other green beans or green vegetable, Broccoli)
#  neg: (Green beans & mushrooms with tangy soy dressing: Pour over the banana and toss gently., None, banana),
#  id: 470
#  anchor: (Green beans & mushrooms with tangy soy dressing: Pour over the beans and toss gently., French green beans, Green bean)
#  pos: (Green beans & mushrooms with tangy soy dressing: Pour over the other green beans or green vegetable and toss gently., Other green beans or green vegetable, Broccoli)
#  neg: (Green beans & mushrooms with tangy soy dressing: Pour over the watercress and toss gently., None, watercress),
#  id: 470
#  anchor: (Green beans & mushrooms with tangy soy dressing: Pour over the beans and toss gently., French green beans, Green bean)
#  pos: (Green beans & mushrooms with tangy soy dressing: Pour over the other green beans or green vegetable and toss gently., Other green beans or green vegetable, Broccoli)
#  neg: (Green beans & mushrooms with tangy soy dressing: Pour over the betel nut and toss gently., None, betel nut),
#  id: 582
#  anchor: (Dumpling Wrapper Bun with juicy filling: Prepare the zucchini and filling, zucchini, Courgette)
#  pos: (Dumpling Wrapper Bun with juicy filling: Prepare the aubergine and filling, Aubergine, Aubergine)
#  neg: (Dumpling Wrapper Bun with juicy filling: Prepare the plantain and filling, None, plantain),
#  id: 582
#  anchor: (Dumpling Wrapper Bun with juicy filling: Prepare the zucchini and filling, zucchini, Courgette)
#  pos: (Dumpling Wrapper Bun with juicy filling: Prepare the aubergine and filling, Aubergine, Aubergine)
#  neg: (Dumpling Wrapper Bun with juicy filling: Prepare the plant-based mayonnaise and filling, None, plant-based mayonnaise),
#  id: 582
#  anchor: (Dumpling Wrapper Bun with juicy filling: Prepare the zucchini and filling, zucchini, Courgette)
#  pos: (Dumpling Wrapper Bun with juicy filling: Prepare the aubergine and filling, Aubergine, Aubergine)
#  neg: (Dumpling Wrapper Bun with juicy filling: Prepare the brown rice and filling, None, brown rice),
#  id: 582
#  anchor: (Dumpling Wrapper Bun with juicy filling: Prepare the zucchini and filling, zucchini, Courgette)
#  pos: (Dumpling Wrapper Bun with juicy filling: Prepare the aubergine and filling, Aubergine, Aubergine)
#  neg: (Dumpling Wrapper Bun with juicy filling: Prepare the pine nut and filling, None, pine nut),
#  id: 582
#  anchor: (Dumpling Wrapper Bun with juicy filling: Prepare the zucchini and filling, zucchini, Courgette)
#  pos: (Dumpling Wrapper Bun with juicy filling: Prepare the aubergine and filling, Aubergine, Aubergine)
#  neg: (Dumpling Wrapper Bun with juicy filling: Prepare the black gram and filling, None, black gram),
#  id: 582
#  anchor: (Dumpling Wrapper Bun with juicy filling: Prepare the zucchini and filling, zucchini, Courgette)
#  pos: (Dumpling Wrapper Bun with juicy filling: Prepare the aubergine and filling, Aubergine, Aubergine)
#  neg: (Dumpling Wrapper Bun with juicy filling: Prepare the natural yogurt and filling, None, natural yogurt),
#  id: 582
#  anchor: (Dumpling Wrapper Bun with juicy filling: Prepare the zucchini and filling, zucchini, Courgette)
#  pos: (Dumpling Wrapper Bun with juicy filling: Prepare the aubergine and filling, Aubergine, Aubergine)
#  neg: (Dumpling Wrapper Bun with juicy filling: Prepare the tomato puree and filling, None, tomato puree),
#  id: 582
#  anchor: (Dumpling Wrapper Bun with juicy filling: Prepare the zucchini and filling, zucchini, Courgette)
#  pos: (Dumpling Wrapper Bun with juicy filling: Prepare the aubergine and filling, Aubergine, Aubergine)
#  neg: (Dumpling Wrapper Bun with juicy filling: Prepare the plum and filling, None, plum),
#  id: 582
#  anchor: (Dumpling Wrapper Bun with juicy filling: Prepare the zucchini and filling, zucchini, Courgette)
#  pos: (Dumpling Wrapper Bun with juicy filling: Prepare the aubergine and filling, Aubergine, Aubergine)
#  neg: (Dumpling Wrapper Bun with juicy filling: Prepare the sausage and filling, None, sausage),
#  id: 582
#  anchor: (Dumpling Wrapper Bun with juicy filling: Prepare the zucchini and filling, zucchini, Courgette)
#  pos: (Dumpling Wrapper Bun with juicy filling: Prepare the aubergine and filling, Aubergine, Aubergine)
#  neg: (Dumpling Wrapper Bun with juicy filling: Prepare the caviar and filling, None, caviar),
#  id: 562
#  anchor: (Simple veggie & tofu stir-fry: Cut the tofu into cubes, then place in a bowl and dust with the cornflour and a pinch of sea salt and black pepper., firm tofu, Tofu:Firm)
#  pos: (Simple veggie & tofu stir-fry: Cut the lentils into cubes, then place in a bowl and dust with the cornflour and a pinch of sea salt and black pepper., Lentils, Lentil)
#  neg: (Simple veggie & tofu stir-fry: Cut the lentil into cubes, then place in a bowl and dust with the cornflour and a pinch of sea salt and black pepper., None, lentil),
#  id: 562
#  anchor: (Simple veggie & tofu stir-fry: Cut the tofu into cubes, then place in a bowl and dust with the cornflour and a pinch of sea salt and black pepper., firm tofu, Tofu:Firm)
#  pos: (Simple veggie & tofu stir-fry: Cut the lentils into cubes, then place in a bowl and dust with the cornflour and a pinch of sea salt and black pepper., Lentils, Lentil)
#  neg: (Simple veggie & tofu stir-fry: Cut the tempeh into cubes, then place in a bowl and dust with the cornflour and a pinch of sea salt and black pepper., None, tempeh),
#  id: 562
#  anchor: (Simple veggie & tofu stir-fry: Cut the tofu into cubes, then place in a bowl and dust with the cornflour and a pinch of sea salt and black pepper., firm tofu, Tofu:Firm)
#  pos: (Simple veggie & tofu stir-fry: Cut the lentils into cubes, then place in a bowl and dust with the cornflour and a pinch of sea salt and black pepper., Lentils, Lentil)
#  neg: (Simple veggie & tofu stir-fry: Cut the vermouth into cubes, then place in a bowl and dust with the cornflour and a pinch of sea salt and black pepper., None, vermouth),
#  id: 562
#  anchor: (Simple veggie & tofu stir-fry: Cut the tofu into cubes, then place in a bowl and dust with the cornflour and a pinch of sea salt and black pepper., firm tofu, Tofu:Firm)
#  pos: (Simple veggie & tofu stir-fry: Cut the lentils into cubes, then place in a bowl and dust with the cornflour and a pinch of sea salt and black pepper., Lentils, Lentil)
#  neg: (Simple veggie & tofu stir-fry: Cut the pineapple into cubes, then place in a bowl and dust with the cornflour and a pinch of sea salt and black pepper., None, pineapple),
#  id: 562
#  anchor: (Simple veggie & tofu stir-fry: Cut the tofu into cubes, then place in a bowl and dust with the cornflour and a pinch of sea salt and black pepper., firm tofu, Tofu:Firm)
#  pos: (Simple veggie & tofu stir-fry: Cut the lentils into cubes, then place in a bowl and dust with the cornflour and a pinch of sea salt and black pepper., Lentils, Lentil)
#  neg: (Simple veggie & tofu stir-fry: Cut the egg noodle into cubes, then place in a bowl and dust with the cornflour and a pinch of sea salt and black pepper., None, egg noodle),
#  id: 562
#  anchor: (Simple veggie & tofu stir-fry: Cut the tofu into cubes, then place in a bowl and dust with the cornflour and a pinch of sea salt and black pepper., firm tofu, Tofu:Firm)
#  pos: (Simple veggie & tofu stir-fry: Cut the lentils into cubes, then place in a bowl and dust with the cornflour and a pinch of sea salt and black pepper., Lentils, Lentil)
#  neg: (Simple veggie & tofu stir-fry: Cut the haricot bean into cubes, then place in a bowl and dust with the cornflour and a pinch of sea salt and black pepper., None, haricot bean),
#  id: 562
#  anchor: (Simple veggie & tofu stir-fry: Cut the tofu into cubes, then place in a bowl and dust with the cornflour and a pinch of sea salt and black pepper., firm tofu, Tofu:Firm)
#  pos: (Simple veggie & tofu stir-fry: Cut the lentils into cubes, then place in a bowl and dust with the cornflour and a pinch of sea salt and black pepper., Lentils, Lentil)
#  neg: (Simple veggie & tofu stir-fry: Cut the parrot fish into cubes, then place in a bowl and dust with the cornflour and a pinch of sea salt and black pepper., None, parrot fish),
#  id: 562
#  anchor: (Simple veggie & tofu stir-fry: Cut the tofu into cubes, then place in a bowl and dust with the cornflour and a pinch of sea salt and black pepper., firm tofu, Tofu:Firm)
#  pos: (Simple veggie & tofu stir-fry: Cut the lentils into cubes, then place in a bowl and dust with the cornflour and a pinch of sea salt and black pepper., Lentils, Lentil)
#  neg: (Simple veggie & tofu stir-fry: Cut the single cream into cubes, then place in a bowl and dust with the cornflour and a pinch of sea salt and black pepper., None, single cream),
#  id: 562
#  anchor: (Simple veggie & tofu stir-fry: Cut the tofu into cubes, then place in a bowl and dust with the cornflour and a pinch of sea salt and black pepper., firm tofu, Tofu:Firm)
#  pos: (Simple veggie & tofu stir-fry: Cut the lentils into cubes, then place in a bowl and dust with the cornflour and a pinch of sea salt and black pepper., Lentils, Lentil)
#  neg: (Simple veggie & tofu stir-fry: Cut the cajun seasoning into cubes, then place in a bowl and dust with the cornflour and a pinch of sea salt and black pepper., None, cajun seasoning),
#  id: 562
#  anchor: (Simple veggie & tofu stir-fry: Cut the tofu into cubes, then place in a bowl and dust with the cornflour and a pinch of sea salt and black pepper., firm tofu, Tofu:Firm)
#  pos: (Simple veggie & tofu stir-fry: Cut the lentils into cubes, then place in a bowl and dust with the cornflour and a pinch of sea salt and black pepper., Lentils, Lentil)
#  neg: (Simple veggie & tofu stir-fry: Cut the avocado into cubes, then place in a bowl and dust with the cornflour and a pinch of sea salt and black pepper., None, avocado),
#  id: 65
#  anchor: (Chilli con carne recipe: Add the onion and cook, stirring fairly frequently, for about 5 minutes, or until the onion is soft, squidgy and slightly translucent.STEP 5Tip in the garlic, red pepper, 1 heaped tsp hot chilli powder or 1 level tbsp mild chilli powder, 1 tsp paprika and 1 tsp ground cumin.STEP 6Give it a good stir, then leave it to cook for another 5 minutes, stirring occasionally.STEP 7Brown 500g lean minced beef., lean minced beef, Beef:Mince)
#  pos: (Chilli con carne recipe: Add the onion and cook, stirring fairly frequently, for about 5 minutes, or until the onion is soft, squidgy and slightly translucent.STEP 5Tip in the garlic, red pepper, 1 heaped tsp hot chilli powder or 1 level tbsp mild chilli powder, 1 tsp paprika and 1 tsp ground cumin.STEP 6Give it a good stir, then leave it to cook for another 5 minutes, stirring occasionally.STEP 7Brown 500g quorn mince., Quorn mince, Quorn:Mince)
#  neg: (Chilli con carne recipe: Add the onion and cook, stirring fairly frequently, for about 5 minutes, or until the onion is soft, squidgy and slightly translucent.STEP 5Tip in the garlic, red pepper, 1 heaped tsp hot chilli powder or 1 level tbsp mild chilli powder, 1 tsp paprika and 1 tsp ground cumin.STEP 6Give it a good stir, then leave it to cook for another 5 minutes, stirring occasionally.STEP 7Brown 500g mache., None, mache),
#  id: 65
#  anchor: (Chilli con carne recipe: Add the onion and cook, stirring fairly frequently, for about 5 minutes, or until the onion is soft, squidgy and slightly translucent.STEP 5Tip in the garlic, red pepper, 1 heaped tsp hot chilli powder or 1 level tbsp mild chilli powder, 1 tsp paprika and 1 tsp ground cumin.STEP 6Give it a good stir, then leave it to cook for another 5 minutes, stirring occasionally.STEP 7Brown 500g lean minced beef., lean minced beef, Beef:Mince)
#  pos: (Chilli con carne recipe: Add the onion and cook, stirring fairly frequently, for about 5 minutes, or until the onion is soft, squidgy and slightly translucent.STEP 5Tip in the garlic, red pepper, 1 heaped tsp hot chilli powder or 1 level tbsp mild chilli powder, 1 tsp paprika and 1 tsp ground cumin.STEP 6Give it a good stir, then leave it to cook for another 5 minutes, stirring occasionally.STEP 7Brown 500g quorn mince., Quorn mince, Quorn:Mince)
#  neg: (Chilli con carne recipe: Add the onion and cook, stirring fairly frequently, for about 5 minutes, or until the onion is soft, squidgy and slightly translucent.STEP 5Tip in the garlic, red pepper, 1 heaped tsp hot chilli powder or 1 level tbsp mild chilli powder, 1 tsp paprika and 1 tsp ground cumin.STEP 6Give it a good stir, then leave it to cook for another 5 minutes, stirring occasionally.STEP 7Brown 500g ale., None, ale),
#  id: 65
#  anchor: (Chilli con carne recipe: Add the onion and cook, stirring fairly frequently, for about 5 minutes, or until the onion is soft, squidgy and slightly translucent.STEP 5Tip in the garlic, red pepper, 1 heaped tsp hot chilli powder or 1 level tbsp mild chilli powder, 1 tsp paprika and 1 tsp ground cumin.STEP 6Give it a good stir, then leave it to cook for another 5 minutes, stirring occasionally.STEP 7Brown 500g lean minced beef., lean minced beef, Beef:Mince)
#  pos: (Chilli con carne recipe: Add the onion and cook, stirring fairly frequently, for about 5 minutes, or until the onion is soft, squidgy and slightly translucent.STEP 5Tip in the garlic, red pepper, 1 heaped tsp hot chilli powder or 1 level tbsp mild chilli powder, 1 tsp paprika and 1 tsp ground cumin.STEP 6Give it a good stir, then leave it to cook for another 5 minutes, stirring occasionally.STEP 7Brown 500g quorn mince., Quorn mince, Quorn:Mince)
#  neg: (Chilli con carne recipe: Add the onion and cook, stirring fairly frequently, for about 5 minutes, or until the onion is soft, squidgy and slightly translucent.STEP 5Tip in the garlic, red pepper, 1 heaped tsp hot chilli powder or 1 level tbsp mild chilli powder, 1 tsp paprika and 1 tsp ground cumin.STEP 6Give it a good stir, then leave it to cook for another 5 minutes, stirring occasionally.STEP 7Brown 500g edam., None, edam),
#  id: 65
#  anchor: (Chilli con carne recipe: Add the onion and cook, stirring fairly frequently, for about 5 minutes, or until the onion is soft, squidgy and slightly translucent.STEP 5Tip in the garlic, red pepper, 1 heaped tsp hot chilli powder or 1 level tbsp mild chilli powder, 1 tsp paprika and 1 tsp ground cumin.STEP 6Give it a good stir, then leave it to cook for another 5 minutes, stirring occasionally.STEP 7Brown 500g lean minced beef., lean minced beef, Beef:Mince)
# ...
#  neg: (Teriyaki Chicken and Rice Bowl: Add the chicken with the marinade and simmer until sauce reduces and thickens and chicken is soya flour through, remove from pan and set aside, None, soya flour),
#  id: 521
#  anchor: (Teriyaki Chicken and Rice Bowl: Add the chicken with the marinade and simmer until sauce reduces and thickens and chicken is cooked through, remove from pan and set aside, cooked long grain rice, Long-grain rice)
#  pos: (Teriyaki Chicken and Rice Bowl: Add the chicken with the marinade and simmer until sauce reduces and thickens and chicken is shirataki rice through, remove from pan and set aside, Shirataki rice, White rice)
#  neg: (Teriyaki Chicken and Rice Bowl: Add the chicken with the marinade and simmer until sauce reduces and thickens and chicken is tea through, remove from pan and set aside, None, tea),
#  id: 521
#  anchor: (Teriyaki Chicken and Rice Bowl: Add the chicken with the marinade and simmer until sauce reduces and thickens and chicken is cooked through, remove from pan and set aside, cooked long grain rice, Long-grain rice)
#  pos: (Teriyaki Chicken and Rice Bowl: Add the chicken with the marinade and simmer until sauce reduces and thickens and chicken is shirataki rice through, remove from pan and set aside, Shirataki rice, White rice)
#  neg: (Teriyaki Chicken and Rice Bowl: Add the chicken with the marinade and simmer until sauce reduces and thickens and chicken is golden syrup through, remove from pan and set aside, None, golden syrup),
#  id: 521
#  anchor: (Teriyaki Chicken and Rice Bowl: Add the chicken with the marinade and simmer until sauce reduces and thickens and chicken is cooked through, remove from pan and set aside, cooked long grain rice, Long-grain rice)
#  pos: (Teriyaki Chicken and Rice Bowl: Add the chicken with the marinade and simmer until sauce reduces and thickens and chicken is shirataki rice through, remove from pan and set aside, Shirataki rice, White rice)
#  neg: (Teriyaki Chicken and Rice Bowl: Add the chicken with the marinade and simmer until sauce reduces and thickens and chicken is pecorino through, remove from pan and set aside, None, pecorino),
#  id: 521
#  anchor: (Teriyaki Chicken and Rice Bowl: Add the chicken with the marinade and simmer until sauce reduces and thickens and chicken is cooked through, remove from pan and set aside, cooked long grain rice, Long-grain rice)
#  pos: (Teriyaki Chicken and Rice Bowl: Add the chicken with the marinade and simmer until sauce reduces and thickens and chicken is shirataki rice through, remove from pan and set aside, Shirataki rice, White rice)
#  neg: (Teriyaki Chicken and Rice Bowl: Add the chicken with the marinade and simmer until sauce reduces and thickens and chicken is rosemary through, remove from pan and set aside, None, rosemary),
#  id: 521
#  anchor: (Teriyaki Chicken and Rice Bowl: Add the chicken with the marinade and simmer until sauce reduces and thickens and chicken is cooked through, remove from pan and set aside, cooked long grain rice, Long-grain rice)
#  pos: (Teriyaki Chicken and Rice Bowl: Add the chicken with the marinade and simmer until sauce reduces and thickens and chicken is shirataki rice through, remove from pan and set aside, Shirataki rice, White rice)
#  neg: (Teriyaki Chicken and Rice Bowl: Add the chicken with the marinade and simmer until sauce reduces and thickens and chicken is quinoa through, remove from pan and set aside, None, quinoa),
#  id: 521
#  anchor: (Teriyaki Chicken and Rice Bowl: Add the chicken with the marinade and simmer until sauce reduces and thickens and chicken is cooked through, remove from pan and set aside, cooked long grain rice, Long-grain rice)
#  pos: (Teriyaki Chicken and Rice Bowl: Add the chicken with the marinade and simmer until sauce reduces and thickens and chicken is shirataki rice through, remove from pan and set aside, Shirataki rice, White rice)
#  neg: (Teriyaki Chicken and Rice Bowl: Add the chicken with the marinade and simmer until sauce reduces and thickens and chicken is all purpose seasoning through, remove from pan and set aside, None, all purpose seasoning),
#  id: 521
#  anchor: (Teriyaki Chicken and Rice Bowl: Add the chicken with the marinade and simmer until sauce reduces and thickens and chicken is cooked through, remove from pan and set aside, cooked long grain rice, Long-grain rice)
#  pos: (Teriyaki Chicken and Rice Bowl: Add the chicken with the marinade and simmer until sauce reduces and thickens and chicken is shirataki rice through, remove from pan and set aside, Shirataki rice, White rice)
#  neg: (Teriyaki Chicken and Rice Bowl: Add the chicken with the marinade and simmer until sauce reduces and thickens and chicken is plant-based meatball through, remove from pan and set aside, None, plant-based meatball),
#  id: 521
#  anchor: (Teriyaki Chicken and Rice Bowl: Add the chicken with the marinade and simmer until sauce reduces and thickens and chicken is cooked through, remove from pan and set aside, cooked long grain rice, Long-grain rice)
#  pos: (Teriyaki Chicken and Rice Bowl: Add the chicken with the marinade and simmer until sauce reduces and thickens and chicken is shirataki rice through, remove from pan and set aside, Shirataki rice, White rice)
#  neg: (Teriyaki Chicken and Rice Bowl: Add the chicken with the marinade and simmer until sauce reduces and thickens and chicken is guava through, remove from pan and set aside, None, guava),
#  id: 92
#  anchor: (Arabic Chicken Shawarma: Place the bag of chicken into the fridge to marinate 8 hours or overnight., chicken breasts, Chicken:Breast)
#  pos: (Arabic Chicken Shawarma: Place the bag of quourn chicken into the fridge to marinate 8 hours or overnight., quourn chicken, Quorn:Pieces)
#  neg: (Arabic Chicken Shawarma: Place the bag of bele into the fridge to marinate 8 hours or overnight., None, bele),
#  id: 92
#  anchor: (Arabic Chicken Shawarma: Place the bag of chicken into the fridge to marinate 8 hours or overnight., chicken breasts, Chicken:Breast)
#  pos: (Arabic Chicken Shawarma: Place the bag of quourn chicken into the fridge to marinate 8 hours or overnight., quourn chicken, Quorn:Pieces)
#  neg: (Arabic Chicken Shawarma: Place the bag of garlic into the fridge to marinate 8 hours or overnight., None, garlic),
#  id: 92
#  anchor: (Arabic Chicken Shawarma: Place the bag of chicken into the fridge to marinate 8 hours or overnight., chicken breasts, Chicken:Breast)
#  pos: (Arabic Chicken Shawarma: Place the bag of quourn chicken into the fridge to marinate 8 hours or overnight., quourn chicken, Quorn:Pieces)
#  neg: (Arabic Chicken Shawarma: Place the bag of rhubarb into the fridge to marinate 8 hours or overnight., None, rhubarb),
#  id: 92
#  anchor: (Arabic Chicken Shawarma: Place the bag of chicken into the fridge to marinate 8 hours or overnight., chicken breasts, Chicken:Breast)
#  pos: (Arabic Chicken Shawarma: Place the bag of quourn chicken into the fridge to marinate 8 hours or overnight., quourn chicken, Quorn:Pieces)
#  neg: (Arabic Chicken Shawarma: Place the bag of pomegranate into the fridge to marinate 8 hours or overnight., None, pomegranate),
#  id: 92
#  anchor: (Arabic Chicken Shawarma: Place the bag of chicken into the fridge to marinate 8 hours or overnight., chicken breasts, Chicken:Breast)
#  pos: (Arabic Chicken Shawarma: Place the bag of quourn chicken into the fridge to marinate 8 hours or overnight., quourn chicken, Quorn:Pieces)
#  neg: (Arabic Chicken Shawarma: Place the bag of butternut squash into the fridge to marinate 8 hours or overnight., None, butternut squash),
#  id: 92
#  anchor: (Arabic Chicken Shawarma: Place the bag of chicken into the fridge to marinate 8 hours or overnight., chicken breasts, Chicken:Breast)
#  pos: (Arabic Chicken Shawarma: Place the bag of quourn chicken into the fridge to marinate 8 hours or overnight., quourn chicken, Quorn:Pieces)
#  neg: (Arabic Chicken Shawarma: Place the bag of evening primrose oil into the fridge to marinate 8 hours or overnight., None, evening primrose oil),
#  id: 92
#  anchor: (Arabic Chicken Shawarma: Place the bag of chicken into the fridge to marinate 8 hours or overnight., chicken breasts, Chicken:Breast)
#  pos: (Arabic Chicken Shawarma: Place the bag of quourn chicken into the fridge to marinate 8 hours or overnight., quourn chicken, Quorn:Pieces)
#  neg: (Arabic Chicken Shawarma: Place the bag of golden syrup into the fridge to marinate 8 hours or overnight., None, golden syrup),
#  id: 92
#  anchor: (Arabic Chicken Shawarma: Place the bag of chicken into the fridge to marinate 8 hours or overnight., chicken breasts, Chicken:Breast)
#  pos: (Arabic Chicken Shawarma: Place the bag of quourn chicken into the fridge to marinate 8 hours or overnight., quourn chicken, Quorn:Pieces)
#  neg: (Arabic Chicken Shawarma: Place the bag of betel nut into the fridge to marinate 8 hours or overnight., None, betel nut),
#  id: 92
#  anchor: (Arabic Chicken Shawarma: Place the bag of chicken into the fridge to marinate 8 hours or overnight., chicken breasts, Chicken:Breast)
#  pos: (Arabic Chicken Shawarma: Place the bag of quourn chicken into the fridge to marinate 8 hours or overnight., quourn chicken, Quorn:Pieces)
#  neg: (Arabic Chicken Shawarma: Place the bag of jam into the fridge to marinate 8 hours or overnight., None, jam),
#  id: 92
#  anchor: (Arabic Chicken Shawarma: Place the bag of chicken into the fridge to marinate 8 hours or overnight., chicken breasts, Chicken:Breast)
#  pos: (Arabic Chicken Shawarma: Place the bag of quourn chicken into the fridge to marinate 8 hours or overnight., quourn chicken, Quorn:Pieces)
#  neg: (Arabic Chicken Shawarma: Place the bag of chicken stock cube into the fridge to marinate 8 hours or overnight., None, chicken stock cube),
#  id: 95
#  anchor: (Molokhia (Mloukhieh): Remove chicken and set aside., chicken breast, Chicken:Breast)
#  pos: (Molokhia (Mloukhieh): Remove quorn chicken and set aside., quorn chicken, Quorn:Pieces)
#  neg: (Molokhia (Mloukhieh): Remove langoustine and set aside., None, langoustine),
#  id: 95
#  anchor: (Molokhia (Mloukhieh): Remove chicken and set aside., chicken breast, Chicken:Breast)
#  pos: (Molokhia (Mloukhieh): Remove quorn chicken and set aside., quorn chicken, Quorn:Pieces)
#  neg: (Molokhia (Mloukhieh): Remove lemongrass and set aside., None, lemongrass),
#  id: 95
#  anchor: (Molokhia (Mloukhieh): Remove chicken and set aside., chicken breast, Chicken:Breast)
#  pos: (Molokhia (Mloukhieh): Remove quorn chicken and set aside., quorn chicken, Quorn:Pieces)
#  neg: (Molokhia (Mloukhieh): Remove mutton and set aside., None, mutton),
#  id: 95
#  anchor: (Molokhia (Mloukhieh): Remove chicken and set aside., chicken breast, Chicken:Breast)
#  pos: (Molokhia (Mloukhieh): Remove quorn chicken and set aside., quorn chicken, Quorn:Pieces)
#  neg: (Molokhia (Mloukhieh): Remove chital and set aside., None, chital),
#  id: 95
#  anchor: (Molokhia (Mloukhieh): Remove chicken and set aside., chicken breast, Chicken:Breast)
#  pos: (Molokhia (Mloukhieh): Remove quorn chicken and set aside., quorn chicken, Quorn:Pieces)
#  neg: (Molokhia (Mloukhieh): Remove truffles and set aside., None, truffles),
#  id: 95
#  anchor: (Molokhia (Mloukhieh): Remove chicken and set aside., chicken breast, Chicken:Breast)
#  pos: (Molokhia (Mloukhieh): Remove quorn chicken and set aside., quorn chicken, Quorn:Pieces)
#  neg: (Molokhia (Mloukhieh): Remove apple sauce and set aside., None, apple sauce),
#  id: 95
#  anchor: (Molokhia (Mloukhieh): Remove chicken and set aside., chicken breast, Chicken:Breast)
#  pos: (Molokhia (Mloukhieh): Remove quorn chicken and set aside., quorn chicken, Quorn:Pieces)
#  neg: (Molokhia (Mloukhieh): Remove semolina and set aside., None, semolina),
#  id: 95
#  anchor: (Molokhia (Mloukhieh): Remove chicken and set aside., chicken breast, Chicken:Breast)
#  pos: (Molokhia (Mloukhieh): Remove quorn chicken and set aside., quorn chicken, Quorn:Pieces)
#  neg: (Molokhia (Mloukhieh): Remove bass and set aside., None, bass),
#  id: 95
#  anchor: (Molokhia (Mloukhieh): Remove chicken and set aside., chicken breast, Chicken:Breast)
#  pos: (Molokhia (Mloukhieh): Remove quorn chicken and set aside., quorn chicken, Quorn:Pieces)
#  neg: (Molokhia (Mloukhieh): Remove paprika and set aside., None, paprika),
#  id: 95
#  anchor: (Molokhia (Mloukhieh): Remove chicken and set aside., chicken breast, Chicken:Breast)
#  pos: (Molokhia (Mloukhieh): Remove quorn chicken and set aside., quorn chicken, Quorn:Pieces)
#  neg: (Molokhia (Mloukhieh): Remove oregano and set aside., None, oregano),
#  id: 27
#  anchor: (Cold Peanut Noodle Salad: Bring a pot of water to a boil for the whole wheat spaghetti., whole wheat spaghetti, Spaghetti)
#  pos: (Cold Peanut Noodle Salad: Bring a pot of water to a boil for the  noodles.,  noodles, Wheat noodle)
#  neg: (Cold Peanut Noodle Salad: Bring a pot of water to a boil for the granulated sugar., None, granulated sugar),
#  id: 27
#  anchor: (Cold Peanut Noodle Salad: Bring a pot of water to a boil for the whole wheat spaghetti., whole wheat spaghetti, Spaghetti)
#  pos: (Cold Peanut Noodle Salad: Bring a pot of water to a boil for the  noodles.,  noodles, Wheat noodle)
#  neg: (Cold Peanut Noodle Salad: Bring a pot of water to a boil for the syrup., None, syrup),
#  id: 27
#  anchor: (Cold Peanut Noodle Salad: Bring a pot of water to a boil for the whole wheat spaghetti., whole wheat spaghetti, Spaghetti)
#  pos: (Cold Peanut Noodle Salad: Bring a pot of water to a boil for the  noodles.,  noodles, Wheat noodle)
#  neg: (Cold Peanut Noodle Salad: Bring a pot of water to a boil for the trout., None, trout),
#  id: 27
#  anchor: (Cold Peanut Noodle Salad: Bring a pot of water to a boil for the whole wheat spaghetti., whole wheat spaghetti, Spaghetti)
#  pos: (Cold Peanut Noodle Salad: Bring a pot of water to a boil for the  noodles.,  noodles, Wheat noodle)
#  neg: (Cold Peanut Noodle Salad: Bring a pot of water to a boil for the cocoa., None, cocoa),
#  id: 27
#  anchor: (Cold Peanut Noodle Salad: Bring a pot of water to a boil for the whole wheat spaghetti., whole wheat spaghetti, Spaghetti)
#  pos: (Cold Peanut Noodle Salad: Bring a pot of water to a boil for the  noodles.,  noodles, Wheat noodle)
#  neg: (Cold Peanut Noodle Salad: Bring a pot of water to a boil for the brazil nut., None, brazil nut),
#  id: 27
#  anchor: (Cold Peanut Noodle Salad: Bring a pot of water to a boil for the whole wheat spaghetti., whole wheat spaghetti, Spaghetti)
#  pos: (Cold Peanut Noodle Salad: Bring a pot of water to a boil for the  noodles.,  noodles, Wheat noodle)
#  neg: (Cold Peanut Noodle Salad: Bring a pot of water to a boil for the nutritional yeast., None, nutritional yeast),
#  id: 27
#  anchor: (Cold Peanut Noodle Salad: Bring a pot of water to a boil for the whole wheat spaghetti., whole wheat spaghetti, Spaghetti)
#  pos: (Cold Peanut Noodle Salad: Bring a pot of water to a boil for the  noodles.,  noodles, Wheat noodle)
#  neg: (Cold Peanut Noodle Salad: Bring a pot of water to a boil for the crayfish., None, crayfish),
#  id: 27
#  anchor: (Cold Peanut Noodle Salad: Bring a pot of water to a boil for the whole wheat spaghetti., whole wheat spaghetti, Spaghetti)
#  pos: (Cold Peanut Noodle Salad: Bring a pot of water to a boil for the  noodles.,  noodles, Wheat noodle)
#  neg: (Cold Peanut Noodle Salad: Bring a pot of water to a boil for the mulberries., None, mulberries),
#  id: 27
#  anchor: (Cold Peanut Noodle Salad: Bring a pot of water to a boil for the whole wheat spaghetti., whole wheat spaghetti, Spaghetti)
#  pos: (Cold Peanut Noodle Salad: Bring a pot of water to a boil for the  noodles.,  noodles, Wheat noodle)
#  neg: (Cold Peanut Noodle Salad: Bring a pot of water to a boil for the kohl rabi., None, kohl rabi),
#  id: 27
#  anchor: (Cold Peanut Noodle Salad: Bring a pot of water to a boil for the whole wheat spaghetti., whole wheat spaghetti, Spaghetti)
#  pos: (Cold Peanut Noodle Salad: Bring a pot of water to a boil for the  noodles.,  noodles, Wheat noodle)
#  neg: (Cold Peanut Noodle Salad: Bring a pot of water to a boil for the beer., None, beer),
#  ...]

# %% [markdown]
# # Save output

# %%
import csv

def write_triplets_to_csv(validTripletPoints, output_file):
    
    # Write data to CSV file
    with open(output_file, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['anchor', 'anchor_raw_ingred_name', 'anchor_matched_ingred_name',
                         'pos', 'pos_raw_ingred_name', 'pos_matched_ingred_name',
                         'neg', 'neg_raw_ingred_name'])
        for point in validTripletPoints:
            writer.writerow([
                point.anchor.rawRecipeText,
                point.anchor.rawName,
                point.anchor.matched,
                point.pos.rawRecipeText,
                point.pos.rawName,
                point.pos.matched,
                point.neg.rawRecipeText,
                point.neg.matched,
            ])

# Example usage:
write_triplets_to_csv(validTripletPoints, OUTPUT_CSV_FILE_PATH)

print(validTripletPoints[0])
# Out:
# id: 579
# anchor: (Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside coconut rice., fat coconut milk, Coconut milk)
# pos: (Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside  oat yoghurt rice.,  oat yoghurt, Plant-based yogurt)
# neg: (Filling & Nourishing Red Lentil Curry with Spinach: Serve alongside agave rice., None, agave)
